# %% [markdown]
# ## Using the AGM_diag class to analyse nextGEMS cycle 3 data
#
# The data analized here are:
# - tco1279-orca025 (5 years)
# - tco2559-ng5 (5 years)
# - ngc3028 (5 years)
#
# In this notebook we will have a look at the vertical bias plots where we compare the model data with ERA5 climatology. The plots show meridional cross sections.
# Different variables are chosen for the comparison.

# %%
from aqua import Reader, catalogue, inspect_catalogue
import os
import sys
# %env PATH={os.environ["PATH"]}:{sys.exec_prefix}/bin/
parent_directory = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_directory)

from atm_global_mean import AGM_diag
# Out:
# FDB5 binary library not present on system, disabling FDB support.
# env: PATH=/sw/spack-levante/texlive-live2021-l5o6sw/bin/x86_64-linux:/sw/spack-levante/texlive-live2021-l5o6sw/bin:/sw/spack-levante/git-lfs-2.11.0-oihcwo/bin:/sw/spack-levante/git-2.31.1-25ve7r/bin:/sw/spack-levante/jupyterhub/jupyterhub/bin:/sw/spack-workplace/spack/bin:/usr/share/Modules/bin:/usr/local/bin:/usr/bin:/usr/local/sbin:/usr/sbin:/home/b/b382257/.conda/envs/aqua/bin/

# %%
#cat = catalogue()
#inspect_catalogue(cat)

# %% [markdown]
# The datasets we are having a look at are:

# %%
reader_era5 = Reader(model="ERA5", exp="era5", source="monthly")
data_era5 = reader_era5.retrieve(fix=True)

reader_tco2559 = Reader(model = 'IFS', exp = 'tco2559-ng5-cycle3', source = 'lra-r100-monthly')
data_tco2559 = reader_tco2559.retrieve(fix = False)

reader_tco1279 = Reader(model="IFS", exp="tco1279-orca025-cycle3",source =  'lra-r100-monthly')
data_tco1279 = reader_tco1279.retrieve(fix = False)

reader_icon = Reader(model = "ICON", exp = "ngc3028", source = 'lra-r100-monthly')
data_icon = reader_icon.retrieve(fix = False)

# %%
AGM_diag.compare_datasets_plev(data_tco2559, 't', slice('2020-01-01','2024-12-31'), model_label='IFS 4.4km')
# Out:
# The vertical bias plots have been saved to ./output/figs.
# The vertical bias data has been saved to ./output/data.

# %%
AGM_diag.compare_datasets_plev(data_tco2559, 'u', slice('2020-01-01','2024-12-31'), model_label='IFS 4.4km')
# Out:
# The vertical bias plots have been saved to ./output/figs.
# The vertical bias data has been saved to ./output/data.

# %%
AGM_diag.compare_datasets_plev(data_tco2559, 'v', slice('2020-01-01','2024-12-31'), model_label='IFS 4.4km')
# Out:
# The vertical bias plots have been saved to ./output/figs.
# The vertical bias data has been saved to ./output/data.

# %%
AGM_diag.compare_datasets_plev(data_tco2559, 'q', slice('2020-01-01','2024-12-31'), model_label='IFS 4.4km')
# Out:
# The vertical bias plots have been saved to ./output/figs.
# The vertical bias data has been saved to ./output/data.

# %%
AGM_diag.compare_datasets_plev(data_tco2559, 'v', slice('2020-01-01','2024-12-31'), model_label='IFS 4.4km')
# Out:
# The vertical bias plots have been saved to ./output/figs.
# The vertical bias data has been saved to ./output/data.

# %%
AGM_diag.compare_datasets_plev(data_tco1279, 't', slice('2020-01-01','2024-12-31'), model_label='IFS 9km')
# Out:
# The vertical bias plots have been saved to ./output/figs.
# The vertical bias data has been saved to ./output/data.
