# %% [markdown]
# # Demonstrator notebook

# %%
from aqua import Reader
import sys
sys.path.insert(0, '../../')
from atmglobalmean import seasonal_bias, compare_datasets_plev

# %% [markdown]
# We are loading the datasets using the AQUA Reader functionality:

# %%
# Loading ERA5 data
reader_era5 = Reader(model="ERA5", exp="era5", source="monthly")
data_era5 = reader_era5.retrieve()

# Loading IFS-NEMO historcal data
reader_ifs_nemo_historical = Reader(model = 'IFS-NEMO', exp = 'historical-1990', source = 'lra-r100-monthly')
data_ifs_nemo_historical = reader_ifs_nemo_historical.retrieve()
# Out:
# 2024-04-24 15:20:28 :: Reader :: WARNING  -> DATA_PATH parameter is required but is missing, setting to default /pfs/lustrep3/projappl/project_465000454/data/AQUA/datasets
# 2024-04-24 15:20:33 :: eccodes :: WARNING  -> ShortName tcc has multiple grib codes associated: ['228164', '164']
# 2024-04-24 15:20:33 :: eccodes :: WARNING  -> AQUA will take the first so that tcc -> 228164, please set up a correct fix if this does not look right
# 2024-04-24 15:20:33 :: eccodes :: WARNING  -> ShortName lcc has multiple grib codes associated: ['3073', '186']
# 2024-04-24 15:20:33 :: eccodes :: WARNING  -> AQUA will take the first so that lcc -> 3073, please set up a correct fix if this does not look right
# 2024-04-24 15:20:33 :: eccodes :: WARNING  -> ShortName mcc has multiple grib codes associated: ['3074', '187']
# 2024-04-24 15:20:33 :: eccodes :: WARNING  -> AQUA will take the first so that mcc -> 3074, please set up a correct fix if this does not look right
# 2024-04-24 15:20:33 :: eccodes :: WARNING  -> ShortName hcc has multiple grib codes associated: ['3075', '188']
# 2024-04-24 15:20:33 :: eccodes :: WARNING  -> AQUA will take the first so that hcc -> 3075, please set up a correct fix if this does not look right
# 2024-04-24 15:20:34 :: Reader :: WARNING  -> DATA_PATH parameter is required but is missing, setting to default /pfs/lustrep3/projappl/project_465000454/data/AQUA/datasets
# 2024-04-24 15:20:34 :: Reader :: WARNING  -> The requested default fixer name IFS-NEMO-default does not exist in fixes files
# 2024-04-24 15:20:34 :: Reader :: WARNING  -> No fixes available for model IFS-NEMO, experiment historical-1990, source lra-r100-monthly

# %% [markdown]
# ### 2m Temperature

# %%
seasonal_bias(
    dataset1=data_ifs_nemo_historical,
    dataset2=data_era5,
    var_name='2t',
    plev=None,
    model_label1='IFS-NEMO historical',
    model_label2='ERA5',
    start_date1 ='1990-01-01',
    end_date1 ='2000-12-31',
    start_date2 ='1980-01-01',
    end_date2 ='2010-12-31',
    vmin=-15,
    vmax=15,
    nlevels=16
    )

# %% [markdown]
# ### Sea surface temperature

# %%
seasonal_bias(
    dataset1=data_ifs_nemo_historical,
    dataset2=data_era5,
    var_name='avg_tos',
    plev=None,
    model_label1='IFS-NEMO historical',
    model_label2='ERA5',
    start_date1 ='1990-01-01',
    end_date1 ='2001-12-31',
    start_date2 ='1980-01-01',
    end_date2 ='2010-12-31',
    vmin=-4,
    vmax=4,
    nlevels=9,
    seasons=False
    )

# %% [markdown]
# ### Zonal bias plots

# %%
compare_datasets_plev(
    dataset1=data_ifs_nemo_historical,
    dataset2=data_era5,
    var_name='u',
    model_label1='IFS-NEMO historical',
    model_label2='ERA5',
    start_date1 ='1990-01-01',
    end_date1 ='2000-12-31',
    start_date2 ='1980-01-01',
    end_date2 ='2010-12-31',
    plev_min = 1000,
    plev_max = 100000,
    vmin = -9,
    vmax = 9
    )
