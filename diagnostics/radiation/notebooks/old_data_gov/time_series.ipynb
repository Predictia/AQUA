# %% [markdown]
# # Time series of radiation biases from different models
# Now we want to use the function that produces us time series of the model data including the individual CERES years to show us the variability

# %%
import sys
sys.path.insert(0,'../../')
from radiation import process_ceres_data, process_model_data
from radiation import plot_model_comparison_timeseries

# %%
lumi=True

# %% [markdown]
# ### Loading the data we need for the analysis
# First we retrieve and process (-> creating fldmeans) some data from the CERES and model output catalogues using the respective functions

# %%
if lumi:
    #ifs_4km = process_model_data(model =  'IFS' , exp = 'historical-1990-devcon' , source = 'lra-r100-monthly')
    ifs_nemo_historical_dev = process_model_data(model =  'IFS-NEMO' , exp = 'historical-1990-dev' , source = 'lra-r100-monthly')
else:
    ifs_4km = process_model_data(model =  'IFS' , exp = 'tco2559-ng5-cycle3' , source = 'lra-r100-monthly')
    ifs_control = process_model_data(model =  'IFS' , exp = 'control-1950-devcon' , source = 'lra-r100-monthly')
    ifs_9km = process_model_data(model =  'IFS' , exp = 'tco1279-orca025-cycle3' , source = 'lra-r100-monthly')
ceres = process_ceres_data(exp = "ebaf-toa41", source = "monthly")
# Out:
# /opt/conda/lib/python3.11/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /opt/conda/lib/python3.11/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /opt/conda/lib/python3.11/site-packages/xarray/core/indexing.py:1446: PerformanceWarning: Slicing with an out-of-order index is generating 21 times more chunks
#   return self.array[key]

# %%
if lumi:
    models = [ifs_nemo_historical_dev]
    plot_model_comparison_timeseries(models,ceres=ceres)
# Out:
# /users/susayed/AQUA/diagnostics/radiation/notebooks/../../radiation/radiation_functions.py:195: DeprecationWarning: invalid escape sequence '\c'
#   ax.set_xlabel("2m temperature [$^{\circ} C$]", fontsize=fontsize-2)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 if lumi:
#       2     models = [ifs_nemo_historical_dev]
# ----> 3     plot_model_comparison_timeseries(models,ceres=ceres)
#
# File ~/AQUA/diagnostics/radiation/notebooks/../../radiation/radiation_functions.py:382, in plot_model_comparison_timeseries(models, linelabels, ceres, outputdir, outputfig, ylim)
#     380 # Iterate through the years
#     381 for year in years:
# --> 382     ttr_diff.append(model["gm"].mtntrf.sel(time=str(year))- ceres['clim_gm'].mtntrf.values)
#     383     tsr_diff.append(model["gm"].mtnsrf.sel(time=str(year))- ceres['clim_gm'].mtnsrf.values)
#     384     tnr_diff.append(model["gm"].tnr.sel(time=str(year)) - ceres['clim_gm'].tnr.values)
#
# File /opt/conda/lib/python3.11/site-packages/xarray/core/common.py:280, in AttrAccessMixin.__getattr__(self, name)
#     278         with suppress(KeyError):
#     279             return source[name]
# --> 280 raise AttributeError(
#     281     f"{type(self).__name__!r} object has no attribute {name!r}"
#     282 )
#
# AttributeError: 'Dataset' object has no attribute 'mtntrf'

# %%
if lumi:
    models = [ifs_nemo_historical_dev]
    plot_model_comparison_timeseries(models, ceres=ceres)
else:
    models = [ifs_4km, ifs_9km]
    plot_model_comparison_timeseries(models, ceres=ceres)

# %%
if lumi:
    models = [era5]
    plot_model_comparison_timeseries(models, ceres=ceres)
else:
    models = [ifs_control]
    plot_model_comparison_timeseries(models, ceres=ceres)
