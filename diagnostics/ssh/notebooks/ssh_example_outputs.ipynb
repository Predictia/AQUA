# %% [markdown]
# # Example notebok for SSH Variability application
#
# This notebook demonstrates how the SSH variability application works when the script is run. We first start by loading some of the modules, going up two levels so that we can import the `ssh`` module

# %%
import sys
sys.path.insert(0, '../../')
from ssh import sshVariability

# %%
# %%time
analyzer = sshVariability('../config.yml')
analyzer.run()
# Out:
# 2023-07-11 10:51:46 :: ssh_logger :: WARNING  -> Time ranges are not equal across models.
# /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 34313 instead
#   warnings.warn(
# /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/site-packages/dask/array/numpy_compat.py:43: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# 2023-07-11 10:51:52 :: ssh_logger :: INFO     -> Dask Dashboard URL: http://127.0.0.1:34313/status
# 2023-07-11 10:51:52 :: ssh_logger :: INFO     -> Workers=16, Memory=503.44 GiB
# 2023-07-11 10:51:52 :: Reader :: WARNING  -> No fixes available for model AVISO
# 2023-07-11 10:51:52 :: ssh_logger :: INFO     -> AVISO data spans from 1993-01-01T00:00:00.000000000 to 2022-06-23T00:00:00.000000000
# 2023-07-11 10:51:52 :: ssh_logger :: INFO     -> Now computing std on AVISO ssh for the provided timespan
# 2023-07-11 10:51:53 :: ssh_logger :: INFO     -> computation for AVISO ssh complete, saving output file
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/work/bb1153/b382076/AQUA/diagnostics/ssh/output/AVISO_std_dev.nc',), 'a', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '8ff26cde-439a-4134-841e-e54b7c656638']
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/AQUA/diagnostics/ssh/notebooks/../../ssh/ssh_class.py:212, in sshVariability.run(self)
#     210 # saving the computation in output files
#     211 logger.info("computation for AVISO ssh complete, saving output file")
# --> 212 self.save_standard_deviation_to_file(config['output_directory'], "AVISO", aviso_ssh_std)
#     214 ssh_data_dict = {}
#     215 # ssh_data_dict[config['base_model']['name']] = aviso_ssh_std
#
# File ~/AQUA/diagnostics/ssh/notebooks/../../ssh/ssh_class.py:67, in sshVariability.save_standard_deviation_to_file(output_directory, model_name, std_dev_data)
#      58 """
#      59 Save the standard deviation data to a NetCDF file.
#      60
#    (...)
#      64     std_dev_data (xarray.DataArray): Computed standard deviation data.
#      65 """
#      66 output_file = os.path.join(output_directory, f"{model_name}_std_dev.nc")
# ---> 67 std_dev_data.to_netcdf(output_file)
#
# File /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/site-packages/xarray/core/dataarray.py:3978, in DataArray.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    3974 else:
#    3975     # No problems with the name - so we're fine!
#    3976     dataset = self.to_dataset()
# -> 3978 return to_netcdf(  # type: ignore  # mypy cannot resolve the overloads:(
#    3979     dataset,
#    3980     path,
#    3981     mode=mode,
#    3982     format=format,
#    3983     group=group,
#    3984     engine=engine,
#    3985     encoding=encoding,
#    3986     unlimited_dims=unlimited_dims,
#    3987     compute=compute,
#    3988     multifile=False,
#    3989     invalid_netcdf=invalid_netcdf,
#    3990 )
#
# File /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/site-packages/xarray/backends/api.py:1255, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1251     else:
#    1252         raise ValueError(
#    1253             f"unrecognized option 'invalid_netcdf' for engine {engine}"
#    1254         )
# -> 1255 store = store_open(target, mode, format, group, **kwargs)
#    1257 if unlimited_dims is None:
#    1258     unlimited_dims = dataset.encoding.get("unlimited_dims", None)
#
# File /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:391, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     385 kwargs = dict(
#     386     clobber=clobber, diskless=diskless, persist=persist, format=format
#     387 )
#     388 manager = CachingFileManager(
#     389     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     390 )
# --> 391 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:338, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     336 self._group = group
#     337 self._mode = mode
# --> 338 self.format = self.ds.data_model
#     339 self._filename = self.ds.filepath()
#     340 self.is_remote = is_remote_uri(self._filename)
#
# File /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:400, in NetCDF4DataStore.ds(self)
#     398 @property
#     399 def ds(self):
# --> 400     return self._acquire()
#
# File /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:394, in NetCDF4DataStore._acquire(self, needs_lock)
#     393 def _acquire(self, needs_lock=True):
# --> 394     with self._manager.acquire_context(needs_lock) as root:
#     395         ds = _nc4_require_group(root, self._group, self._mode)
#     396     return ds
#
# File /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2464, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2027, in netCDF4._netCDF4._ensure_nc_success()
#
# PermissionError: [Errno 13] Permission denied: '/work/bb1153/b382076/AQUA/diagnostics/ssh/output/AVISO_std_dev.nc'
# /work/bb1153/b382076/mambaforge/envs/aqua/lib/python3.11/site-packages/dask/array/numpy_compat.py:43: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)

# %% [markdown]
# Double-Checking the output files.

# %%
import xarray as xr

# %% [markdown]
# Checking the output files, if they have the data that is required.

# %%
# Specify the path to the NetCDF file output
file_path = '../output/AVISO_std_dev.nc'

# Open the NetCDF file using xarray
data = xr.open_dataset(file_path)
data
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 720, longitude: 1440)
# Coordinates:
#   * latitude   (latitude) float32 -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
#   * longitude  (longitude) float32 -179.9 -179.6 -179.4 ... 179.4 179.6 179.9
# Data variables:
#     adt        (latitude, longitude) float64 ...

# %%
# Specify the path to the NetCDF file output
file_path = '../output/FESOM_std_dev.nc'

# Open the NetCDF file using xarray
data = xr.open_dataset(file_path)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (nod2: 7402886)
# Dimensions without coordinates: nod2
# Data variables:
#     ssh      (nod2) float32 ...

# %%
# Specify the path to the NetCDF file output
file_path = '../output/ICON_std_dev.nc'

# Open the NetCDF file using xarray
data = xr.open_dataset(file_path)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (cell: 196608)
# Dimensions without coordinates: cell
# Data variables:
#     zos      (cell) float32 ...
