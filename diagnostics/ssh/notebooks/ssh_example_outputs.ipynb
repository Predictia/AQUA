# %% [markdown]
# # Example notebook for SSH Variability application
#
# This notebook demonstrates how the SSH variability application works when the script is run. We first start by loading some of the modules, going up two levels so that we can import the `ssh` module

# %%
import sys
sys.path.insert(0, '../../')
from ssh import sshVariability

# %% [markdown]
# Please make sure that your config file is updated with the path to the output folder where the outputs of this notebook should be saved. In this code, if the output_directory key is not found in the config file, the output_directory variable will be set to a directory named 'output' in the current working directory (os.getcwd()).

# %% [markdown]
# The following cell executes the 'ssh_class.py' script with sshVariability class. The script performs the following:
#
# 1. Reads and parses the configuration file (`config.yml`) to retrieve the necessary parameters and settings for the script's execution. Please make sure that the config file is updated with the information you would like to analyze.
#
# 2. Within the `sshVariability` class, defines methods to retrieve, process, and analyze the SSH data for each model starting with AVISO observational data.
#
# 3. Saved the std computation under outputs along with visualization based on the target grid defined in the config file. AQUA regridder capability is used to regrid the data and visualize the results in subplots.

# %%
# %%time
analyzer = sshVariability('../config.yml')
analyzer.run()
# runtime is around 7-8 min depending on how much data you wish to analyse.
# Out:
# 2023-11-24 14:17:42 :: ssh_logger :: WARNING  -> Time ranges are not equal across models.
# /home/a/a270238/conda/envs/aqua_common/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45015 instead
#   warnings.warn(
# 2023-11-24 14:17:44 :: ssh_logger :: INFO     -> Dask Dashboard URL: http://127.0.0.1:45015/status
# 2023-11-24 14:17:44 :: ssh_logger :: INFO     -> Workers=16, Memory=100.00 GiB
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /work/ab0995/a270238/work/AQUA/diagnostics/ssh/notebooks/../../ssh/ssh_class.py:229, in sshVariability.run(self)
#     228 try:
# --> 229     reader = Reader(model=config['base_model']['name'], exp=config['base_model']
#     230                 ['experiment'], source=config['base_model']['source'], fix=True)
#     231 except:
#
# File /work/ab0995/a270238/work_destinE/AQUA/aqua/reader/reader.py:135, in Reader.__init__(self, model, exp, source, freq, fix, regrid, method, zoom, configdir, areas, datamodel, streaming, stream_step, stream_unit, stream_startdate, rebuild, loglevel, nproc, aggregation, verbose, exclude_incomplete, buffer)
#     133 # get configuration from the machine
#     134 self.catalog_file, self.regrid_file, self.fixer_folder, self.config_file = (
# --> 135     Configurer.get_reader_filenames())
#     136 self.cat = intake.open_catalog(self.catalog_file)
#
# File /work/ab0995/a270238/work_destinE/AQUA/aqua/util/config.py:92, in ConfigPath.get_reader_filenames(self)
#      91     raise FileNotFoundError(f'Cannot find catalog file in {catalog_file}')
# ---> 92 regrid_file = base['reader']['regrid'].format(machine=self.machine,
#      93                                               configdir=self.configdir)
#      94 if not os.path.exists(regrid_file):
#
# File ~/conda/envs/aqua_common/lib/python3.11/site-packages/ruamel/yaml/comments.py:842, in CommentedMap.__getitem__(self, key)
#     841 try:
# --> 842     return ordereddict.__getitem__(self, key)
#     843 except KeyError:
#
# KeyError: 'regrid'
#
# During handling of the above exception, another exception occurred:
#
# NoObservationError                        Traceback (most recent call last)
# File <timed exec>:2
#
# File /work/ab0995/a270238/work/AQUA/diagnostics/ssh/notebooks/../../ssh/ssh_class.py:232, in sshVariability.run(self)
#     229     reader = Reader(model=config['base_model']['name'], exp=config['base_model']
#     230                 ['experiment'], source=config['base_model']['source'], fix=True)
#     231 except:
# --> 232     raise NoObservationError("AVISO data not found.")
#     234 aviso_cat = reader.retrieve()
#     236 aviso_time_min = np.datetime64(aviso_cat.time.min().values)
#
# NoObservationError: AVISO data not found.

# %% [markdown]
# Double-Checking the output files. The cells below are just checking if the output files contain the right data.

# %% [markdown]
# The subfolders "NetCDF" and "PDF" are automatically created under your defined "Output" folder. This is where individual outputs will get saved. Note: NetCDF files that get saved are ungridded as they get saved before AQUA regridder is used.

# %%
import xarray as xr

# %%
# Specify the path to the NetCDF file output
file_path = '../output/NetCDF/AVISO_ssh-L4_daily_std.nc'

# Open the NetCDF file using xarray
data = xr.open_dataset(file_path)
data
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 720, longitude: 1440)
# Coordinates:
#   * latitude   (latitude) float32 -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
#   * longitude  (longitude) float32 -179.9 -179.6 -179.4 ... 179.4 179.6 179.9
# Data variables:
#     adt        (latitude, longitude) float64 ...
