# %% [markdown]
# # Example notebok for SSH Variability application
#
# This notebook demonstrates how the SSH variability application works when the script is run.

# %%
import sys
# temporary hack to access the diagnostic.
sys.path.insert(0, '../')
from ssh_class import sshVariability
# from ssh import sshVariability

# %%
# %%time
analyzer = sshVariability('../config.yml')
analyzer.run()
# Out:
# 2023-07-06 12:05:16 :: ssh_logger :: WARNING  -> Time ranges are not equal across models.
# 2023-07-06 12:05:19 :: ssh_logger :: INFO     -> Dask Dashboard URL: http://127.0.0.1:8787/status
# 2023-07-06 12:05:19 :: ssh_logger :: INFO     -> Workers=16, Memory=235.37 GiB
# 2023-07-06 12:05:20 :: Reader :: WARNING  -> No fixes available for model AVISO
# 2023-07-06 12:05:20 :: ssh_logger :: INFO     -> AVISO data spans from 1993-01-01T00:00:00.000000000 to 2022-06-23T00:00:00.000000000
# 2023-07-06 12:05:20 :: ssh_logger :: INFO     -> Now computing std on AVISO ssh for the provided timespan
# 2023-07-06 12:05:20 :: ssh_logger :: INFO     -> computation for AVISO ssh complete, saving output file
# /home/a/a270223/mambaforge/envs/aqua/lib/python3.10/site-packages/dask/array/numpy_compat.py:43: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# 2023-07-06 12:05:56 :: ssh_logger :: INFO     -> Now loading data for other models to compare against AVISO ssh variability
# 2023-07-06 12:05:56 :: ssh_logger :: INFO     -> initializing AQUA reader to read the model inputs for {'name': 'ICON', 'experiment': 'ngc3028', 'source': 'P1D', 'regrid': 'r025', 'variable': 'zos', 'zoom': 7, 'timespan': ['2020-01-20', '2025-07-22']}
# 2023-07-06 12:06:07 :: ssh_logger :: INFO     -> ICON data spans from 2020-01-21T00:00:00.000000000 to 2025-07-22T00:00:00.000000000
# 2023-07-06 12:06:07 :: ssh_logger :: INFO     -> Getting SSH data complete for ICON, now computing standard deviation on the default timestamp
# 2023-07-06 12:06:07 :: ssh_logger :: INFO     -> computation complete, saving output file
# /home/a/a270223/mambaforge/envs/aqua/lib/python3.10/site-packages/dask/array/numpy_compat.py:43: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# 2023-07-06 12:06:14 :: ssh_logger :: INFO     -> output saved, now regridding using the aqua regridder
# 2023-07-06 12:06:15 :: ssh_logger :: INFO     -> initializing AQUA reader to read the model inputs for {'name': 'FESOM', 'experiment': 'tco2559-ng5-cycle3', 'source': '2D_daily_native', 'regrid': 'r025', 'variable': 'zos', 'zoom': None, 'timespan': ['2020-01-20', '2024-12-31']}
# 2023-07-06 12:06:24 :: Reader :: WARNING  -> Weights file not found: /work/bb1153/b382075/nextgems/weights/weights_FESOM_tco2559-ng5-cycle3_2D_daily_native_ycon_r025_l2d.nc
# 2023-07-06 12:06:24 :: Reader :: WARNING  -> Attempting to generate it ...
# WARNING:root:vert_coord is None
# /home/a/a270223/mambaforge/envs/aqua/lib/python3.10/site-packages/distributed/client.py:3109: UserWarning: Sending large graph of size 45.58 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /home/a/a270223/mambaforge/envs/aqua/lib/python3.10/site-packages/distributed/client.py:3109: UserWarning: Sending large graph of size 45.58 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# 2023-07-06 12:09:25 :: Reader :: WARNING  -> Success!
# 2023-07-06 12:09:34 :: ssh_logger :: INFO     -> FESOM data spans from 2020-01-20T23:56:00.000000000 to 2024-12-31T23:56:00.000000000
# 2023-07-06 12:09:34 :: ssh_logger :: INFO     -> Getting SSH data complete for FESOM, now computing standard deviation on the default timestamp
# 2023-07-06 12:09:35 :: ssh_logger :: INFO     -> computation complete, saving output file
# 2023-07-06 12:11:26 :: ssh_logger :: INFO     -> output saved, now regridding using the aqua regridder
# 2023-07-06 12:11:26 :: ssh_logger :: INFO     -> visualizing the data in subplots
# 2023-07-06 12:11:35 :: ssh_logger :: INFO     -> Saving plots as a PDF output file
# CPU times: user 4min 20s, sys: 27.5 s, total: 4min 47s
# Wall time: 9min 41s

# %% [markdown]
# Double-Checking the output files.

# %%
import xarray as xr

# %% [markdown]
# Checking the output files, if they have the data that is required.

# %%
# Specify the path to the NetCDF file output
file_path = '../output/AVISO_std_dev.nc'

# Open the NetCDF file using xarray
data = xr.open_dataset(file_path)
data
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 720, longitude: 1440)
# Coordinates:
#   * latitude   (latitude) float32 -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
#   * longitude  (longitude) float32 -179.9 -179.6 -179.4 ... 179.4 179.6 179.9
# Data variables:
#     adt        (latitude, longitude) float64 ...

# %%
# Specify the path to the NetCDF file output
file_path = '../output/FESOM_std_dev.nc'

# Open the NetCDF file using xarray
data = xr.open_dataset(file_path)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (nod2: 7402886)
# Dimensions without coordinates: nod2
# Data variables:
#     ssh      (nod2) float32 ...

# %%
# Specify the path to the NetCDF file output
file_path = '../output/ICON_std_dev.nc'

# Open the NetCDF file using xarray
data = xr.open_dataset(file_path)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (cell: 196608)
# Dimensions without coordinates: cell
# Data variables:
#     zos      (cell) float32 ...
