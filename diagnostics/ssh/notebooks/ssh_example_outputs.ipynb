# %% [markdown]
# # Example notebook for SSH Variability application
#
# This notebook demonstrates how the SSH variability application works when the script is run. We first start by loading some of the modules, going up two levels so that we can import the `ssh` module

# %%
import sys
sys.path.insert(0, '../../')
from ssh import sshVariability

# %% [markdown]
# Please make sure that your config file is updated with the path to the output folder where the outputs of this notebook should be saved. In this code, if the output_directory key is not found in the config file, the output_directory variable will be set to a directory named 'output' in the current working directory (os.getcwd()).

# %% [markdown]
# The following cell executes the 'ssh_class.py' script with sshVariability class. The script performs the following:
#
# 1. Reads and parses the configuration file (`config.yml`) to retrieve the necessary parameters and settings for the script's execution. Please make sure that the config file is updated with the information you would like to analyze.
#
# 2. Within the `sshVariability` class, defines methods to retrieve, process, and analyze the SSH data for each model starting with AVISO observational data.
#
# 3. Saved the std computation under outputs along with visualization based on the target grid defined in the config file. AQUA regridder capability is used to regrid the data and visualize the results in subplots.

# %%
# %%time
analyzer = sshVariability('../config.yml')
analyzer.run()
# runtime is around 7-8 min depending on how much data you wish to analyse.
# Out:
# 2023-07-11 14:47:08 :: ssh_logger :: WARNING  -> Time ranges are not equal across models.
# 2023-07-11 14:47:11 :: ssh_logger :: INFO     -> Dask Dashboard URL: http://127.0.0.1:8787/status
# 2023-07-11 14:47:11 :: ssh_logger :: INFO     -> Workers=16, Memory=235.37 GiB
# 2023-07-11 14:47:11 :: Reader :: WARNING  -> No fixes available for model AVISO
# 2023-07-11 14:47:14 :: ssh_logger :: INFO     -> AVISO data spans from 1993-01-01T00:00:00.000000000 to 2022-06-23T00:00:00.000000000
# 2023-07-11 14:47:14 :: ssh_logger :: INFO     -> Now computing std on AVISO ssh for the provided timespan
# 2023-07-11 14:47:14 :: ssh_logger :: INFO     -> computation for AVISO ssh complete, saving output file
# /home/a/a270223/mambaforge/envs/aqua/lib/python3.10/site-packages/dask/array/numpy_compat.py:43: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# 2023-07-11 14:47:47 :: ssh_logger :: INFO     -> Now loading data for other models to compare against AVISO ssh variability
# 2023-07-11 14:47:47 :: ssh_logger :: INFO     -> initializing AQUA reader to read the model inputs for {'name': 'ICON', 'experiment': 'ngc3028', 'source': 'P1D', 'regrid': 'r025', 'variable': 'zos', 'zoom': 7, 'timespan': ['2020-01-20', '2025-07-22']}
# 2023-07-11 14:47:59 :: ssh_logger :: INFO     -> ICON data spans from 2020-01-21T00:00:00.000000000 to 2025-07-22T00:00:00.000000000
# 2023-07-11 14:47:59 :: ssh_logger :: INFO     -> Getting SSH data complete for ICON, now computing standard deviation on the default timestamp
# 2023-07-11 14:47:59 :: ssh_logger :: INFO     -> computation complete, saving output file
# /home/a/a270223/mambaforge/envs/aqua/lib/python3.10/site-packages/dask/array/numpy_compat.py:43: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# 2023-07-11 14:48:06 :: ssh_logger :: INFO     -> output saved, now regridding using the aqua regridder
# 2023-07-11 14:48:06 :: ssh_logger :: INFO     -> initializing AQUA reader to read the model inputs for {'name': 'FESOM', 'experiment': 'tco2559-ng5-cycle3', 'source': '2D_daily_native', 'regrid': 'r025', 'variable': 'zos', 'zoom': None, 'timespan': ['2020-01-20', '2024-12-31']}
# 2023-07-11 14:49:04 :: ssh_logger :: INFO     -> FESOM data spans from 2020-01-20T23:56:00.000000000 to 2024-12-31T23:56:00.000000000
# 2023-07-11 14:49:04 :: ssh_logger :: INFO     -> Getting SSH data complete for FESOM, now computing standard deviation on the default timestamp
# 2023-07-11 14:49:05 :: ssh_logger :: INFO     -> computation complete, saving output file
# 2023-07-11 14:51:00 :: ssh_logger :: INFO     -> output saved, now regridding using the aqua regridder
# 2023-07-11 14:51:00 :: ssh_logger :: INFO     -> visualizing the data in subplots
# 2023-07-11 14:51:09 :: ssh_logger :: INFO     -> Saving plots as a PDF output file
# CPU times: user 4min 4s, sys: 21.4 s, total: 4min 25s
# Wall time: 7min 19s

# %% [markdown]
# Double-Checking the output files. The cells below are just checking if the output files contain the right data.

# %% [markdown]
# The subfolders "NetCDF" and "PDF" are automatically created under your defined "Output" folder. This is where individual outputs will get saved. Note: NetCDF files that get saved are ungridded as they get saved before AQUA regridder is used.

# %%
import xarray as xr

# %%
# Specify the path to the NetCDF file output
file_path = '../output/NetCDF/AVISO_ssh-L4_daily_std.nc'

# Open the NetCDF file using xarray
data = xr.open_dataset(file_path)
data
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 720, longitude: 1440)
# Coordinates:
#   * latitude   (latitude) float32 -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
#   * longitude  (longitude) float32 -179.9 -179.6 -179.4 ... 179.4 179.6 179.9
# Data variables:
#     adt        (latitude, longitude) float64 ...
