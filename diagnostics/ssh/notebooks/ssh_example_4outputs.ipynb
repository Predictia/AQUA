# %% [markdown]
# # Example notebok for SSH Variability application
#
# This notebook demonstrates how the SSH variability application works when the script is run.

# %%
import os

# Specify the path to your desired working directory
working_directory = '/work/ab0995/a270223/AQUA/diagnostics/SSH/'

# Change the working directory
os.chdir(working_directory)

# %%
import sys
# temporary hack if your env-dummy.yml
# does not install your diagnostic.
sys.path.insert(0, '../')
from ssh_class import sshVariability
# Out:
# FDB5 binary library not present on system, disabling FDB support.

# %%
analyzer = sshVariability('../config.yml')
analyzer.run()
# Out:
# 2023-06-28 16:03:37 :: ssh_logger :: WARNING  -> Time ranges are not equal across models.
# 2023-06-28 16:03:39 :: ssh_logger :: INFO     -> Dask Dashboard URL: http://127.0.0.1:8787/status
# 2023-06-28 16:03:39 :: ssh_logger :: INFO     -> Workers=16, Memory=235.37 GiB
# 2023-06-28 16:03:40 :: Reader :: WARNING  -> No fixes available for model AVISO
# 2023-06-28 16:03:42 :: ssh_logger :: INFO     -> AVISO data spans from 1993-01-01T00:00:00.000000000 to 2022-06-23T00:00:00.000000000
# 2023-06-28 16:03:42 :: ssh_logger :: INFO     -> Now computing std on AVISO ssh for the provided timespan
# 2023-06-28 16:03:42 :: ssh_logger :: INFO     -> computation for AVISO ssh complete, saving output file
# /home/a/a270223/mambaforge/envs/aqua/lib/python3.10/site-packages/dask/array/numpy_compat.py:43: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# 2023-06-28 16:04:10 :: ssh_logger :: INFO     -> Now loading data for other models to compare against AVISO ssh variability
# 2023-06-28 16:04:10 :: ssh_logger :: INFO     -> initializing AQUA reader to read the model inputs for {'name': 'ICON', 'experiment': 'ngc3028', 'source': 'P1D', 'regrid': 'r100', 'variable': 'zos', 'zoom': 7, 'timespan': ['2020-01-20', '2024-12-31']}
# 2023-06-28 16:04:21 :: ssh_logger :: INFO     -> ICON data spans from 2020-01-21T00:00:00.000000000 to 2025-07-22T00:00:00.000000000
# 2023-06-28 16:04:21 :: ssh_logger :: INFO     -> Getting SSH data complete for ICON, now computing standard deviation on the default timestamp
# 2023-06-28 16:04:21 :: ssh_logger :: INFO     -> computation complete, saving output file
# /home/a/a270223/mambaforge/envs/aqua/lib/python3.10/site-packages/dask/array/numpy_compat.py:43: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# 2023-06-28 16:04:29 :: ssh_logger :: INFO     -> output saved, now regridding using the aqua regridder
# 2023-06-28 16:04:29 :: ssh_logger :: INFO     -> initializing AQUA reader to read the model inputs for {'name': 'ICON', 'experiment': 'ngc3026', 'source': 'P1D', 'regrid': 'r100', 'variable': 'zos', 'zoom': 7, 'timespan': ['2020-01-20', '2021-01-24']}
# 2023-06-28 16:04:39 :: ssh_logger :: INFO     -> ICON data spans from 2020-01-21T00:00:00.000000000 to 2021-01-24T00:00:00.000000000
# 2023-06-28 16:04:39 :: ssh_logger :: INFO     -> Getting SSH data complete for ICON, now computing standard deviation on the default timestamp
# 2023-06-28 16:04:39 :: ssh_logger :: INFO     -> computation complete, saving output file
# /home/a/a270223/mambaforge/envs/aqua/lib/python3.10/site-packages/dask/array/numpy_compat.py:43: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# 2023-06-28 16:04:40 :: ssh_logger :: INFO     -> output saved, now regridding using the aqua regridder
# 2023-06-28 16:04:41 :: ssh_logger :: INFO     -> initializing AQUA reader to read the model inputs for {'name': 'FESOM', 'experiment': 'tco2559-ng5-cycle3', 'source': '2D_daily_native', 'regrid': 'r100', 'variable': 'zos', 'zoom': None, 'timespan': ['2020-01-20', '2024-12-31']}
# 2023-06-28 16:05:29 :: ssh_logger :: INFO     -> FESOM data spans from 2020-01-20T23:56:00.000000000 to 2024-12-31T23:56:00.000000000
# 2023-06-28 16:05:29 :: ssh_logger :: INFO     -> Getting SSH data complete for FESOM, now computing standard deviation on the default timestamp
# 2023-06-28 16:05:29 :: ssh_logger :: INFO     -> computation complete, saving output file
# 2023-06-28 16:07:21 :: ssh_logger :: INFO     -> output saved, now regridding using the aqua regridder
# 2023-06-28 16:07:22 :: ssh_logger :: INFO     -> visualizing the data in subplots
# 2023-06-28 16:07:26 :: ssh_logger :: INFO     -> Saving plots as a PDF output file

# %% [markdown]
# Double-Checking the output files.

# %%
import xarray as xr

# %% [markdown]
# Checking the output files, if they have the data that is required.

# %%
# Specify the path to the NetCDF file output
file_path = '../output/AVISO_std_dev.nc'

# Open the NetCDF file using xarray
data = xr.open_dataset(file_path)
data
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 720, longitude: 1440)
# Coordinates:
#   * latitude   (latitude) float32 -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
#   * longitude  (longitude) float32 -179.9 -179.6 -179.4 ... 179.4 179.6 179.9
# Data variables:
#     adt        (latitude, longitude) float64 ...

# %%
# Specify the path to the NetCDF file output
file_path = '../output/FESOM_std_dev.nc'

# Open the NetCDF file using xarray
data = xr.open_dataset(file_path)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (nod2: 7402886)
# Dimensions without coordinates: nod2
# Data variables:
#     ssh      (nod2) float32 ...

# %%
# Specify the path to the NetCDF file output
file_path = '../output/ICON_std_dev.nc'

# Open the NetCDF file using xarray
data = xr.open_dataset(file_path)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (cell: 196608)
# Dimensions without coordinates: cell
# Data variables:
#     zos      (cell) float32 ...
