# %%
import os
import glob
import netCDF4 as nc
import numpy as np
from datetime import datetime
import xarray as xr

from aqua.util import load_yaml
#from plotting_hist import plot_hist_cat, plot_press_wind

# %% [markdown]
# Get variables and other parameters from configuration file and store them in a dictionary

# %%
# load the config file
tdict = load_yaml('../cli/config_tcs.yaml')
tdict
# Out:
# {'dataset': {'model': 'IFS', 'exp': 'tco1279-orca025-cycle3', 'source2d': '2D_1h_native', 'source3d': '3D_1h_native'}, 'paths': {'tmpdir': '/home/b/b382216/work/tc/tmpdir', 'fulldir': '/home/b/b382216/work/tc/fullres', 'plotdir': '/home/b/b382216/work/tc/Figures/'}, 'setup': {'loglevel': 'WARNING'}, 'grids': {'lowgrid': 'r100', 'highgrid': 'r010'}, 'varlist': ['msl', '10u', '10v', 'tprate'], 'time': {'startdate': '2020-01-20', 'enddate': '2020-02-20', 'frequency': '6h'}, 'stream': {'streamstep': 10}, 'detect': {'boxdim': 10}, 'stitch': {'n_days_freq': 30, 'n_days_ext': 2}}

# %%
# Directory where the NetCDF files are located
fullres_data_directory = '/home/b/b382216/work/tc/fullres/IFS/tco2559-ng5-cycle3/'

# Directory with tempest (Stitch nodes) output track files
tempest_data_directory = '/home/b/b382216/work/tc/tmpdir/IFS/tco2559-ng5-cycle3/'

# Pattern to match NetCDF files
fullres_file_pattern = 'tempest_tracks_*.nc'

# Pattern to match tempest txt files
tempest_file_pattern = 'tempest_track_*.txt'

# Output directory for the new .txt files with fullres data
output_directory = '/home/b/b382216/work/tc/fullres/IFS/tco2559-ng5-cycle3/tempest_fullres_txt'


# Find and process all matching files
fullres_file_paths = sorted(glob.glob(os.path.join(fullres_data_directory, fullres_file_pattern)))
tempest_file_paths = sorted(glob.glob(os.path.join(tempest_data_directory, tempest_file_pattern)))

# List to store data arrays
data_arrays = []

# Initialize a list to store track headers
track_headers = []

# Define a function to parse the text data and separate tracks
def parse_text_file(file_path):
    data = []  # Create an empty list to store the data
    track_data = []  # List to store data for the current track
    track_header = None

    with open(file_path, 'r') as file:
        for line in file:
            parts = line.split()
            if not parts:
                continue  # Skip empty lines

            if parts[0] == 'start':
                if track_header is not None:
                    data.append((track_header, track_data))  # Add track header and data to the result
                track_header = {
                    'track_length': int(parts[1]),
                    'year': int(parts[2]),
                    'month': int(parts[3]),
                    'date': int(parts[4]),
                    'hour': int(parts[5])
                }
                track_data = []
            else:
                if track_header is not None:
                    entry = {
                        'lon_index': int(parts[0]),
                        'lat_index': int(parts[1]),
                        'longitude': float(parts[2]),
                        'latitude': float(parts[3]),
                        'year': int(parts[6]),
                        'month': int(parts[7]),
                        'date': int(parts[8]),
                        'hour': int(parts[9]),
                        'mslp': float(parts[4]),  # Assuming MSLP is in the 4th position
                        'wind_module': float(parts[5])  # Assuming wind module is in the 5th position
                    }
                    track_data.append(entry)

    if track_data:  # Add the last track header and data if not empty
        data.append((track_header, track_data))

    return data

# Loop through the NetCDF files and the corresponding text files
for fullres_file_path, tempest_file_path in zip(fullres_file_paths, tempest_file_paths):
    # Open the NetCDF file
    dataset = xr.open_dataset(fullres_file_path)
    mslp = dataset['msl']
    u10 = dataset['10u']
    v10 = dataset['10v']
    time_nc = dataset['time']
    print("Opened tempest file:", tempest_file_path)
    print("Opened NetCDF file:", fullres_file_path)

    #compute wind module
    wind_mod= (u10**2+v10**2)**0.5
    # Parse the corresponding text file
    parsed_results = parse_text_file(tempest_file_path)
    updated_lines = []
    # Loop through parsed results and print variables at each time step
    for i, (track_header, result) in enumerate(parsed_results):
        print(f"Track {i + 1}:")

        # Print the track header information
        print(f"Track Length: {track_header['track_length']}, Year: {track_header['year']}, Month: {track_header['month']}, Date: {track_header['date']}, Hour: {track_header['hour']}")

        # Write the track header information to the new .txt file
        header_line = f"start {track_header['track_length']} {track_header['year']} {track_header['month']} {track_header['date']} {track_header['hour']}\n"
        updated_lines.append(header_line)

        for entry in result:
            lon = entry['longitude']
            lat = entry['latitude']
            year = entry['year']
            month = entry['month']
            date = entry['date']
            hour = entry['hour']
            mslp_tempest = entry['mslp']
            wind_mod_tempest = entry['wind_module']

            # create a time stamp with the date in the tempest file/dict

            time_stamp = datetime(year, month, date, hour, 0, 0)
            # open the netcdf file at 
            mslp_time = mslp.sel(time=time_stamp, method="nearest")
            mslp_value = np.min(mslp_time.sel(lat=slice(lat-2,lat+2), lon=slice(lon-2,lon+2)).values)
            wind_mod_time = wind_mod.sel(time=time_stamp, method="nearest")
            wind_mod_value = np.max(wind_mod_time.sel(lat=slice(lat-2,lat+2), lon=slice(lon-2,lon+2)).values)


            print(f"Time tempest dict: {time_stamp}, lat tempest {lat}, lon tempest {lon},  MSLP tempest: {mslp_tempest}, wind_mod tempest: {wind_mod_tempest}")
            print(f"Time netcdf: {time_nc.sel(time=time_stamp, method='nearest').values}, MSLP netcdf: {mslp_value}, wind_mod netcdf: {wind_mod_value}\n")

            entry['mslp'] = mslp_value
            entry['wind_module'] = wind_mod_value

            entry_line = f"{entry['lon_index']} {entry['lat_index']} {entry['longitude']} {entry['latitude']} {entry['mslp']} {entry['wind_module']} {entry['year']} {entry['month']} {entry['date']} {entry['hour']}\n"
            updated_lines.append(entry_line)

    filename = os.path.basename(tempest_file_path)
    new_filename = f"fullres_{filename}"  # Add "fullres_" as a prefix to the original filename
    new_file_path = os.path.join(output_directory, new_filename)
    with open(new_file_path, 'w') as new_file:
        new_file.writelines(updated_lines)
    print(f"Created {new_file_path}")
        

    dataset.close()
# Out:
# Opened tempest file: /home/b/b382216/work/tc/tmpdir/IFS/tco2559-ng5-cycle3/tempest_track_20200120-20200218.txt
# Opened NetCDF file: /home/b/b382216/work/tc/fullres/IFS/tco2559-ng5-cycle3/tempest_tracks_20200120-20200218.nc
# Track 1:
# Track Length: 12, Year: 2020, Month: 1, Date: 22, Hour: 0
# Time tempest dict: 2020-01-22 00:00:00, lat tempest -18.5, lon tempest 68.0,  MSLP tempest: 100396.6, wind_mod tempest: 13.97
# Time netcdf: 2020-01-22T00:00:00.000000000, MSLP netcdf: 100157.99193397671, wind_mod netcdf: 20.411855938955014
#
# Time tempest dict: 2020-01-22 06:00:00, lat tempest -19.5, lon tempest 68.0,  MSLP tempest: 100515.3, wind_mod tempest: 14.42783
# Time netcdf: 2020-01-22T06:00:00.000000000, MSLP netcdf: 100397.98145165609, wind_mod netcdf: 20.11255899356146
#
# Time tempest dict: 2020-01-22 12:00:00, lat tempest -20.5, lon tempest 69.0,  MSLP tempest: 100361.3, wind_mod tempest: 12.97528
# Time netcdf: 2020-01-22T12:00:00.000000000, MSLP netcdf: 100268.65367267071, wind_mod netcdf: 17.014893355160016
#
# Time tempest dict: 2020-01-22 18:00:00, lat tempest -21.5, lon tempest 69.0,  MSLP tempest: 100600.3, wind_mod tempest: 13.56507
# Time netcdf: 2020-01-22T18:00:00.000000000, MSLP netcdf: 100490.95228205151, wind_mod netcdf: 16.37563344855313
#
# Time tempest dict: 2020-01-23 00:00:00, lat tempest -22.5, lon tempest 70.0,  MSLP tempest: 100502.3, wind_mod tempest: 13.43154
# Time netcdf: 2020-01-23T00:00:00.000000000, MSLP netcdf: 100383.18990488196, wind_mod netcdf: 18.179475558166388
#
# Time tempest dict: 2020-01-23 06:00:00, lat tempest -23.5, lon tempest 70.0,  MSLP tempest: 100624.8, wind_mod tempest: 14.06795
# Time netcdf: 2020-01-23T06:00:00.000000000, MSLP netcdf: 100565.93834479601, wind_mod netcdf: 19.98817251268815
#
# Time tempest dict: 2020-01-23 12:00:00, lat tempest -25.5, lon tempest 70.0,  MSLP tempest: 100352.6, wind_mod tempest: 14.32646
# Time netcdf: 2020-01-23T12:00:00.000000000, MSLP netcdf: 100250.61337631098, wind_mod netcdf: 18.413050430278822
#
# Time tempest dict: 2020-01-23 18:00:00, lat tempest -26.5, lon tempest 70.0,  MSLP tempest: 100465.0, wind_mod tempest: 14.42013
# Time netcdf: 2020-01-23T18:00:00.000000000, MSLP netcdf: 100133.90091392891, wind_mod netcdf: 20.49387798379794
#
# Time tempest dict: 2020-01-24 00:00:00, lat tempest -28.5, lon tempest 71.0,  MSLP tempest: 100213.1, wind_mod tempest: 16.11677
# Time netcdf: 2020-01-24T00:00:00.000000000, MSLP netcdf: 99993.31608829835, wind_mod netcdf: 19.24565262765369
#
# Time tempest dict: 2020-01-24 06:00:00, lat tempest -29.5, lon tempest 72.0,  MSLP tempest: 100153.5, wind_mod tempest: 16.85328
# Time netcdf: 2020-01-24T06:00:00.000000000, MSLP netcdf: 100029.25360106469, wind_mod netcdf: 19.468067517347475
#
# Time tempest dict: 2020-01-24 12:00:00, lat tempest -24.5, lon tempest 67.0,  MSLP tempest: 100164.8, wind_mod tempest: 12.12004
# Time netcdf: 2020-01-24T12:00:00.000000000, MSLP netcdf: 99952.97800927437, wind_mod netcdf: 14.819733070805334
#
# Time tempest dict: 2020-01-24 18:00:00, lat tempest -24.5, lon tempest 68.0,  MSLP tempest: 100301.0, wind_mod tempest: 11.21917
# Time netcdf: 2020-01-24T18:00:00.000000000, MSLP netcdf: 100127.00590087344, wind_mod netcdf: 14.609274331704414
#
# Track 2:
# Track Length: 43, Year: 2020, Month: 1, Date: 28, Hour: 18
# Time tempest dict: 2020-01-28 18:00:00, lat tempest -14.5, lon tempest 140.0,  MSLP tempest: 99856.82, wind_mod tempest: 12.06151
# Time netcdf: 2020-01-28T18:00:00.000000000, MSLP netcdf: 99600.17830960266, wind_mod netcdf: 16.125888211065845
#
# Time tempest dict: 2020-01-29 00:00:00, lat tempest -15.5, lon tempest 141.0,  MSLP tempest: 99922.53, wind_mod tempest: 11.2669
# Time netcdf: 2020-01-29T00:00:00.000000000, MSLP netcdf: 99656.54063901375, wind_mod netcdf: 19.191224989072417
#
# Time tempest dict: 2020-01-29 06:00:00, lat tempest -15.5, lon tempest 141.0,  MSLP tempest: 99621.47, wind_mod tempest: 13.01613
# Time netcdf: 2020-01-29T06:00:00.000000000, MSLP netcdf: 99088.79105870018, wind_mod netcdf: 17.471233548991187
#
# Time tempest dict: 2020-01-29 12:00:00, lat tempest -15.5, lon tempest 140.0,  MSLP tempest: 99746.39, wind_mod tempest: 14.89756
# Time netcdf: 2020-01-29T12:00:00.000000000, MSLP netcdf: 99188.61038356568, wind_mod netcdf: 20.325125622262924
#
# Time tempest dict: 2020-01-29 18:00:00, lat tempest -16.5, lon tempest 140.0,  MSLP tempest: 99238.42, wind_mod tempest: 14.02784
# Time netcdf: 2020-01-29T18:00:00.000000000, MSLP netcdf: 98695.15143107357, wind_mod netcdf: 22.935094263341743
#
# Time tempest dict: 2020-01-30 00:00:00, lat tempest -16.5, lon tempest 140.0,  MSLP tempest: 99061.68, wind_mod tempest: 14.33805
# Time netcdf: 2020-01-30T00:00:00.000000000, MSLP netcdf: 98579.81896581357, wind_mod netcdf: 25.808088434366802
#
# Time tempest dict: 2020-01-30 06:00:00, lat tempest -17.5, lon tempest 139.0,  MSLP tempest: 98914.81, wind_mod tempest: 13.54268
# Time netcdf: 2020-01-30T06:00:00.000000000, MSLP netcdf: 97996.35451365038, wind_mod netcdf: 24.527507876496184
#
# Time tempest dict: 2020-01-30 12:00:00, lat tempest -17.5, lon tempest 139.0,  MSLP tempest: 99198.84, wind_mod tempest: 13.10829
# Time netcdf: 2020-01-30T12:00:00.000000000, MSLP netcdf: 98692.04925249, wind_mod netcdf: 19.508709426112024
#
# Time tempest dict: 2020-01-30 18:00:00, lat tempest -18.5, lon tempest 138.0,  MSLP tempest: 99220.03, wind_mod tempest: 11.66482
# Time netcdf: 2020-01-30T18:00:00.000000000, MSLP netcdf: 98755.71836778901, wind_mod netcdf: 17.178176012909372
#
# Time tempest dict: 2020-01-31 00:00:00, lat tempest -18.5, lon tempest 138.0,  MSLP tempest: 99601.62, wind_mod tempest: 12.49127
# Time netcdf: 2020-01-31T00:00:00.000000000, MSLP netcdf: 99175.67227847037, wind_mod netcdf: 17.331189988115653
#
# Time tempest dict: 2020-01-31 06:00:00, lat tempest -18.5, lon tempest 137.0,  MSLP tempest: 99237.3, wind_mod tempest: 12.09411
# Time netcdf: 2020-01-31T06:00:00.000000000, MSLP netcdf: 99054.65410295497, wind_mod netcdf: 16.183597222623952
#
# Time tempest dict: 2020-01-31 12:00:00, lat tempest -18.5, lon tempest 137.0,  MSLP tempest: 99454.62, wind_mod tempest: 12.75225
# Time netcdf: 2020-01-31T12:00:00.000000000, MSLP netcdf: 99146.30167887807, wind_mod netcdf: 17.728489601781025
#
# Time tempest dict: 2020-01-31 18:00:00, lat tempest -19.5, lon tempest 137.0,  MSLP tempest: 99148.7, wind_mod tempest: 12.51463
# Time netcdf: 2020-01-31T18:00:00.000000000, MSLP netcdf: 98867.0642847591, wind_mod netcdf: 16.811180309641017
#
# Time tempest dict: 2020-02-01 00:00:00, lat tempest -19.5, lon tempest 137.0,  MSLP tempest: 99651.09, wind_mod tempest: 11.53318
# Time netcdf: 2020-02-01T00:00:00.000000000, MSLP netcdf: 99283.5405265122, wind_mod netcdf: 15.015671570499412
#
# Time tempest dict: 2020-02-01 06:00:00, lat tempest -20.5, lon tempest 136.0,  MSLP tempest: 99501.98, wind_mod tempest: 10.78223
# Time netcdf: 2020-02-01T06:00:00.000000000, MSLP netcdf: 99181.74253294774, wind_mod netcdf: 13.99815871201353
#
# Time tempest dict: 2020-02-01 12:00:00, lat tempest -20.5, lon tempest 136.0,  MSLP tempest: 99791.57, wind_mod tempest: 12.46551
# Time netcdf: 2020-02-01T12:00:00.000000000, MSLP netcdf: 99425.65071143114, wind_mod netcdf: 16.945961466153836
#
# Time tempest dict: 2020-02-01 18:00:00, lat tempest -21.5, lon tempest 136.0,  MSLP tempest: 99459.29, wind_mod tempest: 10.52244
# Time netcdf: 2020-02-01T18:00:00.000000000, MSLP netcdf: 99237.9223322872, wind_mod netcdf: 14.710322522223606
#
# Time tempest dict: 2020-02-02 00:00:00, lat tempest -21.5, lon tempest 136.0,  MSLP tempest: 99791.39, wind_mod tempest: 11.06473
# Time netcdf: 2020-02-02T00:00:00.000000000, MSLP netcdf: 99565.28695880355, wind_mod netcdf: 15.810963156814223
#
# Time tempest dict: 2020-02-02 06:00:00, lat tempest -21.5, lon tempest 136.0,  MSLP tempest: 99768.59, wind_mod tempest: 10.80436
# Time netcdf: 2020-02-02T06:00:00.000000000, MSLP netcdf: 99451.6700996775, wind_mod netcdf: 15.271838501075948
#
# Time tempest dict: 2020-02-02 12:00:00, lat tempest -22.5, lon tempest 136.0,  MSLP tempest: 99979.67, wind_mod tempest: 10.58051
# Time netcdf: 2020-02-02T12:00:00.000000000, MSLP netcdf: 99706.9713328769, wind_mod netcdf: 14.697599954386888
#
# Time tempest dict: 2020-02-02 18:00:00, lat tempest -23.5, lon tempest 136.0,  MSLP tempest: 99665.01, wind_mod tempest: 11.42235
# Time netcdf: 2020-02-02T18:00:00.000000000, MSLP netcdf: 99256.140458177, wind_mod netcdf: 16.918575635704237
#
# Time tempest dict: 2020-02-03 00:00:00, lat tempest -23.5, lon tempest 136.0,  MSLP tempest: 99878.3, wind_mod tempest: 11.79278
# Time netcdf: 2020-02-03T00:00:00.000000000, MSLP netcdf: 99536.0412840617, wind_mod netcdf: 15.534095128171902
#
# Time tempest dict: 2020-02-03 06:00:00, lat tempest -23.5, lon tempest 135.0,  MSLP tempest: 99716.55, wind_mod tempest: 9.348901
# Time netcdf: 2020-02-03T06:00:00.000000000, MSLP netcdf: 99451.71641333822, wind_mod netcdf: 14.247649563526995
#
# Time tempest dict: 2020-02-03 12:00:00, lat tempest -23.5, lon tempest 135.0,  MSLP tempest: 99902.54, wind_mod tempest: 9.595752
# Time netcdf: 2020-02-03T12:00:00.000000000, MSLP netcdf: 99626.69795636652, wind_mod netcdf: 12.933951688798144
#
# Time tempest dict: 2020-02-03 18:00:00, lat tempest -23.5, lon tempest 135.0,  MSLP tempest: 99695.18, wind_mod tempest: 9.961545
# Time netcdf: 2020-02-03T18:00:00.000000000, MSLP netcdf: 99364.24552432523, wind_mod netcdf: 15.93436225988881
#
# Time tempest dict: 2020-02-04 00:00:00, lat tempest -23.5, lon tempest 134.0,  MSLP tempest: 99953.52, wind_mod tempest: 11.257
# Time netcdf: 2020-02-04T00:00:00.000000000, MSLP netcdf: 99681.72130634924, wind_mod netcdf: 13.570127143313572
#
# Time tempest dict: 2020-02-04 06:00:00, lat tempest -22.5, lon tempest 134.0,  MSLP tempest: 99593.93, wind_mod tempest: 9.282685
# Time netcdf: 2020-02-04T06:00:00.000000000, MSLP netcdf: 99201.52091478427, wind_mod netcdf: 13.90577225196148
#
# Time tempest dict: 2020-02-04 12:00:00, lat tempest -21.5, lon tempest 133.0,  MSLP tempest: 99758.38, wind_mod tempest: 9.320124
# Time netcdf: 2020-02-04T12:00:00.000000000, MSLP netcdf: 99397.32023733799, wind_mod netcdf: 13.26246059853391
#
# Time tempest dict: 2020-02-04 18:00:00, lat tempest -21.5, lon tempest 133.0,  MSLP tempest: 99352.32, wind_mod tempest: 10.52423
# Time netcdf: 2020-02-04T18:00:00.000000000, MSLP netcdf: 98981.96664147906, wind_mod netcdf: 14.599853270637958
#
# Time tempest dict: 2020-02-05 00:00:00, lat tempest -21.5, lon tempest 132.0,  MSLP tempest: 99384.76, wind_mod tempest: 10.34363
# Time netcdf: 2020-02-05T00:00:00.000000000, MSLP netcdf: 99142.69498180307, wind_mod netcdf: 18.63904651705787
#
# Time tempest dict: 2020-02-05 06:00:00, lat tempest -21.5, lon tempest 131.0,  MSLP tempest: 99301.07, wind_mod tempest: 11.11755
# Time netcdf: 2020-02-05T06:00:00.000000000, MSLP netcdf: 98854.41491911605, wind_mod netcdf: 16.374771194253917
#
# Time tempest dict: 2020-02-05 12:00:00, lat tempest -21.5, lon tempest 131.0,  MSLP tempest: 99288.27, wind_mod tempest: 12.6816
# Time netcdf: 2020-02-05T12:00:00.000000000, MSLP netcdf: 99052.29110805331, wind_mod netcdf: 17.071546726720456
#
# Time tempest dict: 2020-02-05 18:00:00, lat tempest -21.5, lon tempest 130.0,  MSLP tempest: 99095.92, wind_mod tempest: 11.74269
# Time netcdf: 2020-02-05T18:00:00.000000000, MSLP netcdf: 98681.19131894625, wind_mod netcdf: 15.639837807264959
#
# Time tempest dict: 2020-02-06 00:00:00, lat tempest -21.5, lon tempest 130.0,  MSLP tempest: 99285.14, wind_mod tempest: 13.19654
# Time netcdf: 2020-02-06T00:00:00.000000000, MSLP netcdf: 98966.11469940904, wind_mod netcdf: 16.96435350609472
#
# Time tempest dict: 2020-02-06 06:00:00, lat tempest -21.5, lon tempest 130.0,  MSLP tempest: 99012.16, wind_mod tempest: 13.69961
# Time netcdf: 2020-02-06T06:00:00.000000000, MSLP netcdf: 98752.82316582781, wind_mod netcdf: 16.931448922975697
#
# Time tempest dict: 2020-02-06 12:00:00, lat tempest -21.5, lon tempest 130.0,  MSLP tempest: 99424.52, wind_mod tempest: 12.76278
# Time netcdf: 2020-02-06T12:00:00.000000000, MSLP netcdf: 98986.1951085284, wind_mod netcdf: 17.604570429580285
#
# Time tempest dict: 2020-02-06 18:00:00, lat tempest -20.5, lon tempest 129.0,  MSLP tempest: 99170.39, wind_mod tempest: 12.06259
# Time netcdf: 2020-02-06T18:00:00.000000000, MSLP netcdf: 98801.29891998832, wind_mod netcdf: 17.880748093349137
#
# Time tempest dict: 2020-02-07 00:00:00, lat tempest -20.5, lon tempest 129.0,  MSLP tempest: 99332.88, wind_mod tempest: 13.02853
# Time netcdf: 2020-02-07T00:00:00.000000000, MSLP netcdf: 99013.33450375113, wind_mod netcdf: 15.922492800890216
#
# Time tempest dict: 2020-02-07 06:00:00, lat tempest -20.5, lon tempest 128.0,  MSLP tempest: 99282.36, wind_mod tempest: 13.25767
# Time netcdf: 2020-02-07T06:00:00.000000000, MSLP netcdf: 98856.03645951279, wind_mod netcdf: 17.180494427033285
#
# Time tempest dict: 2020-02-07 12:00:00, lat tempest -20.5, lon tempest 128.0,  MSLP tempest: 99437.45, wind_mod tempest: 13.56521
# Time netcdf: 2020-02-07T12:00:00.000000000, MSLP netcdf: 99138.92915685661, wind_mod netcdf: 16.62683624096362
#
# Time tempest dict: 2020-02-07 18:00:00, lat tempest -20.5, lon tempest 127.0,  MSLP tempest: 99321.19, wind_mod tempest: 12.07216
# Time netcdf: 2020-02-07T18:00:00.000000000, MSLP netcdf: 99040.6692235328, wind_mod netcdf: 14.881795727590903
#
# Time tempest dict: 2020-02-08 00:00:00, lat tempest -20.5, lon tempest 127.0,  MSLP tempest: 99668.84, wind_mod tempest: 10.27332
# Time netcdf: 2020-02-08T00:00:00.000000000, MSLP netcdf: 99417.6186810585, wind_mod netcdf: 13.579059297771614
#
# Time tempest dict: 2020-02-08 06:00:00, lat tempest -20.5, lon tempest 126.0,  MSLP tempest: 99684.41, wind_mod tempest: 9.142118
# Time netcdf: 2020-02-08T06:00:00.000000000, MSLP netcdf: 99414.18969691698, wind_mod netcdf: 11.866824451250531
#
# Track 3:
# Track Length: 30, Year: 2020, Month: 1, Date: 29, Hour: 18
# Time tempest dict: 2020-01-29 18:00:00, lat tempest -13.5, lon tempest 123.0,  MSLP tempest: 99845.48, wind_mod tempest: 12.09441
# Time netcdf: 2020-01-29T18:00:00.000000000, MSLP netcdf: 99285.52212666399, wind_mod netcdf: 21.904552733608764
#
# Time tempest dict: 2020-01-30 00:00:00, lat tempest -13.5, lon tempest 123.0,  MSLP tempest: 99854.25, wind_mod tempest: 12.15209
# Time netcdf: 2020-01-30T00:00:00.000000000, MSLP netcdf: 99573.9113852987, wind_mod netcdf: 18.970507537858907
#
# Time tempest dict: 2020-01-30 06:00:00, lat tempest -13.5, lon tempest 122.0,  MSLP tempest: 99629.62, wind_mod tempest: 14.8579
# Time netcdf: 2020-01-30T06:00:00.000000000, MSLP netcdf: 99168.64126340387, wind_mod netcdf: 21.355220893988676
#
# Time tempest dict: 2020-01-30 12:00:00, lat tempest -13.5, lon tempest 122.0,  MSLP tempest: 99813.44, wind_mod tempest: 14.86328
# Time netcdf: 2020-01-30T12:00:00.000000000, MSLP netcdf: 99345.69013563503, wind_mod netcdf: 19.70889442065569
#
# Time tempest dict: 2020-01-30 18:00:00, lat tempest -13.5, lon tempest 122.0,  MSLP tempest: 99413.12, wind_mod tempest: 16.01563
# Time netcdf: 2020-01-30T18:00:00.000000000, MSLP netcdf: 98792.90922564661, wind_mod netcdf: 24.607623059672704
#
# Time tempest dict: 2020-01-31 00:00:00, lat tempest -14.5, lon tempest 122.0,  MSLP tempest: 99233.58, wind_mod tempest: 17.61941
# Time netcdf: 2020-01-31T00:00:00.000000000, MSLP netcdf: 98780.20332921144, wind_mod netcdf: 27.51754060002028
#
# Time tempest dict: 2020-01-31 06:00:00, lat tempest -14.5, lon tempest 122.0,  MSLP tempest: 99015.62, wind_mod tempest: 16.75454
# Time netcdf: 2020-01-31T06:00:00.000000000, MSLP netcdf: 98212.99558523655, wind_mod netcdf: 23.649571483200845
#
# Time tempest dict: 2020-01-31 12:00:00, lat tempest -15.5, lon tempest 122.0,  MSLP tempest: 99028.15, wind_mod tempest: 15.3534
# Time netcdf: 2020-01-31T12:00:00.000000000, MSLP netcdf: 98354.52017596793, wind_mod netcdf: 29.027343339354406
#
# Time tempest dict: 2020-01-31 18:00:00, lat tempest -15.5, lon tempest 122.0,  MSLP tempest: 98678.19, wind_mod tempest: 16.84634
# Time netcdf: 2020-01-31T18:00:00.000000000, MSLP netcdf: 97768.54801815911, wind_mod netcdf: 29.39675069965994
#
# Time tempest dict: 2020-02-01 00:00:00, lat tempest -16.5, lon tempest 122.0,  MSLP tempest: 98778.77, wind_mod tempest: 19.11879
# Time netcdf: 2020-02-01T00:00:00.000000000, MSLP netcdf: 97346.5475635312, wind_mod netcdf: 31.57356303386902
#
# Time tempest dict: 2020-02-01 06:00:00, lat tempest -17.5, lon tempest 121.0,  MSLP tempest: 98605.45, wind_mod tempest: 19.50224
# Time netcdf: 2020-02-01T06:00:00.000000000, MSLP netcdf: 97141.90596391901, wind_mod netcdf: 34.75378760467077
#
# Time tempest dict: 2020-02-01 12:00:00, lat tempest -17.5, lon tempest 121.0,  MSLP tempest: 98501.75, wind_mod tempest: 19.18792
# Time netcdf: 2020-02-01T12:00:00.000000000, MSLP netcdf: 96468.21977656485, wind_mod netcdf: 39.84418531821791
#
# Time tempest dict: 2020-02-01 18:00:00, lat tempest -17.5, lon tempest 120.0,  MSLP tempest: 97795.8, wind_mod tempest: 20.5161
# Time netcdf: 2020-02-01T18:00:00.000000000, MSLP netcdf: 95400.4194987929, wind_mod netcdf: 45.55864230647957
#
# Time tempest dict: 2020-02-02 00:00:00, lat tempest -18.5, lon tempest 120.0,  MSLP tempest: 98188.58, wind_mod tempest: 21.86638
# Time netcdf: 2020-02-02T00:00:00.000000000, MSLP netcdf: 95616.53059395502, wind_mod netcdf: 44.008828726539605
#
# Time tempest dict: 2020-02-02 06:00:00, lat tempest -18.5, lon tempest 119.0,  MSLP tempest: 97596.07, wind_mod tempest: 20.02801
# Time netcdf: 2020-02-02T06:00:00.000000000, MSLP netcdf: 95413.07990273272, wind_mod netcdf: 45.24888653138002
#
# Time tempest dict: 2020-02-02 12:00:00, lat tempest -18.5, lon tempest 119.0,  MSLP tempest: 97876.83, wind_mod tempest: 20.39758
# Time netcdf: 2020-02-02T12:00:00.000000000, MSLP netcdf: 95649.52424584658, wind_mod netcdf: 43.88290627776497
#
# Time tempest dict: 2020-02-02 18:00:00, lat tempest -19.5, lon tempest 119.0,  MSLP tempest: 98493.61, wind_mod tempest: 20.43073
# Time netcdf: 2020-02-02T18:00:00.000000000, MSLP netcdf: 96055.59296104078, wind_mod netcdf: 37.970032440524506
#
# Time tempest dict: 2020-02-03 00:00:00, lat tempest -19.5, lon tempest 119.0,  MSLP tempest: 98776.4, wind_mod tempest: 20.03422
# Time netcdf: 2020-02-03T00:00:00.000000000, MSLP netcdf: 96810.76032654251, wind_mod netcdf: 39.178785565054135
#
# Time tempest dict: 2020-02-03 06:00:00, lat tempest -19.5, lon tempest 118.0,  MSLP tempest: 98269.92, wind_mod tempest: 18.29159
# Time netcdf: 2020-02-03T06:00:00.000000000, MSLP netcdf: 96780.79011884828, wind_mod netcdf: 39.596991430761605
#
# Time tempest dict: 2020-02-03 12:00:00, lat tempest -19.5, lon tempest 118.0,  MSLP tempest: 99079.95, wind_mod tempest: 17.61379
# Time netcdf: 2020-02-03T12:00:00.000000000, MSLP netcdf: 97918.9232344075, wind_mod netcdf: 28.148300910428755
#
# Time tempest dict: 2020-02-03 18:00:00, lat tempest -20.5, lon tempest 117.0,  MSLP tempest: 99223.47, wind_mod tempest: 18.79763
# Time netcdf: 2020-02-03T18:00:00.000000000, MSLP netcdf: 97649.49113803255, wind_mod netcdf: 34.15576144539322
#
# Time tempest dict: 2020-02-04 00:00:00, lat tempest -20.5, lon tempest 117.0,  MSLP tempest: 99286.01, wind_mod tempest: 16.66187
# Time netcdf: 2020-02-04T00:00:00.000000000, MSLP netcdf: 98323.00930164859, wind_mod netcdf: 24.99905942498194
#
# Time tempest dict: 2020-02-04 06:00:00, lat tempest -21.5, lon tempest 116.0,  MSLP tempest: 99503.28, wind_mod tempest: 15.16243
# Time netcdf: 2020-02-04T06:00:00.000000000, MSLP netcdf: 98771.13334469777, wind_mod netcdf: 21.12894233302458
#
# Time tempest dict: 2020-02-04 12:00:00, lat tempest -21.5, lon tempest 116.0,  MSLP tempest: 99780.78, wind_mod tempest: 11.73544
# Time netcdf: 2020-02-04T12:00:00.000000000, MSLP netcdf: 99222.94097575099, wind_mod netcdf: 19.055179127550726
#
# Time tempest dict: 2020-02-04 18:00:00, lat tempest -21.5, lon tempest 115.0,  MSLP tempest: 99685.11, wind_mod tempest: 11.23436
# Time netcdf: 2020-02-04T18:00:00.000000000, MSLP netcdf: 99392.98317642265, wind_mod netcdf: 16.4483629258764
#
# Time tempest dict: 2020-02-05 00:00:00, lat tempest -21.5, lon tempest 115.0,  MSLP tempest: 100023.2, wind_mod tempest: 10.35922
# Time netcdf: 2020-02-05T00:00:00.000000000, MSLP netcdf: 99645.84007536044, wind_mod netcdf: 14.391644040941323
#
# Time tempest dict: 2020-02-05 06:00:00, lat tempest -22.5, lon tempest 114.0,  MSLP tempest: 99972.09, wind_mod tempest: 9.394036
# Time netcdf: 2020-02-05T06:00:00.000000000, MSLP netcdf: 99746.71287306258, wind_mod netcdf: 12.563727237258723
#
# Time tempest dict: 2020-02-05 12:00:00, lat tempest -21.5, lon tempest 113.0,  MSLP tempest: 100037.7, wind_mod tempest: 9.433232
# Time netcdf: 2020-02-05T12:00:00.000000000, MSLP netcdf: 99913.31726414278, wind_mod netcdf: 13.52487501474662
#
# Time tempest dict: 2020-02-05 18:00:00, lat tempest -21.5, lon tempest 113.0,  MSLP tempest: 100139.9, wind_mod tempest: 9.020751
# Time netcdf: 2020-02-05T18:00:00.000000000, MSLP netcdf: 100007.59135119748, wind_mod netcdf: 11.383425070027664
#
# Time tempest dict: 2020-02-06 00:00:00, lat tempest -20.5, lon tempest 112.0,  MSLP tempest: 100198.2, wind_mod tempest: 8.883835
# Time netcdf: 2020-02-06T00:00:00.000000000, MSLP netcdf: 100109.05260906152, wind_mod netcdf: 11.779846234335002
#
# Track 4:
# Track Length: 36, Year: 2020, Month: 2, Date: 3, Hour: 12
# Time tempest dict: 2020-02-03 12:00:00, lat tempest -13.5, lon tempest 72.0,  MSLP tempest: 100261.3, wind_mod tempest: 12.85913
# Time netcdf: 2020-02-03T12:00:00.000000000, MSLP netcdf: 100112.11692521081, wind_mod netcdf: 21.60743182515381
#
# Time tempest dict: 2020-02-03 18:00:00, lat tempest -13.5, lon tempest 73.0,  MSLP tempest: 100397.4, wind_mod tempest: 13.65824
# Time netcdf: 2020-02-03T18:00:00.000000000, MSLP netcdf: 100296.4893967508, wind_mod netcdf: 17.44611855246075
#
# Time tempest dict: 2020-02-04 00:00:00, lat tempest -14.5, lon tempest 73.0,  MSLP tempest: 100062.6, wind_mod tempest: 11.96418
# Time netcdf: 2020-02-04T00:00:00.000000000, MSLP netcdf: 99930.21861943611, wind_mod netcdf: 16.579761002920584
#
# Time tempest dict: 2020-02-04 06:00:00, lat tempest -14.5, lon tempest 73.0,  MSLP tempest: 100160.9, wind_mod tempest: 13.30392
# Time netcdf: 2020-02-04T06:00:00.000000000, MSLP netcdf: 100068.7826993513, wind_mod netcdf: 15.95969755995471
#
# Time tempest dict: 2020-02-04 12:00:00, lat tempest -14.5, lon tempest 73.0,  MSLP tempest: 99792.16, wind_mod tempest: 15.40542
# Time netcdf: 2020-02-04T12:00:00.000000000, MSLP netcdf: 99704.8802548406, wind_mod netcdf: 18.190368021534216
#
# Time tempest dict: 2020-02-04 18:00:00, lat tempest -15.5, lon tempest 73.0,  MSLP tempest: 100000.8, wind_mod tempest: 13.76727
# Time netcdf: 2020-02-04T18:00:00.000000000, MSLP netcdf: 99816.85914528616, wind_mod netcdf: 17.263940670900496
#
# Time tempest dict: 2020-02-05 00:00:00, lat tempest -15.5, lon tempest 73.0,  MSLP tempest: 99568.93, wind_mod tempest: 15.92385
# Time netcdf: 2020-02-05T00:00:00.000000000, MSLP netcdf: 99430.77477105262, wind_mod netcdf: 20.16383322850952
#
# Time tempest dict: 2020-02-05 06:00:00, lat tempest -15.5, lon tempest 73.0,  MSLP tempest: 99640.2, wind_mod tempest: 15.92547
# Time netcdf: 2020-02-05T06:00:00.000000000, MSLP netcdf: 99341.95945326533, wind_mod netcdf: 20.08814506767204
#
# Time tempest dict: 2020-02-05 12:00:00, lat tempest -15.5, lon tempest 73.0,  MSLP tempest: 99349.16, wind_mod tempest: 18.16096
# Time netcdf: 2020-02-05T12:00:00.000000000, MSLP netcdf: 99178.01833140689, wind_mod netcdf: 21.531814592924327
#
# Time tempest dict: 2020-02-05 18:00:00, lat tempest -15.5, lon tempest 73.0,  MSLP tempest: 99323.04, wind_mod tempest: 19.1031
# Time netcdf: 2020-02-05T18:00:00.000000000, MSLP netcdf: 98959.69363584308, wind_mod netcdf: 24.518311267772667
#
# Time tempest dict: 2020-02-06 00:00:00, lat tempest -15.5, lon tempest 74.0,  MSLP tempest: 98894.16, wind_mod tempest: 19.18246
# Time netcdf: 2020-02-06T00:00:00.000000000, MSLP netcdf: 98512.53158723214, wind_mod netcdf: 28.87552944157181
#
# Time tempest dict: 2020-02-06 06:00:00, lat tempest -16.5, lon tempest 74.0,  MSLP tempest: 98827.98, wind_mod tempest: 19.15998
# Time netcdf: 2020-02-06T06:00:00.000000000, MSLP netcdf: 98440.09616283033, wind_mod netcdf: 28.764868871139964
#
# Time tempest dict: 2020-02-06 12:00:00, lat tempest -16.5, lon tempest 74.0,  MSLP tempest: 98465.65, wind_mod tempest: 19.56726
# Time netcdf: 2020-02-06T12:00:00.000000000, MSLP netcdf: 97853.38367544234, wind_mod netcdf: 26.328516792990634
#
# Time tempest dict: 2020-02-06 18:00:00, lat tempest -16.5, lon tempest 74.0,  MSLP tempest: 98470.04, wind_mod tempest: 21.32742
# Time netcdf: 2020-02-06T18:00:00.000000000, MSLP netcdf: 97858.13125270019, wind_mod netcdf: 27.9013205085667
#
# Time tempest dict: 2020-02-07 00:00:00, lat tempest -16.5, lon tempest 74.0,  MSLP tempest: 98076.98, wind_mod tempest: 21.79915
# Time netcdf: 2020-02-07T00:00:00.000000000, MSLP netcdf: 97564.93469072992, wind_mod netcdf: 31.47575068463761
#
# Time tempest dict: 2020-02-07 06:00:00, lat tempest -16.5, lon tempest 75.0,  MSLP tempest: 98147.02, wind_mod tempest: 21.38966
# Time netcdf: 2020-02-07T06:00:00.000000000, MSLP netcdf: 97555.15055192947, wind_mod netcdf: 28.049521252495936
#
# Time tempest dict: 2020-02-07 12:00:00, lat tempest -16.5, lon tempest 74.0,  MSLP tempest: 98105.97, wind_mod tempest: 20.35386
# Time netcdf: 2020-02-07T12:00:00.000000000, MSLP netcdf: 97318.87575620216, wind_mod netcdf: 27.446531718705643
#
# Time tempest dict: 2020-02-07 18:00:00, lat tempest -17.5, lon tempest 74.0,  MSLP tempest: 97717.28, wind_mod tempest: 21.25204
# Time netcdf: 2020-02-07T18:00:00.000000000, MSLP netcdf: 97289.76081746511, wind_mod netcdf: 27.04360219319228
#
# Time tempest dict: 2020-02-08 00:00:00, lat tempest -17.5, lon tempest 74.0,  MSLP tempest: 97867.52, wind_mod tempest: 20.53482
# Time netcdf: 2020-02-08T00:00:00.000000000, MSLP netcdf: 97000.71406933221, wind_mod netcdf: 28.51843359571402
#
# Time tempest dict: 2020-02-08 06:00:00, lat tempest -18.5, lon tempest 73.0,  MSLP tempest: 97475.17, wind_mod tempest: 21.25627
# Time netcdf: 2020-02-08T06:00:00.000000000, MSLP netcdf: 96960.36943453204, wind_mod netcdf: 30.81221485265328
#
# Time tempest dict: 2020-02-08 12:00:00, lat tempest -18.5, lon tempest 73.0,  MSLP tempest: 97241.84, wind_mod tempest: 23.31572
# Time netcdf: 2020-02-08T12:00:00.000000000, MSLP netcdf: 96320.00840991664, wind_mod netcdf: 32.8081197680954
#
# Time tempest dict: 2020-02-08 18:00:00, lat tempest -19.5, lon tempest 72.0,  MSLP tempest: 96923.95, wind_mod tempest: 23.64897
# Time netcdf: 2020-02-08T18:00:00.000000000, MSLP netcdf: 96143.91328568068, wind_mod netcdf: 32.8678406003972
#
# Time tempest dict: 2020-02-09 00:00:00, lat tempest -20.5, lon tempest 72.0,  MSLP tempest: 97178.54, wind_mod tempest: 24.03751
# Time netcdf: 2020-02-09T00:00:00.000000000, MSLP netcdf: 95826.39349401733, wind_mod netcdf: 34.70889905616072
#
# Time tempest dict: 2020-02-09 06:00:00, lat tempest -20.5, lon tempest 71.0,  MSLP tempest: 96731.15, wind_mod tempest: 26.86247
# Time netcdf: 2020-02-09T06:00:00.000000000, MSLP netcdf: 95770.88487319503, wind_mod netcdf: 39.37143019804006
#
# Time tempest dict: 2020-02-09 12:00:00, lat tempest -21.5, lon tempest 70.0,  MSLP tempest: 96473.26, wind_mod tempest: 26.32882
# Time netcdf: 2020-02-09T12:00:00.000000000, MSLP netcdf: 95515.77086528229, wind_mod netcdf: 38.69236026721626
#
# Time tempest dict: 2020-02-09 18:00:00, lat tempest -22.5, lon tempest 70.0,  MSLP tempest: 96578.95, wind_mod tempest: 26.33052
# Time netcdf: 2020-02-09T18:00:00.000000000, MSLP netcdf: 95857.18852609144, wind_mod netcdf: 37.613810563156605
#
# Time tempest dict: 2020-02-10 00:00:00, lat tempest -22.5, lon tempest 69.0,  MSLP tempest: 96775.24, wind_mod tempest: 28.11657
# Time netcdf: 2020-02-10T00:00:00.000000000, MSLP netcdf: 95920.72660585013, wind_mod netcdf: 38.32563441805217
#
# Time tempest dict: 2020-02-10 06:00:00, lat tempest -23.5, lon tempest 68.0,  MSLP tempest: 97266.07, wind_mod tempest: 27.00443
# Time netcdf: 2020-02-10T06:00:00.000000000, MSLP netcdf: 96531.04276714912, wind_mod netcdf: 36.420804162386304
#
# Time tempest dict: 2020-02-10 12:00:00, lat tempest -24.5, lon tempest 68.0,  MSLP tempest: 97103.06, wind_mod tempest: 26.43386
# Time netcdf: 2020-02-10T12:00:00.000000000, MSLP netcdf: 96554.02232181537, wind_mod netcdf: 38.21685121940469
#
# Time tempest dict: 2020-02-10 18:00:00, lat tempest -24.5, lon tempest 67.0,  MSLP tempest: 97431.65, wind_mod tempest: 25.89935
# Time netcdf: 2020-02-10T18:00:00.000000000, MSLP netcdf: 96861.03204968305, wind_mod netcdf: 38.184401020349284
#
# Time tempest dict: 2020-02-11 00:00:00, lat tempest -25.5, lon tempest 66.0,  MSLP tempest: 97172.48, wind_mod tempest: 26.86108
# Time netcdf: 2020-02-11T00:00:00.000000000, MSLP netcdf: 96932.81017547351, wind_mod netcdf: 32.03813439064453
#
# Time tempest dict: 2020-02-11 06:00:00, lat tempest -26.5, lon tempest 65.0,  MSLP tempest: 97677.17, wind_mod tempest: 25.07148
# Time netcdf: 2020-02-11T06:00:00.000000000, MSLP netcdf: 97336.7103560429, wind_mod netcdf: 31.466549078062176
#
# Time tempest dict: 2020-02-11 12:00:00, lat tempest -27.5, lon tempest 65.0,  MSLP tempest: 98093.64, wind_mod tempest: 24.61188
# Time netcdf: 2020-02-11T12:00:00.000000000, MSLP netcdf: 97479.39555248625, wind_mod netcdf: 33.37540393517724
#
# Time tempest dict: 2020-02-11 18:00:00, lat tempest -27.5, lon tempest 64.0,  MSLP tempest: 98291.23, wind_mod tempest: 23.48317
# Time netcdf: 2020-02-11T18:00:00.000000000, MSLP netcdf: 97850.55399910652, wind_mod netcdf: 30.163252973553114
#
# Time tempest dict: 2020-02-12 00:00:00, lat tempest -28.5, lon tempest 63.0,  MSLP tempest: 98622.75, wind_mod tempest: 23.05202
# Time netcdf: 2020-02-12T00:00:00.000000000, MSLP netcdf: 98219.1074977116, wind_mod netcdf: 28.1877459742961
#
# Time tempest dict: 2020-02-12 06:00:00, lat tempest -30.5, lon tempest 62.0,  MSLP tempest: 98907.21, wind_mod tempest: 22.10005
# Time netcdf: 2020-02-12T06:00:00.000000000, MSLP netcdf: 98723.75260706621, wind_mod netcdf: 27.562451133001193
#
# Track 5:
# Track Length: 21, Year: 2020, Month: 2, Date: 9, Hour: 6
# Time tempest dict: 2020-02-09 06:00:00, lat tempest -13.5, lon tempest 100.0,  MSLP tempest: 100049.9, wind_mod tempest: 12.09694
# Time netcdf: 2020-02-09T06:00:00.000000000, MSLP netcdf: 99893.00548613041, wind_mod netcdf: 18.286853510007735
#
# Time tempest dict: 2020-02-09 12:00:00, lat tempest -12.5, lon tempest 99.0,  MSLP tempest: 100090.8, wind_mod tempest: 12.9674
# Time netcdf: 2020-02-09T12:00:00.000000000, MSLP netcdf: 100000.01428602794, wind_mod netcdf: 15.359902815461838
#
# Time tempest dict: 2020-02-09 18:00:00, lat tempest -13.5, lon tempest 99.0,  MSLP tempest: 100112.0, wind_mod tempest: 10.45402
# Time netcdf: 2020-02-09T18:00:00.000000000, MSLP netcdf: 99882.87208509716, wind_mod netcdf: 21.16783174794227
#
# Time tempest dict: 2020-02-10 00:00:00, lat tempest -13.5, lon tempest 99.0,  MSLP tempest: 100079.6, wind_mod tempest: 12.35474
# Time netcdf: 2020-02-10T00:00:00.000000000, MSLP netcdf: 99966.3781847036, wind_mod netcdf: 16.328111325161917
#
# Time tempest dict: 2020-02-10 06:00:00, lat tempest -13.5, lon tempest 99.0,  MSLP tempest: 100111.5, wind_mod tempest: 10.96806
# Time netcdf: 2020-02-10T06:00:00.000000000, MSLP netcdf: 100064.0920009825, wind_mod netcdf: 15.050169517483392
#
# Time tempest dict: 2020-02-10 12:00:00, lat tempest -13.5, lon tempest 100.0,  MSLP tempest: 100088.4, wind_mod tempest: 11.94091
# Time netcdf: 2020-02-10T12:00:00.000000000, MSLP netcdf: 100039.15170321672, wind_mod netcdf: 15.854854801274097
#
# Time tempest dict: 2020-02-10 18:00:00, lat tempest -13.5, lon tempest 100.0,  MSLP tempest: 100146.3, wind_mod tempest: 11.71505
# Time netcdf: 2020-02-10T18:00:00.000000000, MSLP netcdf: 100062.90340434475, wind_mod netcdf: 16.738835773025784
#
# Time tempest dict: 2020-02-11 00:00:00, lat tempest -13.5, lon tempest 101.0,  MSLP tempest: 100122.2, wind_mod tempest: 14.18064
# Time netcdf: 2020-02-11T00:00:00.000000000, MSLP netcdf: 100017.98014210464, wind_mod netcdf: 16.178954308841455
#
# Time tempest dict: 2020-02-11 06:00:00, lat tempest -14.5, lon tempest 102.0,  MSLP tempest: 100018.4, wind_mod tempest: 13.3184
# Time netcdf: 2020-02-11T06:00:00.000000000, MSLP netcdf: 99877.12800338613, wind_mod netcdf: 16.64446487493916
#
# Time tempest dict: 2020-02-11 12:00:00, lat tempest -15.5, lon tempest 104.0,  MSLP tempest: 100062.9, wind_mod tempest: 13.40948
# Time netcdf: 2020-02-11T12:00:00.000000000, MSLP netcdf: 99920.54087611874, wind_mod netcdf: 19.03911510789987
#
# Time tempest dict: 2020-02-11 18:00:00, lat tempest -15.5, lon tempest 105.0,  MSLP tempest: 99976.57, wind_mod tempest: 14.75571
# Time netcdf: 2020-02-11T18:00:00.000000000, MSLP netcdf: 99856.8842649663, wind_mod netcdf: 18.555507234131703
#
# Time tempest dict: 2020-02-12 00:00:00, lat tempest -16.5, lon tempest 106.0,  MSLP tempest: 99800.21, wind_mod tempest: 14.80255
# Time netcdf: 2020-02-12T00:00:00.000000000, MSLP netcdf: 99589.43364718292, wind_mod netcdf: 19.569156796933793
#
# Time tempest dict: 2020-02-12 06:00:00, lat tempest -17.5, lon tempest 107.0,  MSLP tempest: 99636.52, wind_mod tempest: 15.57886
# Time netcdf: 2020-02-12T06:00:00.000000000, MSLP netcdf: 99477.7981841009, wind_mod netcdf: 20.42249513054813
#
# Time tempest dict: 2020-02-12 12:00:00, lat tempest -18.5, lon tempest 108.0,  MSLP tempest: 99679.88, wind_mod tempest: 14.90405
# Time netcdf: 2020-02-12T12:00:00.000000000, MSLP netcdf: 99379.837155894, wind_mod netcdf: 20.758519344352955
#
# Time tempest dict: 2020-02-12 18:00:00, lat tempest -18.5, lon tempest 109.0,  MSLP tempest: 99754.55, wind_mod tempest: 14.2064
# Time netcdf: 2020-02-12T18:00:00.000000000, MSLP netcdf: 99406.62311606265, wind_mod netcdf: 18.696667988821446
#
# Time tempest dict: 2020-02-13 00:00:00, lat tempest -19.5, lon tempest 109.0,  MSLP tempest: 99413.97, wind_mod tempest: 14.60204
# Time netcdf: 2020-02-13T00:00:00.000000000, MSLP netcdf: 99101.70463559037, wind_mod netcdf: 21.847097348227685
#
# Time tempest dict: 2020-02-13 06:00:00, lat tempest -20.5, lon tempest 109.0,  MSLP tempest: 99292.92, wind_mod tempest: 16.02723
# Time netcdf: 2020-02-13T06:00:00.000000000, MSLP netcdf: 99018.60765399445, wind_mod netcdf: 23.53088026624938
#
# Time tempest dict: 2020-02-13 12:00:00, lat tempest -21.5, lon tempest 110.0,  MSLP tempest: 99460.43, wind_mod tempest: 17.03157
# Time netcdf: 2020-02-13T12:00:00.000000000, MSLP netcdf: 98999.91176395389, wind_mod netcdf: 25.579962823930114
#
# Time tempest dict: 2020-02-13 18:00:00, lat tempest -22.5, lon tempest 110.0,  MSLP tempest: 99384.11, wind_mod tempest: 17.20855
# Time netcdf: 2020-02-13T18:00:00.000000000, MSLP netcdf: 98983.02032707768, wind_mod netcdf: 27.225235380723056
#
# Time tempest dict: 2020-02-14 00:00:00, lat tempest -23.5, lon tempest 111.0,  MSLP tempest: 99791.34, wind_mod tempest: 15.64813
# Time netcdf: 2020-02-14T00:00:00.000000000, MSLP netcdf: 99166.00082548919, wind_mod netcdf: 22.253017710835266
#
# Time tempest dict: 2020-02-14 06:00:00, lat tempest -23.5, lon tempest 111.0,  MSLP tempest: 99816.63, wind_mod tempest: 13.92262
# Time netcdf: 2020-02-14T06:00:00.000000000, MSLP netcdf: 99439.08415306718, wind_mod netcdf: 19.963723808418962
#
# Track 6:
# Track Length: 16, Year: 2020, Month: 2, Date: 10, Hour: 0
# Time tempest dict: 2020-02-10 00:00:00, lat tempest -13.5, lon tempest 177.0,  MSLP tempest: 100183.0, wind_mod tempest: 11.11807
# Time netcdf: 2020-02-10T00:00:00.000000000, MSLP netcdf: 100100.9080103208, wind_mod netcdf: 15.641074842745414
#
# Time tempest dict: 2020-02-10 06:00:00, lat tempest -13.5, lon tempest 178.0,  MSLP tempest: 100039.8, wind_mod tempest: 11.54907
# Time netcdf: 2020-02-10T06:00:00.000000000, MSLP netcdf: 99958.15273483377, wind_mod netcdf: 17.731745025565395
#
# Time tempest dict: 2020-02-10 12:00:00, lat tempest -13.5, lon tempest 179.0,  MSLP tempest: 100101.2, wind_mod tempest: 12.43187
# Time netcdf: 2020-02-10T12:00:00.000000000, MSLP netcdf: 99751.94069145792, wind_mod netcdf: 22.404231573341516
#
# Time tempest dict: 2020-02-10 18:00:00, lat tempest -13.5, lon tempest 180.0,  MSLP tempest: 99858.64, wind_mod tempest: 13.61534
# Time netcdf: 2020-02-10T18:00:00.000000000, MSLP netcdf: 99534.26059689875, wind_mod netcdf: 19.944931950023154
#
# Time tempest dict: 2020-02-11 00:00:00, lat tempest -13.5, lon tempest 180.0,  MSLP tempest: 99770.99, wind_mod tempest: 13.13293
# Time netcdf: 2020-02-11T00:00:00.000000000, MSLP netcdf: 99525.44280121893, wind_mod netcdf: 20.32269717342898
#
# Time tempest dict: 2020-02-11 06:00:00, lat tempest -13.5, lon tempest 181.0,  MSLP tempest: 99660.64, wind_mod tempest: 15.39675
# Time netcdf: 2020-02-11T06:00:00.000000000, MSLP netcdf: 99437.24696405203, wind_mod netcdf: 20.34323346713668
#
# Time tempest dict: 2020-02-11 12:00:00, lat tempest -14.5, lon tempest 181.0,  MSLP tempest: 99640.12, wind_mod tempest: 14.92503
# Time netcdf: 2020-02-11T12:00:00.000000000, MSLP netcdf: 99177.36276595863, wind_mod netcdf: 20.138557197683628
#
# Time tempest dict: 2020-02-11 18:00:00, lat tempest -14.5, lon tempest 181.0,  MSLP tempest: 99644.87, wind_mod tempest: 15.81247
# Time netcdf: 2020-02-11T18:00:00.000000000, MSLP netcdf: 99149.47043605366, wind_mod netcdf: 22.533111232545675
#
# Time tempest dict: 2020-02-12 00:00:00, lat tempest -15.5, lon tempest 181.0,  MSLP tempest: 99562.24, wind_mod tempest: 16.91456
# Time netcdf: 2020-02-12T00:00:00.000000000, MSLP netcdf: 98936.59744802609, wind_mod netcdf: 25.840066449839693
#
# Time tempest dict: 2020-02-12 06:00:00, lat tempest -16.5, lon tempest 181.0,  MSLP tempest: 99566.35, wind_mod tempest: 16.48207
# Time netcdf: 2020-02-12T06:00:00.000000000, MSLP netcdf: 99067.34885712228, wind_mod netcdf: 20.458420541675114
#
# Time tempest dict: 2020-02-12 12:00:00, lat tempest -17.5, lon tempest 181.0,  MSLP tempest: 99751.46, wind_mod tempest: 16.66517
# Time netcdf: 2020-02-12T12:00:00.000000000, MSLP netcdf: 99242.9765946566, wind_mod netcdf: 22.888962465341464
#
# Time tempest dict: 2020-02-12 18:00:00, lat tempest -18.5, lon tempest 181.0,  MSLP tempest: 99592.79, wind_mod tempest: 15.46618
# Time netcdf: 2020-02-12T18:00:00.000000000, MSLP netcdf: 99097.41674331414, wind_mod netcdf: 21.644338389068096
#
# Time tempest dict: 2020-02-13 00:00:00, lat tempest -19.5, lon tempest 180.0,  MSLP tempest: 99703.61, wind_mod tempest: 16.80535
# Time netcdf: 2020-02-13T00:00:00.000000000, MSLP netcdf: 99182.9714810192, wind_mod netcdf: 22.472803228633683
#
# Time tempest dict: 2020-02-13 06:00:00, lat tempest -20.5, lon tempest 180.0,  MSLP tempest: 99589.41, wind_mod tempest: 15.2734
# Time netcdf: 2020-02-13T06:00:00.000000000, MSLP netcdf: 99283.82089051418, wind_mod netcdf: 21.039251365076446
#
# Time tempest dict: 2020-02-13 12:00:00, lat tempest -21.5, lon tempest 179.0,  MSLP tempest: 99833.23, wind_mod tempest: 16.58439
# Time netcdf: 2020-02-13T12:00:00.000000000, MSLP netcdf: 99379.2201806277, wind_mod netcdf: 20.133524799323695
#
# Time tempest dict: 2020-02-13 18:00:00, lat tempest -21.5, lon tempest 179.0,  MSLP tempest: 99799.0, wind_mod tempest: 15.85458
# Time netcdf: 2020-02-13T18:00:00.000000000, MSLP netcdf: 99368.75056933975, wind_mod netcdf: 22.853906643951877
#
# Created /home/b/b382216/work/tc/fullres/IFS/tco2559-ng5-cycle3/tempest_fullres_txt/fullres_tempest_track_20200120-20200218.txt
# Opened tempest file: /home/b/b382216/work/tc/tmpdir/IFS/tco2559-ng5-cycle3/tempest_track_20200219-20200319.txt
# Opened NetCDF file: /home/b/b382216/work/tc/fullres/IFS/tco2559-ng5-cycle3/tempest_tracks_20200219-20200319.nc
# Track 1:
# Track Length: 20, Year: 2020, Month: 2, Date: 20, Hour: 0
# Time tempest dict: 2020-02-20 00:00:00, lat tempest -13.5, lon tempest 88.0,  MSLP tempest: 100325.5, wind_mod tempest: 11.6053
# Time netcdf: 2020-02-20T00:00:00.000000000, MSLP netcdf: 100073.25823072287, wind_mod netcdf: 17.2637285528816
#
# Time tempest dict: 2020-02-20 06:00:00, lat tempest -13.5, lon tempest 88.0,  MSLP tempest: 100332.9, wind_mod tempest: 13.89796
# Time netcdf: 2020-02-20T06:00:00.000000000, MSLP netcdf: 100072.26413870712, wind_mod netcdf: 22.616203857258352
#
# Time tempest dict: 2020-02-20 12:00:00, lat tempest -13.5, lon tempest 89.0,  MSLP tempest: 100278.9, wind_mod tempest: 13.80182
# Time netcdf: 2020-02-20T12:00:00.000000000, MSLP netcdf: 99745.45472436148, wind_mod netcdf: 20.226493406694203
#
# Time tempest dict: 2020-02-20 18:00:00, lat tempest -13.5, lon tempest 89.0,  MSLP tempest: 100429.5, wind_mod tempest: 13.40297
# Time netcdf: 2020-02-20T18:00:00.000000000, MSLP netcdf: 99908.08661335871, wind_mod netcdf: 18.106113312205622
#
# Time tempest dict: 2020-02-21 00:00:00, lat tempest -13.5, lon tempest 89.0,  MSLP tempest: 100144.1, wind_mod tempest: 14.59189
# Time netcdf: 2020-02-21T00:00:00.000000000, MSLP netcdf: 99318.73216443682, wind_mod netcdf: 24.566998795033456
#
# Time tempest dict: 2020-02-21 06:00:00, lat tempest -13.5, lon tempest 89.0,  MSLP tempest: 100233.9, wind_mod tempest: 15.83242
# Time netcdf: 2020-02-21T06:00:00.000000000, MSLP netcdf: 98917.24770999484, wind_mod netcdf: 30.24889114614522
#
# Time tempest dict: 2020-02-21 12:00:00, lat tempest -14.5, lon tempest 89.0,  MSLP tempest: 100187.1, wind_mod tempest: 14.2272
# Time netcdf: 2020-02-21T12:00:00.000000000, MSLP netcdf: 98460.83846681415, wind_mod netcdf: 29.925773767260424
#
# Time tempest dict: 2020-02-21 18:00:00, lat tempest -14.5, lon tempest 89.0,  MSLP tempest: 100329.4, wind_mod tempest: 14.76906
# Time netcdf: 2020-02-21T18:00:00.000000000, MSLP netcdf: 98235.31406816519, wind_mod netcdf: 31.816755194057063
#
# Time tempest dict: 2020-02-22 00:00:00, lat tempest -14.5, lon tempest 90.0,  MSLP tempest: 99905.27, wind_mod tempest: 14.56193
# Time netcdf: 2020-02-22T00:00:00.000000000, MSLP netcdf: 98357.45770871543, wind_mod netcdf: 29.917306210640277
#
# Time tempest dict: 2020-02-22 06:00:00, lat tempest -14.5, lon tempest 90.0,  MSLP tempest: 100016.4, wind_mod tempest: 13.08437
# Time netcdf: 2020-02-22T06:00:00.000000000, MSLP netcdf: 98938.3024690221, wind_mod netcdf: 24.683295734609075
#
# Time tempest dict: 2020-02-22 12:00:00, lat tempest -14.5, lon tempest 90.0,  MSLP tempest: 99879.26, wind_mod tempest: 12.0068
# Time netcdf: 2020-02-22T12:00:00.000000000, MSLP netcdf: 98774.68878381485, wind_mod netcdf: 25.986489353809375
#
# Time tempest dict: 2020-02-22 18:00:00, lat tempest -14.5, lon tempest 90.0,  MSLP tempest: 100172.3, wind_mod tempest: 12.41293
# Time netcdf: 2020-02-22T18:00:00.000000000, MSLP netcdf: 99032.26160578532, wind_mod netcdf: 24.439612443390203
#
# Time tempest dict: 2020-02-23 00:00:00, lat tempest -15.5, lon tempest 90.0,  MSLP tempest: 99887.71, wind_mod tempest: 12.50297
# Time netcdf: 2020-02-23T00:00:00.000000000, MSLP netcdf: 98956.5569847999, wind_mod netcdf: 23.83323861696244
#
# Time tempest dict: 2020-02-23 06:00:00, lat tempest -15.5, lon tempest 90.0,  MSLP tempest: 100003.0, wind_mod tempest: 13.75968
# Time netcdf: 2020-02-23T06:00:00.000000000, MSLP netcdf: 99267.84321061372, wind_mod netcdf: 22.726769866337747
#
# Time tempest dict: 2020-02-23 12:00:00, lat tempest -16.5, lon tempest 90.0,  MSLP tempest: 100046.1, wind_mod tempest: 13.61255
# Time netcdf: 2020-02-23T12:00:00.000000000, MSLP netcdf: 99196.72733292439, wind_mod netcdf: 24.50596293326603
#
# Time tempest dict: 2020-02-23 18:00:00, lat tempest -16.5, lon tempest 89.0,  MSLP tempest: 100179.5, wind_mod tempest: 13.72752
# Time netcdf: 2020-02-23T18:00:00.000000000, MSLP netcdf: 99657.37833203554, wind_mod netcdf: 22.22165781934224
#
# Time tempest dict: 2020-02-24 00:00:00, lat tempest -16.5, lon tempest 89.0,  MSLP tempest: 100149.2, wind_mod tempest: 15.184
# Time netcdf: 2020-02-24T00:00:00.000000000, MSLP netcdf: 99719.33224249049, wind_mod netcdf: 21.19589156356171
#
# Time tempest dict: 2020-02-24 06:00:00, lat tempest -17.5, lon tempest 88.0,  MSLP tempest: 100298.6, wind_mod tempest: 14.08142
# Time netcdf: 2020-02-24T06:00:00.000000000, MSLP netcdf: 99993.07815233043, wind_mod netcdf: 19.41223292029982
#
# Time tempest dict: 2020-02-24 12:00:00, lat tempest -17.5, lon tempest 88.0,  MSLP tempest: 100252.9, wind_mod tempest: 14.54639
# Time netcdf: 2020-02-24T12:00:00.000000000, MSLP netcdf: 99864.61414824515, wind_mod netcdf: 20.184993750001926
#
# Time tempest dict: 2020-02-24 18:00:00, lat tempest -17.5, lon tempest 87.0,  MSLP tempest: 100518.9, wind_mod tempest: 12.87821
# Time netcdf: 2020-02-24T18:00:00.000000000, MSLP netcdf: 100145.56053451342, wind_mod netcdf: 16.782135253940368
#
# Track 2:
# Track Length: 41, Year: 2020, Month: 2, Date: 20, Hour: 18
# Time tempest dict: 2020-02-20 18:00:00, lat tempest -13.5, lon tempest 55.0,  MSLP tempest: 100704.4, wind_mod tempest: 9.542131
# Time netcdf: 2020-02-20T18:00:00.000000000, MSLP netcdf: 100677.99196870603, wind_mod netcdf: 12.122067832148023
#
# Time tempest dict: 2020-02-21 00:00:00, lat tempest -13.5, lon tempest 55.0,  MSLP tempest: 100406.1, wind_mod tempest: 9.663392
# Time netcdf: 2020-02-21T00:00:00.000000000, MSLP netcdf: 100334.2290868956, wind_mod netcdf: 13.81446837373124
#
# Time tempest dict: 2020-02-21 06:00:00, lat tempest -13.5, lon tempest 55.0,  MSLP tempest: 100631.8, wind_mod tempest: 9.23333
# Time netcdf: 2020-02-21T06:00:00.000000000, MSLP netcdf: 100466.25850152467, wind_mod netcdf: 13.866904915040601
#
# Time tempest dict: 2020-02-21 12:00:00, lat tempest -13.5, lon tempest 55.0,  MSLP tempest: 100341.7, wind_mod tempest: 11.27074
# Time netcdf: 2020-02-21T12:00:00.000000000, MSLP netcdf: 100200.1341204635, wind_mod netcdf: 14.481137084154359
#
# Time tempest dict: 2020-02-21 18:00:00, lat tempest -13.5, lon tempest 55.0,  MSLP tempest: 100544.6, wind_mod tempest: 11.80915
# Time netcdf: 2020-02-21T18:00:00.000000000, MSLP netcdf: 100282.36609046663, wind_mod netcdf: 14.195176678141827
#
# Time tempest dict: 2020-02-22 00:00:00, lat tempest -13.5, lon tempest 56.0,  MSLP tempest: 100177.1, wind_mod tempest: 11.63408
# Time netcdf: 2020-02-22T00:00:00.000000000, MSLP netcdf: 99825.89358149352, wind_mod netcdf: 16.311713146656672
#
# Time tempest dict: 2020-02-22 06:00:00, lat tempest -13.5, lon tempest 57.0,  MSLP tempest: 100312.4, wind_mod tempest: 12.57917
# Time netcdf: 2020-02-22T06:00:00.000000000, MSLP netcdf: 99930.2183169733, wind_mod netcdf: 17.723244031518973
#
# Time tempest dict: 2020-02-22 12:00:00, lat tempest -13.5, lon tempest 58.0,  MSLP tempest: 99897.01, wind_mod tempest: 14.11214
# Time netcdf: 2020-02-22T12:00:00.000000000, MSLP netcdf: 99317.63857193335, wind_mod netcdf: 23.56755107316655
#
# Time tempest dict: 2020-02-22 18:00:00, lat tempest -13.5, lon tempest 59.0,  MSLP tempest: 99936.77, wind_mod tempest: 16.52989
# Time netcdf: 2020-02-22T18:00:00.000000000, MSLP netcdf: 99294.91753, wind_mod netcdf: 24.263303680385068
#
# Time tempest dict: 2020-02-23 00:00:00, lat tempest -13.5, lon tempest 60.0,  MSLP tempest: 99354.11, wind_mod tempest: 18.28253
# Time netcdf: 2020-02-23T00:00:00.000000000, MSLP netcdf: 98214.4510154649, wind_mod netcdf: 28.092777291758527
#
# Time tempest dict: 2020-02-23 06:00:00, lat tempest -13.5, lon tempest 61.0,  MSLP tempest: 99458.66, wind_mod tempest: 18.97486
# Time netcdf: 2020-02-23T06:00:00.000000000, MSLP netcdf: 97514.69874181133, wind_mod netcdf: 37.918873103083996
#
# Time tempest dict: 2020-02-23 12:00:00, lat tempest -14.5, lon tempest 63.0,  MSLP tempest: 98776.9, wind_mod tempest: 20.02118
# Time netcdf: 2020-02-23T12:00:00.000000000, MSLP netcdf: 95818.91608265876, wind_mod netcdf: 48.544182922701545
#
# Time tempest dict: 2020-02-23 18:00:00, lat tempest -14.5, lon tempest 63.0,  MSLP tempest: 98549.87, wind_mod tempest: 20.93988
# Time netcdf: 2020-02-23T18:00:00.000000000, MSLP netcdf: 94644.3891007952, wind_mod netcdf: 54.32070957732084
#
# Time tempest dict: 2020-02-24 00:00:00, lat tempest -15.5, lon tempest 64.0,  MSLP tempest: 98035.32, wind_mod tempest: 21.37976
# Time netcdf: 2020-02-24T00:00:00.000000000, MSLP netcdf: 94253.79703306059, wind_mod netcdf: 52.74699551149933
#
# Time tempest dict: 2020-02-24 06:00:00, lat tempest -15.5, lon tempest 64.0,  MSLP tempest: 98740.4, wind_mod tempest: 24.00852
# Time netcdf: 2020-02-24T06:00:00.000000000, MSLP netcdf: 93748.84941042676, wind_mod netcdf: 55.26828034619268
#
# Time tempest dict: 2020-02-24 12:00:00, lat tempest -16.5, lon tempest 65.0,  MSLP tempest: 97648.01, wind_mod tempest: 19.18177
# ...
#
# Time tempest dict: 2021-01-02 12:00:00, lat tempest -22.5, lon tempest 59.0,  MSLP tempest: 99612.47, wind_mod tempest: 17.88116
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2021-01-02 18:00:00, lat tempest -22.5, lon tempest 59.0,  MSLP tempest: 100109.8, wind_mod tempest: 16.50864
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2021-01-03 00:00:00, lat tempest -23.5, lon tempest 59.0,  MSLP tempest: 100056.9, wind_mod tempest: 16.35779
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Track 2:
# Track Length: 38, Year: 2020, Month: 12, Date: 26, Hour: 18
# Time tempest dict: 2020-12-26 18:00:00, lat tempest -8.5, lon tempest 151.0,  MSLP tempest: 100076.1, wind_mod tempest: 10.69938
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-27 00:00:00, lat tempest -9.5, lon tempest 150.0,  MSLP tempest: 100365.0, wind_mod tempest: 11.42293
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-27 06:00:00, lat tempest -10.5, lon tempest 149.0,  MSLP tempest: 100112.3, wind_mod tempest: 13.2001
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-27 12:00:00, lat tempest -12.5, lon tempest 148.0,  MSLP tempest: 100277.1, wind_mod tempest: 14.19233
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-27 18:00:00, lat tempest -12.5, lon tempest 146.0,  MSLP tempest: 99951.12, wind_mod tempest: 15.11417
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-28 00:00:00, lat tempest -12.5, lon tempest 144.0,  MSLP tempest: 100060.7, wind_mod tempest: 14.45516
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-28 06:00:00, lat tempest -11.5, lon tempest 143.0,  MSLP tempest: 99727.43, wind_mod tempest: 13.83218
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-28 12:00:00, lat tempest -12.5, lon tempest 144.0,  MSLP tempest: 99998.88, wind_mod tempest: 13.71113
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-28 18:00:00, lat tempest -12.5, lon tempest 141.0,  MSLP tempest: 99670.25, wind_mod tempest: 14.29494
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-29 00:00:00, lat tempest -12.5, lon tempest 140.0,  MSLP tempest: 99504.59, wind_mod tempest: 16.87107
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-29 06:00:00, lat tempest -12.5, lon tempest 139.0,  MSLP tempest: 98864.04, wind_mod tempest: 18.37095
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-29 12:00:00, lat tempest -12.5, lon tempest 138.0,  MSLP tempest: 98770.55, wind_mod tempest: 20.10102
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-29 18:00:00, lat tempest -12.5, lon tempest 138.0,  MSLP tempest: 98127.94, wind_mod tempest: 23.87857
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-30 00:00:00, lat tempest -12.5, lon tempest 137.0,  MSLP tempest: 97359.48, wind_mod tempest: 22.38129
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-30 06:00:00, lat tempest -13.5, lon tempest 136.0,  MSLP tempest: 97735.05, wind_mod tempest: 22.13485
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-30 12:00:00, lat tempest -13.5, lon tempest 135.0,  MSLP tempest: 98173.62, wind_mod tempest: 20.75479
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-30 18:00:00, lat tempest -14.5, lon tempest 134.0,  MSLP tempest: 98100.8, wind_mod tempest: 14.82698
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-31 00:00:00, lat tempest -15.5, lon tempest 133.0,  MSLP tempest: 98792.35, wind_mod tempest: 11.92845
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-31 06:00:00, lat tempest -16.5, lon tempest 132.0,  MSLP tempest: 99037.65, wind_mod tempest: 12.73868
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-31 12:00:00, lat tempest -16.5, lon tempest 131.0,  MSLP tempest: 99165.52, wind_mod tempest: 12.161
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2020-12-31 18:00:00, lat tempest -16.5, lon tempest 129.0,  MSLP tempest: 99290.87, wind_mod tempest: 10.51137
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2021-01-01 00:00:00, lat tempest -16.5, lon tempest 128.0,  MSLP tempest: 99464.92, wind_mod tempest: 9.547765
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2021-01-01 06:00:00, lat tempest -16.5, lon tempest 128.0,  MSLP tempest: 99205.3, wind_mod tempest: 10.67149
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2021-01-01 12:00:00, lat tempest -17.5, lon tempest 127.0,  MSLP tempest: 99543.91, wind_mod tempest: 10.74904
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2021-01-01 18:00:00, lat tempest -18.5, lon tempest 126.0,  MSLP tempest: 99151.16, wind_mod tempest: 13.28844
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 100328.92349783942, wind_mod netcdf: 9.400814646931412
#
# Time tempest dict: 2021-01-02 00:00:00, lat tempest -18.5, lon tempest 125.0,  MSLP tempest: 99396.73, wind_mod tempest: 14.53906
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 100205.47143343004, wind_mod netcdf: 10.094862085402147
#
# Time tempest dict: 2021-01-02 06:00:00, lat tempest -18.5, lon tempest 125.0,  MSLP tempest: 99216.16, wind_mod tempest: 12.46568
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 100205.47143343004, wind_mod netcdf: 10.094862085402147
#
# Time tempest dict: 2021-01-02 12:00:00, lat tempest -18.5, lon tempest 124.0,  MSLP tempest: 99311.38, wind_mod tempest: 10.90202
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 100031.7986637261, wind_mod netcdf: 11.90408867458011
#
# Time tempest dict: 2021-01-02 18:00:00, lat tempest -18.5, lon tempest 124.0,  MSLP tempest: 99147.8, wind_mod tempest: 11.00029
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 100031.7986637261, wind_mod netcdf: 11.90408867458011
#
# Time tempest dict: 2021-01-03 00:00:00, lat tempest -19.5, lon tempest 123.0,  MSLP tempest: 99380.55, wind_mod tempest: 12.69711
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 99956.64208668709, wind_mod netcdf: 13.784302494870763
#
# Time tempest dict: 2021-01-03 06:00:00, lat tempest -19.5, lon tempest 123.0,  MSLP tempest: 99166.45, wind_mod tempest: 10.98361
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 99956.64208668709, wind_mod netcdf: 13.784302494870763
#
# Time tempest dict: 2021-01-03 12:00:00, lat tempest -20.5, lon tempest 122.0,  MSLP tempest: 99299.23, wind_mod tempest: 11.77628
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 99900.5699218711, wind_mod netcdf: 13.526382836127175
#
# Time tempest dict: 2021-01-03 18:00:00, lat tempest -21.5, lon tempest 122.0,  MSLP tempest: 99194.22, wind_mod tempest: 13.66475
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 100151.05195054601, wind_mod netcdf: 12.35523433773623
#
# Time tempest dict: 2021-01-04 00:00:00, lat tempest -21.5, lon tempest 121.0,  MSLP tempest: 99414.09, wind_mod tempest: 10.97389
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 100087.63393211566, wind_mod netcdf: 12.828622811257919
#
# Time tempest dict: 2021-01-04 06:00:00, lat tempest -22.5, lon tempest 121.0,  MSLP tempest: 99412.44, wind_mod tempest: 10.72091
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 100224.51581113836, wind_mod netcdf: 10.529652399690749
#
# Time tempest dict: 2021-01-04 12:00:00, lat tempest -23.5, lon tempest 121.0,  MSLP tempest: 99718.8, wind_mod tempest: 8.8788
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 100405.19712386624, wind_mod netcdf: 9.95466421334865
#
# Time tempest dict: 2021-01-04 18:00:00, lat tempest -24.5, lon tempest 120.0,  MSLP tempest: 99679.32, wind_mod tempest: 9.355392
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Time tempest dict: 2021-01-05 00:00:00, lat tempest -26.5, lon tempest 120.0,  MSLP tempest: 99893.4, wind_mod tempest: 9.144801
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: nan, wind_mod netcdf: nan
#
# Track 3:
# Track Length: 14, Year: 2021, Month: 1, Date: 12, Hour: 12
# Time tempest dict: 2021-01-12 12:00:00, lat tempest -14.5, lon tempest 118.0,  MSLP tempest: 99895.39, wind_mod tempest: 12.50254
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 98939.91430486778, wind_mod netcdf: 20.783862752259676
#
# Time tempest dict: 2021-01-12 18:00:00, lat tempest -14.5, lon tempest 118.0,  MSLP tempest: 99704.95, wind_mod tempest: 10.45736
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 98939.91430486778, wind_mod netcdf: 20.783862752259676
#
# Time tempest dict: 2021-01-13 00:00:00, lat tempest -14.5, lon tempest 118.0,  MSLP tempest: 99634.75, wind_mod tempest: 11.80611
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 98939.91430486778, wind_mod netcdf: 20.783862752259676
#
# Time tempest dict: 2021-01-13 06:00:00, lat tempest -14.5, lon tempest 118.0,  MSLP tempest: 99428.53, wind_mod tempest: 13.80305
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 98939.91430486778, wind_mod netcdf: 20.783862752259676
#
# Time tempest dict: 2021-01-13 12:00:00, lat tempest -14.5, lon tempest 118.0,  MSLP tempest: 99412.48, wind_mod tempest: 13.86901
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 98939.91430486778, wind_mod netcdf: 20.783862752259676
#
# Time tempest dict: 2021-01-13 18:00:00, lat tempest -15.5, lon tempest 118.0,  MSLP tempest: 99139.12, wind_mod tempest: 13.64164
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 98939.91430486778, wind_mod netcdf: 19.486944762841873
#
# Time tempest dict: 2021-01-14 00:00:00, lat tempest -15.5, lon tempest 119.0,  MSLP tempest: 99162.68, wind_mod tempest: 16.64938
# Time netcdf: 2021-01-14T00:00:00.000000000, MSLP netcdf: 98939.91430486778, wind_mod netcdf: 19.486944762841873
#
# Time tempest dict: 2021-01-14 06:00:00, lat tempest -16.5, lon tempest 118.0,  MSLP tempest: 98823.72, wind_mod tempest: 15.86307
# Time netcdf: 2021-01-14T06:00:00.000000000, MSLP netcdf: 98384.46821847242, wind_mod netcdf: 24.15718597707672
#
# Time tempest dict: 2021-01-14 12:00:00, lat tempest -16.5, lon tempest 119.0,  MSLP tempest: 98774.73, wind_mod tempest: 18.10712
# Time netcdf: 2021-01-14T12:00:00.000000000, MSLP netcdf: 98502.84785472925, wind_mod netcdf: 22.265727632247025
#
# Time tempest dict: 2021-01-14 18:00:00, lat tempest -17.5, lon tempest 119.0,  MSLP tempest: 98362.14, wind_mod tempest: 18.12226
# Time netcdf: 2021-01-14T18:00:00.000000000, MSLP netcdf: 98173.82367373635, wind_mod netcdf: 24.156651298975813
#
# Time tempest dict: 2021-01-15 00:00:00, lat tempest -17.5, lon tempest 119.0,  MSLP tempest: 98159.3, wind_mod tempest: 19.74123
# Time netcdf: 2021-01-15T00:00:00.000000000, MSLP netcdf: 97783.66473854738, wind_mod netcdf: 26.618285312269002
#
# Time tempest dict: 2021-01-15 06:00:00, lat tempest -18.5, lon tempest 119.0,  MSLP tempest: 97736.63, wind_mod tempest: 20.74904
# Time netcdf: 2021-01-15T06:00:00.000000000, MSLP netcdf: 97208.15173719409, wind_mod netcdf: 27.568864099754865
#
# Time tempest dict: 2021-01-15 12:00:00, lat tempest -19.5, lon tempest 118.0,  MSLP tempest: 97953.85, wind_mod tempest: 19.94894
# Time netcdf: 2021-01-15T12:00:00.000000000, MSLP netcdf: 97246.77398569114, wind_mod netcdf: 25.627249469473643
#
# Time tempest dict: 2021-01-15 18:00:00, lat tempest -19.5, lon tempest 118.0,  MSLP tempest: 97746.19, wind_mod tempest: 20.20782
# Time netcdf: 2021-01-15T18:00:00.000000000, MSLP netcdf: 97129.36876152866, wind_mod netcdf: 26.01939995956848
#
# Created /home/b/b382216/work/tc/fullres/IFS/tco2559-ng5-cycle3/tempest_fullres_txt/fullres_tempest_track_20201215-20210113.txt
# Opened tempest file: /home/b/b382216/work/tc/tmpdir/IFS/tco2559-ng5-cycle3/tempest_track_20210114-20210212.txt
# Opened NetCDF file: /home/b/b382216/work/tc/fullres/IFS/tco2559-ng5-cycle3/tempest_tracks_20210213-20210314.nc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/b/b382216/AQUA/diagnostics/tropical_cyclones/notebooks/cat_histogram_fullres.ipynb Cell 7 line 8
#      <a href='vscode-notebook-cell://ssh-remote%2Blevante.dkrz.de/home/b/b382216/AQUA/diagnostics/tropical_cyclones/notebooks/cat_histogram_fullres.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=79'>80</a> print("Opened NetCDF file:", fullres_file_path)
#      <a href='vscode-notebook-cell://ssh-remote%2Blevante.dkrz.de/home/b/b382216/AQUA/diagnostics/tropical_cyclones/notebooks/cat_histogram_fullres.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=81'>82</a> #compute wind module
# ---> <a href='vscode-notebook-cell://ssh-remote%2Blevante.dkrz.de/home/b/b382216/AQUA/diagnostics/tropical_cyclones/notebooks/cat_histogram_fullres.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=82'>83</a> wind_mod= (u10**2+v10**2)**0.5
#      <a href='vscode-notebook-cell://ssh-remote%2Blevante.dkrz.de/home/b/b382216/AQUA/diagnostics/tropical_cyclones/notebooks/cat_histogram_fullres.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=83'>84</a> # Parse the corresponding text file
#      <a href='vscode-notebook-cell://ssh-remote%2Blevante.dkrz.de/home/b/b382216/AQUA/diagnostics/tropical_cyclones/notebooks/cat_histogram_fullres.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=84'>85</a> parsed_results = parse_text_file(tempest_file_path)
#
# File /work/bb1153/b382216/mambaforge/envs/aqua/lib/python3.10/site-packages/xarray/core/_typed_ops.py:231, in DataArrayOpsMixin.__pow__(self, other)
#     230 def __pow__(self, other):
# --> 231     return self._binary_op(other, operator.pow)
#
# File /work/bb1153/b382216/mambaforge/envs/aqua/lib/python3.10/site-packages/xarray/core/dataarray.py:4620, in DataArray._binary_op(self, other, f, reflexive)
#    4616 other_variable = getattr(other, "variable", other)
#    4617 other_coords = getattr(other, "coords", None)
#    4619 variable = (
# -> 4620     f(self.variable, other_variable)
#    4621     if not reflexive
#    4622     else f(other_variable, self.variable)
#    4623 )
#    4624 coords, indexes = self.coords._merge_raw(other_coords, reflexive)
#    4625 name = self._result_name(other)
#
# File /work/bb1153/b382216/mambaforge/envs/aqua/lib/python3.10/site-packages/xarray/core/_typed_ops.py:437, in VariableOpsMixin.__pow__(self, other)
#     436 def __pow__(self, other):
# --> 437     return self._binary_op(other, operator.pow)
#
# File /work/bb1153/b382216/mambaforge/envs/aqua/lib/python3.10/site-packages/xarray/core/variable.py:2705, in Variable._binary_op(self, other, f, reflexive)
#    2702 attrs = self._attrs if keep_attrs else None
#    2703 with np.errstate(all="ignore"):
#    2704     new_data = (
# -> 2705         f(self_data, other_data) if not reflexive else f(other_data, self_data)
#    2706     )
#    2707 result = Variable(dims, new_data, attrs=attrs)
#    2708 return result
#
# KeyboardInterrupt:

# %%
# Directory where the NetCDF files are located
fullres_data_directory = '/home/b/b382216/work/tc/fullres/IFS/tco1279-orca025-cycle3/'

# Directory with tempest (Stitch nodes) output track files
tempest_data_directory = '/home/b/b382216/work/tc/tmpdir/IFS/tco1279-orca025-cycle3/'

# Pattern to match NetCDF files
fullres_file_pattern = 'tempest_tracks_*.nc'

# Pattern to match tempest txt files
tempest_file_pattern = 'tempest_track_*.txt'

# Output directory for the new .txt files with fullres data
output_directory = '/home/b/b382216/work/tc/fullres/IFS/tco1279-orca025-cycle3/tempest_fullres_txt'


# Find and process all matching files
fullres_file_paths = sorted(glob.glob(os.path.join(fullres_data_directory, fullres_file_pattern)))
tempest_file_paths = sorted(glob.glob(os.path.join(tempest_data_directory, tempest_file_pattern)))

# List to store data arrays
data_arrays = []

# Initialize a list to store track headers
track_headers = []

# Define a function to parse the text data and separate tracks
def parse_text_file(file_path):
    data = []  # Create an empty list to store the data
    track_data = []  # List to store data for the current track
    track_header = None

    with open(file_path, 'r') as file:
        for line in file:
            parts = line.split()
            if not parts:
                continue  # Skip empty lines

            if parts[0] == 'start':
                if track_header is not None:
                    data.append((track_header, track_data))  # Add track header and data to the result
                track_header = {
                    'track_length': int(parts[1]),
                    'year': int(parts[2]),
                    'month': int(parts[3]),
                    'date': int(parts[4]),
                    'hour': int(parts[5])
                }
                track_data = []
            else:
                if track_header is not None:
                    entry = {
                        'lon_index': int(parts[0]),
                        'lat_index': int(parts[1]),
                        'longitude': float(parts[2]),
                        'latitude': float(parts[3]),
                        'year': int(parts[6]),
                        'month': int(parts[7]),
                        'date': int(parts[8]),
                        'hour': int(parts[9]),
                        'mslp': float(parts[4]),  # Assuming MSLP is in the 4th position
                        'wind_module': float(parts[5])  # Assuming wind module is in the 5th position
                    }
                    track_data.append(entry)

    if track_data:  # Add the last track header and data if not empty
        data.append((track_header, track_data))

    return data

# Loop through the NetCDF files and the corresponding text files
for fullres_file_path in (fullres_file_paths):
    date_string = fullres_file_path.split('_')[-1].split('.')[0]  # Extract the last part after the last '_' and before the '.nc'
    tempest_file_path = tempest_data_directory + "tempest_track_" + date_string + ".txt"
    # Open the NetCDF file
    dataset = xr.open_dataset(fullres_file_path)
    mslp = dataset['msl']
    u10 = dataset['10u']
    v10 = dataset['10v']
    time_nc = dataset['time']
    print("Opened tempest file:", tempest_file_path)
    print("Opened NetCDF file:", fullres_file_path)

    #compute wind module
    wind_mod= (u10**2+v10**2)**0.5
    # Parse the corresponding text file
    parsed_results = parse_text_file(tempest_file_path)
    updated_lines = []
    # Loop through parsed results and print variables at each time step
    for i, (track_header, result) in enumerate(parsed_results):
        print(f"Track {i + 1}:")

        # Print the track header information
        print(f"Track Length: {track_header['track_length']}, Year: {track_header['year']}, Month: {track_header['month']}, Date: {track_header['date']}, Hour: {track_header['hour']}")

        # Write the track header information to the new .txt file
        header_line = f"start {track_header['track_length']} {track_header['year']} {track_header['month']} {track_header['date']} {track_header['hour']}\n"
        updated_lines.append(header_line)

        for entry in result:
            lon = entry['longitude']
            lat = entry['latitude']
            year = entry['year']
            month = entry['month']
            date = entry['date']
            hour = entry['hour']
            mslp_tempest = entry['mslp']
            wind_mod_tempest = entry['wind_module']

            # create a time stamp with the date in the tempest file/dict

            time_stamp = datetime(year, month, date, hour, 0, 0)
            # open the netcdf file at 
            mslp_time = mslp.sel(time=time_stamp, method="nearest")
            mslp_value = np.min(mslp_time.sel(lat=slice(lat-2,lat+2), lon=slice(lon-2,lon+2)).values)
            wind_mod_time = wind_mod.sel(time=time_stamp, method="nearest")
            wind_mod_value = np.max(wind_mod_time.sel(lat=slice(lat-2,lat+2), lon=slice(lon-2,lon+2)).values)


            print(f"Time tempest dict: {time_stamp}, lat tempest {lat}, lon tempest {lon},  MSLP tempest: {mslp_tempest}, wind_mod tempest: {wind_mod_tempest}")
            print(f"Time netcdf: {time_nc.sel(time=time_stamp, method='nearest').values}, MSLP netcdf: {mslp_value}, wind_mod netcdf: {wind_mod_value}\n")

            entry['mslp'] = mslp_value
            entry['wind_module'] = wind_mod_value

            entry_line = f"{entry['lon_index']} {entry['lat_index']} {entry['longitude']} {entry['latitude']} {entry['mslp']} {entry['wind_module']} {entry['year']} {entry['month']} {entry['date']} {entry['hour']}\n"
            updated_lines.append(entry_line)

    filename = os.path.basename(tempest_file_path)
    new_filename = f"fullres_{filename}"  # Add "fullres_" as a prefix to the original filename
    new_file_path = os.path.join(output_directory, new_filename)
    with open(new_file_path, 'w') as new_file:
        new_file.writelines(updated_lines)
    print(f"Created {new_file_path}")
        

    dataset.close()
# Out:
# Opened tempest file: /home/b/b382216/work/tc/tmpdir/IFS/tco1279-orca025-cycle3/tempest_track_20200120-20200218.txt
# Opened NetCDF file: /home/b/b382216/work/tc/fullres/IFS/tco1279-orca025-cycle3/tempest_tracks_20200120-20200218.nc
# Track 1:
# Track Length: 15, Year: 2020, Month: 1, Date: 23, Hour: 18
# Time tempest dict: 2020-01-23 18:00:00, lat tempest -20.5, lon tempest 60.0,  MSLP tempest: 100381.9, wind_mod tempest: 13.46387
# Time netcdf: 2020-01-23T18:00:00.000000000, MSLP netcdf: 100308.1419771099, wind_mod netcdf: 15.815569921179678
#
# Time tempest dict: 2020-01-24 00:00:00, lat tempest -20.5, lon tempest 62.0,  MSLP tempest: 100146.6, wind_mod tempest: 14.5857
# Time netcdf: 2020-01-24T00:00:00.000000000, MSLP netcdf: 99956.2009060352, wind_mod netcdf: 16.218624408233445
#
# Time tempest dict: 2020-01-24 06:00:00, lat tempest -21.5, lon tempest 63.0,  MSLP tempest: 100399.2, wind_mod tempest: 13.37549
# Time netcdf: 2020-01-24T06:00:00.000000000, MSLP netcdf: 100201.03295385485, wind_mod netcdf: 15.298191785913842
#
# Time tempest dict: 2020-01-24 12:00:00, lat tempest -21.5, lon tempest 64.0,  MSLP tempest: 100135.5, wind_mod tempest: 13.55375
# Time netcdf: 2020-01-24T12:00:00.000000000, MSLP netcdf: 99947.99604061643, wind_mod netcdf: 16.437461485653458
#
# Time tempest dict: 2020-01-24 18:00:00, lat tempest -21.5, lon tempest 65.0,  MSLP tempest: 100334.4, wind_mod tempest: 12.11279
# Time netcdf: 2020-01-24T18:00:00.000000000, MSLP netcdf: 100135.04452378886, wind_mod netcdf: 14.359840417471064
#
# Time tempest dict: 2020-01-25 00:00:00, lat tempest -22.5, lon tempest 66.0,  MSLP tempest: 100044.0, wind_mod tempest: 13.23459
# Time netcdf: 2020-01-25T00:00:00.000000000, MSLP netcdf: 99859.82620580772, wind_mod netcdf: 14.780424188731704
#
# Time tempest dict: 2020-01-25 06:00:00, lat tempest -22.5, lon tempest 67.0,  MSLP tempest: 100159.4, wind_mod tempest: 12.75797
# Time netcdf: 2020-01-25T06:00:00.000000000, MSLP netcdf: 99989.05280293703, wind_mod netcdf: 14.668469749244782
#
# Time tempest dict: 2020-01-25 12:00:00, lat tempest -23.5, lon tempest 68.0,  MSLP tempest: 100038.4, wind_mod tempest: 13.59411
# Time netcdf: 2020-01-25T12:00:00.000000000, MSLP netcdf: 99725.83539950948, wind_mod netcdf: 15.670095175543
#
# Time tempest dict: 2020-01-25 18:00:00, lat tempest -23.5, lon tempest 69.0,  MSLP tempest: 100099.2, wind_mod tempest: 13.53479
# Time netcdf: 2020-01-25T18:00:00.000000000, MSLP netcdf: 99714.55430961959, wind_mod netcdf: 16.415620561656755
#
# Time tempest dict: 2020-01-26 00:00:00, lat tempest -23.5, lon tempest 70.0,  MSLP tempest: 99753.29, wind_mod tempest: 12.43697
# Time netcdf: 2020-01-26T00:00:00.000000000, MSLP netcdf: 99472.89504977172, wind_mod netcdf: 16.531550625577513
#
# Time tempest dict: 2020-01-26 06:00:00, lat tempest -23.5, lon tempest 71.0,  MSLP tempest: 99809.31, wind_mod tempest: 14.63395
# Time netcdf: 2020-01-26T06:00:00.000000000, MSLP netcdf: 99576.76077490694, wind_mod netcdf: 16.001658328425012
#
# Time tempest dict: 2020-01-26 12:00:00, lat tempest -23.5, lon tempest 72.0,  MSLP tempest: 99612.02, wind_mod tempest: 15.47487
# Time netcdf: 2020-01-26T12:00:00.000000000, MSLP netcdf: 99412.45232588954, wind_mod netcdf: 17.250571341961276
#
# Time tempest dict: 2020-01-26 18:00:00, lat tempest -23.5, lon tempest 73.0,  MSLP tempest: 99750.88, wind_mod tempest: 15.66315
# Time netcdf: 2020-01-26T18:00:00.000000000, MSLP netcdf: 99606.43423305888, wind_mod netcdf: 17.560877910149824
#
# Time tempest dict: 2020-01-27 00:00:00, lat tempest -23.5, lon tempest 74.0,  MSLP tempest: 99601.04, wind_mod tempest: 16.41759
# Time netcdf: 2020-01-27T00:00:00.000000000, MSLP netcdf: 99465.00356930261, wind_mod netcdf: 17.63592557676055
#
# Time tempest dict: 2020-01-27 06:00:00, lat tempest -23.5, lon tempest 75.0,  MSLP tempest: 99770.73, wind_mod tempest: 16.16658
# Time netcdf: 2020-01-27T06:00:00.000000000, MSLP netcdf: 99627.51502111576, wind_mod netcdf: 17.743981276857436
#
# Track 2:
# Track Length: 10, Year: 2020, Month: 2, Date: 5, Hour: 12
# Time tempest dict: 2020-02-05 12:00:00, lat tempest -16.5, lon tempest 75.0,  MSLP tempest: 100004.0, wind_mod tempest: 12.69253
# Time netcdf: 2020-02-05T12:00:00.000000000, MSLP netcdf: 99971.60508607508, wind_mod netcdf: 14.10368013174533
#
# Time tempest dict: 2020-02-05 18:00:00, lat tempest -16.5, lon tempest 75.0,  MSLP tempest: 100141.7, wind_mod tempest: 13.38372
# Time netcdf: 2020-02-05T18:00:00.000000000, MSLP netcdf: 100121.55709430805, wind_mod netcdf: 14.334074929096756
#
# Time tempest dict: 2020-02-06 00:00:00, lat tempest -16.5, lon tempest 75.0,  MSLP tempest: 99821.56, wind_mod tempest: 13.80414
# Time netcdf: 2020-02-06T00:00:00.000000000, MSLP netcdf: 99790.35749047877, wind_mod netcdf: 15.796440779303962
#
# Time tempest dict: 2020-02-06 06:00:00, lat tempest -17.5, lon tempest 75.0,  MSLP tempest: 99875.51, wind_mod tempest: 15.08766
# Time netcdf: 2020-02-06T06:00:00.000000000, MSLP netcdf: 99846.93527942536, wind_mod netcdf: 16.149433594977427
#
# Time tempest dict: 2020-02-06 12:00:00, lat tempest -17.5, lon tempest 75.0,  MSLP tempest: 99577.76, wind_mod tempest: 15.17062
# Time netcdf: 2020-02-06T12:00:00.000000000, MSLP netcdf: 99546.30110730842, wind_mod netcdf: 16.680291590059593
#
# Time tempest dict: 2020-02-06 18:00:00, lat tempest -17.5, lon tempest 75.0,  MSLP tempest: 99766.12, wind_mod tempest: 14.99136
# Time netcdf: 2020-02-06T18:00:00.000000000, MSLP netcdf: 99744.76535059117, wind_mod netcdf: 16.10117088295478
#
# Time tempest dict: 2020-02-07 00:00:00, lat tempest -16.5, lon tempest 75.0,  MSLP tempest: 99457.79, wind_mod tempest: 14.01257
# Time netcdf: 2020-02-07T00:00:00.000000000, MSLP netcdf: 99432.17611255594, wind_mod netcdf: 16.813659460968637
#
# Time tempest dict: 2020-02-07 06:00:00, lat tempest -17.5, lon tempest 76.0,  MSLP tempest: 99534.58, wind_mod tempest: 12.59347
# Time netcdf: 2020-02-07T06:00:00.000000000, MSLP netcdf: 99510.48315829958, wind_mod netcdf: 19.383340469801603
#
# Time tempest dict: 2020-02-07 12:00:00, lat tempest -17.5, lon tempest 76.0,  MSLP tempest: 99320.66, wind_mod tempest: 15.03829
# Time netcdf: 2020-02-07T12:00:00.000000000, MSLP netcdf: 99296.67388627103, wind_mod netcdf: 21.514540640758185
#
# Time tempest dict: 2020-02-07 18:00:00, lat tempest -18.5, lon tempest 76.0,  MSLP tempest: 99477.93, wind_mod tempest: 16.78711
# Time netcdf: 2020-02-07T18:00:00.000000000, MSLP netcdf: 99452.35222226231, wind_mod netcdf: 22.550229039118015
#
# Track 3:
# Track Length: 19, Year: 2020, Month: 2, Date: 8, Hour: 6
# Time tempest dict: 2020-02-08 06:00:00, lat tempest -19.5, lon tempest 75.0,  MSLP tempest: 99314.82, wind_mod tempest: 18.20776
# Time netcdf: 2020-02-08T06:00:00.000000000, MSLP netcdf: 99300.09876976834, wind_mod netcdf: 23.432096696687243
#
# Time tempest dict: 2020-02-08 12:00:00, lat tempest -18.5, lon tempest 75.0,  MSLP tempest: 99070.6, wind_mod tempest: 15.67327
# Time netcdf: 2020-02-08T12:00:00.000000000, MSLP netcdf: 99052.65895093484, wind_mod netcdf: 17.53226963578182
#
# Time tempest dict: 2020-02-08 18:00:00, lat tempest -20.5, lon tempest 73.0,  MSLP tempest: 99283.52, wind_mod tempest: 18.20957
# Time netcdf: 2020-02-08T18:00:00.000000000, MSLP netcdf: 99222.56998377833, wind_mod netcdf: 23.553991432893127
#
# Time tempest dict: 2020-02-09 00:00:00, lat tempest -19.5, lon tempest 73.0,  MSLP tempest: 99024.71, wind_mod tempest: 15.18231
# Time netcdf: 2020-02-09T00:00:00.000000000, MSLP netcdf: 98947.23301983038, wind_mod netcdf: 16.556203274652585
#
# Time tempest dict: 2020-02-09 06:00:00, lat tempest -20.5, lon tempest 72.0,  MSLP tempest: 99142.17, wind_mod tempest: 14.55183
# Time netcdf: 2020-02-09T06:00:00.000000000, MSLP netcdf: 99118.34876211622, wind_mod netcdf: 19.431562075445235
#
# Time tempest dict: 2020-02-09 12:00:00, lat tempest -20.5, lon tempest 71.0,  MSLP tempest: 98981.4, wind_mod tempest: 14.46044
# Time netcdf: 2020-02-09T12:00:00.000000000, MSLP netcdf: 98947.30952566286, wind_mod netcdf: 18.316598590920485
#
# Time tempest dict: 2020-02-09 18:00:00, lat tempest -20.5, lon tempest 70.0,  MSLP tempest: 99173.09, wind_mod tempest: 15.08185
# Time netcdf: 2020-02-09T18:00:00.000000000, MSLP netcdf: 99128.90088450222, wind_mod netcdf: 19.833283162357862
#
# Time tempest dict: 2020-02-10 00:00:00, lat tempest -20.5, lon tempest 70.0,  MSLP tempest: 98935.59, wind_mod tempest: 12.58326
# Time netcdf: 2020-02-10T00:00:00.000000000, MSLP netcdf: 98893.69000401377, wind_mod netcdf: 19.111807520755267
#
# Time tempest dict: 2020-02-10 06:00:00, lat tempest -20.5, lon tempest 70.0,  MSLP tempest: 99085.47, wind_mod tempest: 14.35067
# Time netcdf: 2020-02-10T06:00:00.000000000, MSLP netcdf: 99058.91688663852, wind_mod netcdf: 18.11905544183193
#
# Time tempest dict: 2020-02-10 12:00:00, lat tempest -21.5, lon tempest 69.0,  MSLP tempest: 98945.61, wind_mod tempest: 15.75206
# Time netcdf: 2020-02-10T12:00:00.000000000, MSLP netcdf: 98907.68524154475, wind_mod netcdf: 20.0130777431253
#
# Time tempest dict: 2020-02-10 18:00:00, lat tempest -22.5, lon tempest 68.0,  MSLP tempest: 99147.98, wind_mod tempest: 16.84468
# Time netcdf: 2020-02-10T18:00:00.000000000, MSLP netcdf: 99110.8528251271, wind_mod netcdf: 21.87830903179869
#
# Time tempest dict: 2020-02-11 00:00:00, lat tempest -23.5, lon tempest 68.0,  MSLP tempest: 98976.32, wind_mod tempest: 17.30559
# Time netcdf: 2020-02-11T00:00:00.000000000, MSLP netcdf: 98878.81428543542, wind_mod netcdf: 23.446715070771106
#
# Time tempest dict: 2020-02-11 06:00:00, lat tempest -24.5, lon tempest 68.0,  MSLP tempest: 99130.99, wind_mod tempest: 17.69038
# Time netcdf: 2020-02-11T06:00:00.000000000, MSLP netcdf: 98975.93870593052, wind_mod netcdf: 21.41247960961444
#
# Time tempest dict: 2020-02-11 12:00:00, lat tempest -26.5, lon tempest 67.0,  MSLP tempest: 99066.9, wind_mod tempest: 17.53162
# Time netcdf: 2020-02-11T12:00:00.000000000, MSLP netcdf: 98998.6075754811, wind_mod netcdf: 19.5992541627093
#
# Time tempest dict: 2020-02-11 18:00:00, lat tempest -27.5, lon tempest 67.0,  MSLP tempest: 99175.45, wind_mod tempest: 18.3968
# Time netcdf: 2020-02-11T18:00:00.000000000, MSLP netcdf: 99023.65452578869, wind_mod netcdf: 21.14991883591003
#
# Time tempest dict: 2020-02-12 00:00:00, lat tempest -29.5, lon tempest 67.0,  MSLP tempest: 99149.83, wind_mod tempest: 18.9938
# Time netcdf: 2020-02-12T00:00:00.000000000, MSLP netcdf: 99083.49079695993, wind_mod netcdf: 20.41463511155241
#
# Time tempest dict: 2020-02-12 06:00:00, lat tempest -31.5, lon tempest 67.0,  MSLP tempest: 99293.91, wind_mod tempest: 19.17264
# Time netcdf: 2020-02-12T06:00:00.000000000, MSLP netcdf: 99237.86630314823, wind_mod netcdf: 23.199298797780298
#
# Time tempest dict: 2020-02-12 12:00:00, lat tempest -33.5, lon tempest 66.0,  MSLP tempest: 98890.88, wind_mod tempest: 21.07478
# Time netcdf: 2020-02-12T12:00:00.000000000, MSLP netcdf: 98860.6598557184, wind_mod netcdf: 25.01261123658872
#
# Time tempest dict: 2020-02-12 18:00:00, lat tempest -34.5, lon tempest 65.0,  MSLP tempest: 98670.0, wind_mod tempest: 22.8347
# Time netcdf: 2020-02-12T18:00:00.000000000, MSLP netcdf: 98554.83196147163, wind_mod netcdf: 27.001831804691026
#
# Track 4:
# Track Length: 21, Year: 2020, Month: 2, Date: 9, Hour: 12
# Time tempest dict: 2020-02-09 12:00:00, lat tempest -13.5, lon tempest 166.0,  MSLP tempest: 100005.7, wind_mod tempest: 10.94893
# Time netcdf: 2020-02-09T12:00:00.000000000, MSLP netcdf: 99968.69563150781, wind_mod netcdf: 13.786845546092312
#
# Time tempest dict: 2020-02-09 18:00:00, lat tempest -14.5, lon tempest 166.0,  MSLP tempest: 99754.09, wind_mod tempest: 10.90272
# Time netcdf: 2020-02-09T18:00:00.000000000, MSLP netcdf: 99739.10997472891, wind_mod netcdf: 13.506322627030908
#
# Time tempest dict: 2020-02-10 00:00:00, lat tempest -15.5, lon tempest 166.0,  MSLP tempest: 99881.56, wind_mod tempest: 10.38504
# Time netcdf: 2020-02-10T00:00:00.000000000, MSLP netcdf: 99864.19497225033, wind_mod netcdf: 14.495238977477246
#
# Time tempest dict: 2020-02-10 06:00:00, lat tempest -15.5, lon tempest 166.0,  MSLP tempest: 99619.47, wind_mod tempest: 11.23603
# Time netcdf: 2020-02-10T06:00:00.000000000, MSLP netcdf: 99599.72177428448, wind_mod netcdf: 15.170477092637427
#
# Time tempest dict: 2020-02-10 12:00:00, lat tempest -16.5, lon tempest 166.0,  MSLP tempest: 99756.6, wind_mod tempest: 14.40508
# Time netcdf: 2020-02-10T12:00:00.000000000, MSLP netcdf: 99700.12544877417, wind_mod netcdf: 16.565468722632698
#
# Time tempest dict: 2020-02-10 18:00:00, lat tempest -16.5, lon tempest 166.0,  MSLP tempest: 99391.36, wind_mod tempest: 16.34674
# Time netcdf: 2020-02-10T18:00:00.000000000, MSLP netcdf: 99352.42768303359, wind_mod netcdf: 18.067964828344042
#
# Time tempest dict: 2020-02-11 00:00:00, lat tempest -17.5, lon tempest 165.0,  MSLP tempest: 99462.73, wind_mod tempest: 16.51345
# Time netcdf: 2020-02-11T00:00:00.000000000, MSLP netcdf: 99405.09074134703, wind_mod netcdf: 22.632379629981813
#
# Time tempest dict: 2020-02-11 06:00:00, lat tempest -17.5, lon tempest 165.0,  MSLP tempest: 99135.53, wind_mod tempest: 18.93531
# Time netcdf: 2020-02-11T06:00:00.000000000, MSLP netcdf: 99078.12614082001, wind_mod netcdf: 22.532282365830003
#
# Time tempest dict: 2020-02-11 12:00:00, lat tempest -18.5, lon tempest 165.0,  MSLP tempest: 99313.76, wind_mod tempest: 19.01768
# Time netcdf: 2020-02-11T12:00:00.000000000, MSLP netcdf: 99204.14267143312, wind_mod netcdf: 23.271125073191296
#
# Time tempest dict: 2020-02-11 18:00:00, lat tempest -18.5, lon tempest 164.0,  MSLP tempest: 99041.91, wind_mod tempest: 17.33033
# Time netcdf: 2020-02-11T18:00:00.000000000, MSLP netcdf: 98884.88892637732, wind_mod netcdf: 20.73187306955146
#
# Time tempest dict: 2020-02-12 00:00:00, lat tempest -18.5, lon tempest 163.0,  MSLP tempest: 99465.38, wind_mod tempest: 15.42957
# Time netcdf: 2020-02-12T00:00:00.000000000, MSLP netcdf: 99310.67327241425, wind_mod netcdf: 19.27661039394942
#
# Time tempest dict: 2020-02-12 06:00:00, lat tempest -19.5, lon tempest 163.0,  MSLP tempest: 99361.31, wind_mod tempest: 16.24637
# Time netcdf: 2020-02-12T06:00:00.000000000, MSLP netcdf: 99199.93511774584, wind_mod netcdf: 18.31556129582158
#
# Time tempest dict: 2020-02-12 12:00:00, lat tempest -19.5, lon tempest 162.0,  MSLP tempest: 99664.8, wind_mod tempest: 15.5451
# Time netcdf: 2020-02-12T12:00:00.000000000, MSLP netcdf: 99575.06923331169, wind_mod netcdf: 18.238534171646418
#
# Time tempest dict: 2020-02-12 18:00:00, lat tempest -19.5, lon tempest 161.0,  MSLP tempest: 99507.09, wind_mod tempest: 15.60881
# Time netcdf: 2020-02-12T18:00:00.000000000, MSLP netcdf: 99436.02927468279, wind_mod netcdf: 18.65754023937657
#
# Time tempest dict: 2020-02-13 00:00:00, lat tempest -19.5, lon tempest 160.0,  MSLP tempest: 99714.38, wind_mod tempest: 16.42473
# Time netcdf: 2020-02-13T00:00:00.000000000, MSLP netcdf: 99667.9733144224, wind_mod netcdf: 18.45960115437394
#
# Time tempest dict: 2020-02-13 06:00:00, lat tempest -19.5, lon tempest 159.0,  MSLP tempest: 99581.93, wind_mod tempest: 16.08108
# Time netcdf: 2020-02-13T06:00:00.000000000, MSLP netcdf: 99553.83412203456, wind_mod netcdf: 18.248641011910266
#
# Time tempest dict: 2020-02-13 12:00:00, lat tempest -19.5, lon tempest 157.0,  MSLP tempest: 99905.44, wind_mod tempest: 16.41036
# Time netcdf: 2020-02-13T12:00:00.000000000, MSLP netcdf: 99863.66100952997, wind_mod netcdf: 18.41900342558912
#
# Time tempest dict: 2020-02-13 18:00:00, lat tempest -19.5, lon tempest 156.0,  MSLP tempest: 99765.07, wind_mod tempest: 14.17798
# Time netcdf: 2020-02-13T18:00:00.000000000, MSLP netcdf: 99737.76869955813, wind_mod netcdf: 16.0644410106939
#
# Time tempest dict: 2020-02-14 00:00:00, lat tempest -18.5, lon tempest 154.0,  MSLP tempest: 100067.9, wind_mod tempest: 10.9373
# Time netcdf: 2020-02-14T00:00:00.000000000, MSLP netcdf: 100031.4410284338, wind_mod netcdf: 16.470273120407896
#
# Time tempest dict: 2020-02-14 06:00:00, lat tempest -18.5, lon tempest 153.0,  MSLP tempest: 99880.95, wind_mod tempest: 11.15924
# Time netcdf: 2020-02-14T06:00:00.000000000, MSLP netcdf: 99854.15423132553, wind_mod netcdf: 15.549865687360581
#
# Time tempest dict: 2020-02-14 12:00:00, lat tempest -18.5, lon tempest 151.0,  MSLP tempest: 100234.0, wind_mod tempest: 13.95987
# Time netcdf: 2020-02-14T12:00:00.000000000, MSLP netcdf: 100190.95338891036, wind_mod netcdf: 15.51270448532406
#
# Created /home/b/b382216/work/tc/fullres/IFS/tco1279-orca025-cycle3/tempest_fullres_txt/fullres_tempest_track_20200120-20200218.txt
# Opened tempest file: /home/b/b382216/work/tc/tmpdir/IFS/tco1279-orca025-cycle3/tempest_track_20200219-20200319.txt
# Opened NetCDF file: /home/b/b382216/work/tc/fullres/IFS/tco1279-orca025-cycle3/tempest_tracks_20200219-20200319.nc
# Track 1:
# Track Length: 83, Year: 2020, Month: 2, Date: 19, Hour: 12
# Time tempest dict: 2020-02-19 12:00:00, lat tempest -14.5, lon tempest 153.0,  MSLP tempest: 100270.0, wind_mod tempest: 11.42625
# Time netcdf: 2020-02-19T12:00:00.000000000, MSLP netcdf: 100242.13757802146, wind_mod netcdf: 13.558313929701768
#
# Time tempest dict: 2020-02-19 18:00:00, lat tempest -14.5, lon tempest 153.0,  MSLP tempest: 99920.02, wind_mod tempest: 12.82117
# Time netcdf: 2020-02-19T18:00:00.000000000, MSLP netcdf: 99888.25648468769, wind_mod netcdf: 15.269934122339297
#
# Time tempest dict: 2020-02-20 00:00:00, lat tempest -14.5, lon tempest 153.0,  MSLP tempest: 100105.7, wind_mod tempest: 14.38063
# Time netcdf: 2020-02-20T00:00:00.000000000, MSLP netcdf: 100053.62557240183, wind_mod netcdf: 15.49049290475288
#
# Time tempest dict: 2020-02-20 06:00:00, lat tempest -14.5, lon tempest 154.0,  MSLP tempest: 99782.81, wind_mod tempest: 14.85265
# Time netcdf: 2020-02-20T06:00:00.000000000, MSLP netcdf: 99713.82925722981, wind_mod netcdf: 16.225803330525135
#
# Time tempest dict: 2020-02-20 12:00:00, lat tempest -14.5, lon tempest 154.0,  MSLP tempest: 99951.13, wind_mod tempest: 14.55598
# Time netcdf: 2020-02-20T12:00:00.000000000, MSLP netcdf: 99882.54507185663, wind_mod netcdf: 15.7966291170756
#
# Time tempest dict: 2020-02-20 18:00:00, lat tempest -15.5, lon tempest 155.0,  MSLP tempest: 99606.22, wind_mod tempest: 13.16076
# Time netcdf: 2020-02-20T18:00:00.000000000, MSLP netcdf: 99543.14408305506, wind_mod netcdf: 16.811014408526535
#
# Time tempest dict: 2020-02-21 00:00:00, lat tempest -15.5, lon tempest 155.0,  MSLP tempest: 99758.65, wind_mod tempest: 14.6387
# Time netcdf: 2020-02-21T00:00:00.000000000, MSLP netcdf: 99709.7621118472, wind_mod netcdf: 17.455926838293628
#
# Time tempest dict: 2020-02-21 06:00:00, lat tempest -15.5, lon tempest 156.0,  MSLP tempest: 99434.07, wind_mod tempest: 14.81616
# Time netcdf: 2020-02-21T06:00:00.000000000, MSLP netcdf: 99348.11454988866, wind_mod netcdf: 17.77847297669046
#
# Time tempest dict: 2020-02-21 12:00:00, lat tempest -15.5, lon tempest 156.0,  MSLP tempest: 99637.97, wind_mod tempest: 15.81974
# Time netcdf: 2020-02-21T12:00:00.000000000, MSLP netcdf: 99590.33314186269, wind_mod netcdf: 17.795549647078676
#
# Time tempest dict: 2020-02-21 18:00:00, lat tempest -15.5, lon tempest 156.0,  MSLP tempest: 99342.67, wind_mod tempest: 14.55514
# Time netcdf: 2020-02-21T18:00:00.000000000, MSLP netcdf: 99258.71808743625, wind_mod netcdf: 18.249381843478034
#
# Time tempest dict: 2020-02-22 00:00:00, lat tempest -15.5, lon tempest 156.0,  MSLP tempest: 99557.98, wind_mod tempest: 14.55684
# Time netcdf: 2020-02-22T00:00:00.000000000, MSLP netcdf: 99405.70533557433, wind_mod netcdf: 17.16973801008891
#
# Time tempest dict: 2020-02-22 06:00:00, lat tempest -15.5, lon tempest 156.0,  MSLP tempest: 99300.72, wind_mod tempest: 14.72316
# Time netcdf: 2020-02-22T06:00:00.000000000, MSLP netcdf: 99088.24597690119, wind_mod netcdf: 17.12705909399689
#
# Time tempest dict: 2020-02-22 12:00:00, lat tempest -16.5, lon tempest 156.0,  MSLP tempest: 99510.12, wind_mod tempest: 16.22194
# Time netcdf: 2020-02-22T12:00:00.000000000, MSLP netcdf: 99300.46678644877, wind_mod netcdf: 17.637468655059298
#
# Time tempest dict: 2020-02-22 18:00:00, lat tempest -16.5, lon tempest 156.0,  MSLP tempest: 99100.96, wind_mod tempest: 16.52092
# Time netcdf: 2020-02-22T18:00:00.000000000, MSLP netcdf: 98909.67173512626, wind_mod netcdf: 18.444457076166053
#
# Time tempest dict: 2020-02-23 00:00:00, lat tempest -16.5, lon tempest 156.0,  MSLP tempest: 99314.46, wind_mod tempest: 16.93458
# Time netcdf: 2020-02-23T00:00:00.000000000, MSLP netcdf: 99072.8930859589, wind_mod netcdf: 19.19203195241713
#
# Time tempest dict: 2020-02-23 06:00:00, lat tempest -16.5, lon tempest 156.0,  MSLP tempest: 98729.48, wind_mod tempest: 17.3132
# Time netcdf: 2020-02-23T06:00:00.000000000, MSLP netcdf: 98395.4366608046, wind_mod netcdf: 21.883691144365617
#
# Time tempest dict: 2020-02-23 12:00:00, lat tempest -16.5, lon tempest 156.0,  MSLP tempest: 98803.94, wind_mod tempest: 17.75245
# Time netcdf: 2020-02-23T12:00:00.000000000, MSLP netcdf: 98145.51967982462, wind_mod netcdf: 23.987997768369972
#
# Time tempest dict: 2020-02-23 18:00:00, lat tempest -15.5, lon tempest 157.0,  MSLP tempest: 98655.6, wind_mod tempest: 19.08442
# Time netcdf: 2020-02-23T18:00:00.000000000, MSLP netcdf: 97548.721869614, wind_mod netcdf: 30.802351755734243
#
# Time tempest dict: 2020-02-24 00:00:00, lat tempest -15.5, lon tempest 157.0,  MSLP tempest: 98191.36, wind_mod tempest: 18.98981
# Time netcdf: 2020-02-24T00:00:00.000000000, MSLP netcdf: 97412.51318562089, wind_mod netcdf: 28.50894847015058
#
# Time tempest dict: 2020-02-24 06:00:00, lat tempest -15.5, lon tempest 158.0,  MSLP tempest: 98070.41, wind_mod tempest: 19.88435
# Time netcdf: 2020-02-24T06:00:00.000000000, MSLP netcdf: 96551.99997254988, wind_mod netcdf: 36.528062110963795
#
# Time tempest dict: 2020-02-24 12:00:00, lat tempest -15.5, lon tempest 160.0,  MSLP tempest: 98113.66, wind_mod tempest: 20.52208
# Time netcdf: 2020-02-24T12:00:00.000000000, MSLP netcdf: 96096.68209385731, wind_mod netcdf: 39.435477555925566
#
# Time tempest dict: 2020-02-24 18:00:00, lat tempest -15.5, lon tempest 161.0,  MSLP tempest: 97834.97, wind_mod tempest: 21.3663
# Time netcdf: 2020-02-24T18:00:00.000000000, MSLP netcdf: 95631.68576153784, wind_mod netcdf: 42.547596013511296
#
# Time tempest dict: 2020-02-25 00:00:00, lat tempest -16.5, lon tempest 161.0,  MSLP tempest: 97974.8, wind_mod tempest: 20.80657
# Time netcdf: 2020-02-25T00:00:00.000000000, MSLP netcdf: 95279.40253840439, wind_mod netcdf: 44.34478365589289
#
# Time tempest dict: 2020-02-25 06:00:00, lat tempest -16.5, lon tempest 162.0,  MSLP tempest: 97586.52, wind_mod tempest: 22.4183
# Time netcdf: 2020-02-25T06:00:00.000000000, MSLP netcdf: 95258.60006776804, wind_mod netcdf: 42.43825604149438
#
# Time tempest dict: 2020-02-25 12:00:00, lat tempest -17.5, lon tempest 162.0,  MSLP tempest: 98301.55, wind_mod tempest: 22.95334
# Time netcdf: 2020-02-25T12:00:00.000000000, MSLP netcdf: 95318.83887913356, wind_mod netcdf: 43.52652331123713
#
# Time tempest dict: 2020-02-25 18:00:00, lat tempest -17.5, lon tempest 162.0,  MSLP tempest: 97842.69, wind_mod tempest: 20.88581
# Time netcdf: 2020-02-25T18:00:00.000000000, MSLP netcdf: 95429.63189751218, wind_mod netcdf: 38.481846999867315
#
# Time tempest dict: 2020-02-26 00:00:00, lat tempest -17.5, lon tempest 161.0,  MSLP tempest: 98084.73, wind_mod tempest: 19.75209
# Time netcdf: 2020-02-26T00:00:00.000000000, MSLP netcdf: 96002.8306199818, wind_mod netcdf: 35.08525091453082
#
# Time tempest dict: 2020-02-26 06:00:00, lat tempest -17.5, lon tempest 161.0,  MSLP tempest: 97989.46, wind_mod tempest: 20.00903
# Time netcdf: 2020-02-26T06:00:00.000000000, MSLP netcdf: 96165.59196788887, wind_mod netcdf: 32.74254987945511
#
# Time tempest dict: 2020-02-26 12:00:00, lat tempest -18.5, lon tempest 161.0,  MSLP tempest: 98679.52, wind_mod tempest: 21.58877
# Time netcdf: 2020-02-26T12:00:00.000000000, MSLP netcdf: 96631.9347842778, wind_mod netcdf: 32.93304189422942
#
# Time tempest dict: 2020-02-26 18:00:00, lat tempest -18.5, lon tempest 160.0,  MSLP tempest: 98179.09, wind_mod tempest: 18.50822
# Time netcdf: 2020-02-26T18:00:00.000000000, MSLP netcdf: 96529.17876503454, wind_mod netcdf: 31.630850152336368
#
# Time tempest dict: 2020-02-27 00:00:00, lat tempest -18.5, lon tempest 159.0,  MSLP tempest: 98563.58, wind_mod tempest: 18.60819
# Time netcdf: 2020-02-27T00:00:00.000000000, MSLP netcdf: 96611.65708364197, wind_mod netcdf: 31.153593552899938
#
# Time tempest dict: 2020-02-27 06:00:00, lat tempest -18.5, lon tempest 159.0,  MSLP tempest: 98278.16, wind_mod tempest: 19.98429
# Time netcdf: 2020-02-27T06:00:00.000000000, MSLP netcdf: 96346.2082015814, wind_mod netcdf: 31.724387418572377
#
# Time tempest dict: 2020-02-27 12:00:00, lat tempest -18.5, lon tempest 158.0,  MSLP tempest: 98380.73, wind_mod tempest: 20.23649
# Time netcdf: 2020-02-27T12:00:00.000000000, MSLP netcdf: 96445.58695581893, wind_mod netcdf: 30.87539102159445
#
# Time tempest dict: 2020-02-27 18:00:00, lat tempest -18.5, lon tempest 157.0,  MSLP tempest: 98035.57, wind_mod tempest: 19.96491
# Time netcdf: 2020-02-27T18:00:00.000000000, MSLP netcdf: 96344.82686686915, wind_mod netcdf: 30.687473627959125
#
# Time tempest dict: 2020-02-28 00:00:00, lat tempest -17.5, lon tempest 156.0,  MSLP tempest: 98302.23, wind_mod tempest: 19.44385
# Time netcdf: 2020-02-28T00:00:00.000000000, MSLP netcdf: 96139.90185144253, wind_mod netcdf: 31.149459752636364
#
# Time tempest dict: 2020-02-28 06:00:00, lat tempest -18.5, lon tempest 155.0,  MSLP tempest: 98213.83, wind_mod tempest: 20.75914
# Time netcdf: 2020-02-28T06:00:00.000000000, MSLP netcdf: 95776.17504179104, wind_mod netcdf: 33.720732664181725
#
# Time tempest dict: 2020-02-28 12:00:00, lat tempest -18.5, lon tempest 155.0,  MSLP tempest: 98268.77, wind_mod tempest: 24.28124
# Time netcdf: 2020-02-28T12:00:00.000000000, MSLP netcdf: 95601.16936174652, wind_mod netcdf: 39.578335968150476
#
# Time tempest dict: 2020-02-28 18:00:00, lat tempest -18.5, lon tempest 154.0,  MSLP tempest: 97848.96, wind_mod tempest: 23.6656
# Time netcdf: 2020-02-28T18:00:00.000000000, MSLP netcdf: 95021.88381830695, wind_mod netcdf: 42.084759641017726
#
# Time tempest dict: 2020-02-29 00:00:00, lat tempest -18.5, lon tempest 153.0,  MSLP tempest: 97820.02, wind_mod tempest: 22.43761
# Time netcdf: 2020-02-29T00:00:00.000000000, MSLP netcdf: 94506.11072907421, wind_mod netcdf: 42.04102267609538
#
# Time tempest dict: 2020-02-29 06:00:00, lat tempest -18.5, lon tempest 152.0,  MSLP tempest: 97770.05, wind_mod tempest: 24.32544
# Time netcdf: 2020-02-29T06:00:00.000000000, MSLP netcdf: 93894.64127538094, wind_mod netcdf: 48.86947342431126
#
# Time tempest dict: 2020-02-29 12:00:00, lat tempest -17.5, lon tempest 152.0,  MSLP tempest: 97461.36, wind_mod tempest: 26.63157
# Time netcdf: 2020-02-29T12:00:00.000000000, MSLP netcdf: 94482.04612148908, wind_mod netcdf: 49.77313271920922
#
# Time tempest dict: 2020-02-29 18:00:00, lat tempest -17.5, lon tempest 152.0,  MSLP tempest: 97339.51, wind_mod tempest: 23.67294
# Time netcdf: 2020-02-29T18:00:00.000000000, MSLP netcdf: 94007.09911480345, wind_mod netcdf: 46.91053341273389
#
# Time tempest dict: 2020-03-01 00:00:00, lat tempest -17.5, lon tempest 151.0,  MSLP tempest: 97532.78, wind_mod tempest: 22.83322
# Time netcdf: 2020-03-01T00:00:00.000000000, MSLP netcdf: 94549.70463751072, wind_mod netcdf: 44.74383078318785
#
# Time tempest dict: 2020-03-01 06:00:00, lat tempest -17.5, lon tempest 152.0,  MSLP tempest: 96961.05, wind_mod tempest: 25.99457
# Time netcdf: 2020-03-01T06:00:00.000000000, MSLP netcdf: 93886.04699410366, wind_mod netcdf: 44.62901613622498
#
# Time tempest dict: 2020-03-01 12:00:00, lat tempest -17.5, lon tempest 152.0,  MSLP tempest: 97268.51, wind_mod tempest: 24.65069
# Time netcdf: 2020-03-01T12:00:00.000000000, MSLP netcdf: 94846.24002081683, wind_mod netcdf: 41.91968488296831
#
# Time tempest dict: 2020-03-01 18:00:00, lat tempest -17.5, lon tempest 152.0,  MSLP tempest: 97246.83, wind_mod tempest: 24.03946
# Time netcdf: 2020-03-01T18:00:00.000000000, MSLP netcdf: 95122.35479411845, wind_mod netcdf: 34.01378492302609
#
# Time tempest dict: 2020-03-02 00:00:00, lat tempest -17.5, lon tempest 152.0,  MSLP tempest: 97799.87, wind_mod tempest: 20.74072
# Time netcdf: 2020-03-02T00:00:00.000000000, MSLP netcdf: 96215.75984548267, wind_mod netcdf: 29.45149322039885
#
# Time tempest dict: 2020-03-02 06:00:00, lat tempest -17.5, lon tempest 152.0,  MSLP tempest: 98183.32, wind_mod tempest: 20.79578
# Time netcdf: 2020-03-02T06:00:00.000000000, MSLP netcdf: 96399.52099487752, wind_mod netcdf: 26.923735624224427
#
# Time tempest dict: 2020-03-02 12:00:00, lat tempest -18.5, lon tempest 152.0,  MSLP tempest: 98660.16, wind_mod tempest: 20.72614
# Time netcdf: 2020-03-02T12:00:00.000000000, MSLP netcdf: 97039.39366659503, wind_mod netcdf: 26.65374082865294
#
# Time tempest dict: 2020-03-02 18:00:00, lat tempest -18.5, lon tempest 153.0,  MSLP tempest: 98352.43, wind_mod tempest: 20.15244
# Time netcdf: 2020-03-02T18:00:00.000000000, MSLP netcdf: 97304.76648534706, wind_mod netcdf: 24.61134785427822
#
# Time tempest dict: 2020-03-03 00:00:00, lat tempest -18.5, lon tempest 152.0,  MSLP tempest: 98693.02, wind_mod tempest: 20.56741
# Time netcdf: 2020-03-03T00:00:00.000000000, MSLP netcdf: 97874.67162190386, wind_mod netcdf: 24.818086250766346
#
# Time tempest dict: 2020-03-03 06:00:00, lat tempest -18.5, lon tempest 152.0,  MSLP tempest: 98605.83, wind_mod tempest: 20.44894
# Time netcdf: 2020-03-03T06:00:00.000000000, MSLP netcdf: 97711.04653673958, wind_mod netcdf: 27.058702344364075
#
# Time tempest dict: 2020-03-03 12:00:00, lat tempest -19.5, lon tempest 153.0,  MSLP tempest: 99019.16, wind_mod tempest: 19.51608
# Time netcdf: 2020-03-03T12:00:00.000000000, MSLP netcdf: 98167.89117039734, wind_mod netcdf: 26.39763571338603
#
# Time tempest dict: 2020-03-03 18:00:00, lat tempest -19.5, lon tempest 152.0,  MSLP tempest: 98501.69, wind_mod tempest: 20.05253
# Time netcdf: 2020-03-03T18:00:00.000000000, MSLP netcdf: 98011.4339890905, wind_mod netcdf: 27.201182769972988
#
# Time tempest dict: 2020-03-04 00:00:00, lat tempest -19.5, lon tempest 152.0,  MSLP tempest: 98725.94, wind_mod tempest: 20.0655
# Time netcdf: 2020-03-04T00:00:00.000000000, MSLP netcdf: 98374.95490555547, wind_mod netcdf: 26.350427448246393
#
# Time tempest dict: 2020-03-04 06:00:00, lat tempest -19.5, lon tempest 153.0,  MSLP tempest: 98641.84, wind_mod tempest: 19.80717
# Time netcdf: 2020-03-04T06:00:00.000000000, MSLP netcdf: 98202.89235761724, wind_mod netcdf: 26.395053640101093
#
# Time tempest dict: 2020-03-04 12:00:00, lat tempest -19.5, lon tempest 153.0,  MSLP tempest: 98905.19, wind_mod tempest: 19.40986
# Time netcdf: 2020-03-04T12:00:00.000000000, MSLP netcdf: 98519.02578492623, wind_mod netcdf: 25.723616973272296
#
# Time tempest dict: 2020-03-04 18:00:00, lat tempest -20.5, lon tempest 153.0,  MSLP tempest: 98755.41, wind_mod tempest: 19.21161
# Time netcdf: 2020-03-04T18:00:00.000000000, MSLP netcdf: 98393.25678697258, wind_mod netcdf: 25.766043515001552
#
# Time tempest dict: 2020-03-05 00:00:00, lat tempest -20.5, lon tempest 153.0,  MSLP tempest: 98873.86, wind_mod tempest: 18.01795
# Time netcdf: 2020-03-05T00:00:00.000000000, MSLP netcdf: 98639.45868915963, wind_mod netcdf: 24.232998795071822
#
# Time tempest dict: 2020-03-05 06:00:00, lat tempest -20.5, lon tempest 153.0,  MSLP tempest: 98778.16, wind_mod tempest: 18.90995
# Time netcdf: 2020-03-05T06:00:00.000000000, MSLP netcdf: 98398.9733686662, wind_mod netcdf: 26.527695897524797
#
# Time tempest dict: 2020-03-05 12:00:00, lat tempest -20.5, lon tempest 154.0,  MSLP tempest: 98829.65, wind_mod tempest: 18.71667
# Time netcdf: 2020-03-05T12:00:00.000000000, MSLP netcdf: 98608.9701986192, wind_mod netcdf: 23.923626710894556
#
# Time tempest dict: 2020-03-05 18:00:00, lat tempest -20.5, lon tempest 154.0,  MSLP tempest: 98635.95, wind_mod tempest: 18.23738
# Time netcdf: 2020-03-05T18:00:00.000000000, MSLP netcdf: 98313.00835163434, wind_mod netcdf: 22.894522883731156
#
# Time tempest dict: 2020-03-06 00:00:00, lat tempest -21.5, lon tempest 154.0,  MSLP tempest: 99060.41, wind_mod tempest: 17.33406
# Time netcdf: 2020-03-06T00:00:00.000000000, MSLP netcdf: 98527.96822649764, wind_mod netcdf: 24.733347080685014
#
# Time tempest dict: 2020-03-06 06:00:00, lat tempest -21.5, lon tempest 155.0,  MSLP tempest: 98568.22, wind_mod tempest: 18.38287
# Time netcdf: 2020-03-06T06:00:00.000000000, MSLP netcdf: 98241.45292079911, wind_mod netcdf: 26.682957977788956
#
# Time tempest dict: 2020-03-06 12:00:00, lat tempest -21.5, lon tempest 155.0,  MSLP tempest: 98814.23, wind_mod tempest: 18.41015
# Time netcdf: 2020-03-06T12:00:00.000000000, MSLP netcdf: 98526.32974013043, wind_mod netcdf: 23.63972582684047
#
# Time tempest dict: 2020-03-06 18:00:00, lat tempest -21.5, lon tempest 155.0,  MSLP tempest: 98472.04, wind_mod tempest: 18.17779
# Time netcdf: 2020-03-06T18:00:00.000000000, MSLP netcdf: 98228.80567194808, wind_mod netcdf: 23.91114038040834
#
# Time tempest dict: 2020-03-07 00:00:00, lat tempest -21.5, lon tempest 155.0,  MSLP tempest: 98677.66, wind_mod tempest: 18.05868
# Time netcdf: 2020-03-07T00:00:00.000000000, MSLP netcdf: 98388.9141739803, wind_mod netcdf: 23.945367866862533
#
# Time tempest dict: 2020-03-07 06:00:00, lat tempest -21.5, lon tempest 155.0,  MSLP tempest: 98295.55, wind_mod tempest: 18.91762
# Time netcdf: 2020-03-07T06:00:00.000000000, MSLP netcdf: 97913.77619283098, wind_mod netcdf: 27.43494464409309
#
# Time tempest dict: 2020-03-07 12:00:00, lat tempest -20.5, lon tempest 155.0,  MSLP tempest: 98736.2, wind_mod tempest: 20.03728
# Time netcdf: 2020-03-07T12:00:00.000000000, MSLP netcdf: 98076.04561211614, wind_mod netcdf: 26.481423715221915
#
# Time tempest dict: 2020-03-07 18:00:00, lat tempest -20.5, lon tempest 155.0,  MSLP tempest: 98204.47, wind_mod tempest: 21.42854
# Time netcdf: 2020-03-07T18:00:00.000000000, MSLP netcdf: 97871.09301577168, wind_mod netcdf: 28.957517172604557
#
# Time tempest dict: 2020-03-08 00:00:00, lat tempest -20.5, lon tempest 154.0,  MSLP tempest: 98773.75, wind_mod tempest: 20.05997
# Time netcdf: 2020-03-08T00:00:00.000000000, MSLP netcdf: 98146.42144420772, wind_mod netcdf: 27.262470649830565
#
# Time tempest dict: 2020-03-08 06:00:00, lat tempest -19.5, lon tempest 154.0,  MSLP tempest: 98406.99, wind_mod tempest: 21.33142
# Time netcdf: 2020-03-08T06:00:00.000000000, MSLP netcdf: 97999.53283390893, wind_mod netcdf: 28.878895717972913
#
# Time tempest dict: 2020-03-08 12:00:00, lat tempest -19.5, lon tempest 154.0,  MSLP tempest: 98746.1, wind_mod tempest: 20.69193
# Time netcdf: 2020-03-08T12:00:00.000000000, MSLP netcdf: 98500.17342956935, wind_mod netcdf: 28.91372284389381
#
# Time tempest dict: 2020-03-08 18:00:00, lat tempest -18.5, lon tempest 154.0,  MSLP tempest: 98751.38, wind_mod tempest: 19.40146
# Time netcdf: 2020-03-08T18:00:00.000000000, MSLP netcdf: 98487.7274394102, wind_mod netcdf: 29.170733831457415
#
# Time tempest dict: 2020-03-09 00:00:00, lat tempest -18.5, lon tempest 153.0,  MSLP tempest: 99219.78, wind_mod tempest: 18.15978
# Time netcdf: 2020-03-09T00:00:00.000000000, MSLP netcdf: 98919.20831890866, wind_mod netcdf: 26.62344723351364
#
# Time tempest dict: 2020-03-09 06:00:00, lat tempest -17.5, lon tempest 153.0,  MSLP tempest: 99077.16, wind_mod tempest: 17.93074
# Time netcdf: 2020-03-09T06:00:00.000000000, MSLP netcdf: 99003.15662474942, wind_mod netcdf: 22.183045276674086
#
# Time tempest dict: 2020-03-09 12:00:00, lat tempest -16.5, lon tempest 153.0,  MSLP tempest: 99661.14, wind_mod tempest: 15.10106
# Time netcdf: 2020-03-09T12:00:00.000000000, MSLP netcdf: 99529.00374033778, wind_mod netcdf: 16.59131843508298
#
# Time tempest dict: 2020-03-09 18:00:00, lat tempest -16.5, lon tempest 153.0,  MSLP tempest: 99633.8, wind_mod tempest: 14.4807
# Time netcdf: 2020-03-09T18:00:00.000000000, MSLP netcdf: 99489.78589171931, wind_mod netcdf: 16.342106571982267
#
# Time tempest dict: 2020-03-10 00:00:00, lat tempest -15.5, lon tempest 152.0,  MSLP tempest: 99930.5, wind_mod tempest: 13.71257
# Time netcdf: 2020-03-10T00:00:00.000000000, MSLP netcdf: 99877.97508917011, wind_mod netcdf: 15.134122899778394
#
# Time tempest dict: 2020-03-10 06:00:00, lat tempest -14.5, lon tempest 152.0,  MSLP tempest: 99814.47, wind_mod tempest: 13.19788
# Time netcdf: 2020-03-10T06:00:00.000000000, MSLP netcdf: 99708.49977939, wind_mod netcdf: 16.20479104308178
#
# Time tempest dict: 2020-03-10 12:00:00, lat tempest -14.5, lon tempest 152.0,  MSLP tempest: 100167.5, wind_mod tempest: 14.02945
# Time netcdf: 2020-03-10T12:00:00.000000000, MSLP netcdf: 100096.06518880845, wind_mod netcdf: 16.13908352866797
#
# Time tempest dict: 2020-03-10 18:00:00, lat tempest -13.5, lon tempest 152.0,  MSLP tempest: 100000.6, wind_mod tempest: 13.20613
# Time netcdf: 2020-03-10T18:00:00.000000000, MSLP netcdf: 99947.29670903909, wind_mod netcdf: 15.498028820719947
#
# Time tempest dict: 2020-03-11 00:00:00, lat tempest -13.5, lon tempest 152.0,  MSLP tempest: 100344.0, wind_mod tempest: 13.49602
# Time netcdf: 2020-03-11T00:00:00.000000000, MSLP netcdf: 100242.46958909923, wind_mod netcdf: 15.142203624181677
#
# Track 2:
# Track Length: 20, Year: 2020, Month: 2, Date: 24, Hour: 12
# Time tempest dict: 2020-02-24 12:00:00, lat tempest -16.5, lon tempest 124.0,  MSLP tempest: 99679.83, wind_mod tempest: 13.57341
# Time netcdf: 2020-02-24T12:00:00.000000000, MSLP netcdf: 99629.03049090451, wind_mod netcdf: 16.552481831333754
#
# Time tempest dict: 2020-02-24 18:00:00, lat tempest -16.5, lon tempest 124.0,  MSLP tempest: 99402.84, wind_mod tempest: 14.50924
# Time netcdf: 2020-02-24T18:00:00.000000000, MSLP netcdf: 99320.68905977957, wind_mod netcdf: 17.08043288339363
#
# Time tempest dict: 2020-02-25 00:00:00, lat tempest -16.5, lon tempest 123.0,  MSLP tempest: 99508.56, wind_mod tempest: 15.22173
# Time netcdf: 2020-02-25T00:00:00.000000000, MSLP netcdf: 99443.76151061764, wind_mod netcdf: 17.755065171895744
#
# Time tempest dict: 2020-02-25 06:00:00, lat tempest -17.5, lon tempest 123.0,  MSLP tempest: 99148.7, wind_mod tempest: 9.208456
# Time netcdf: 2020-02-25T06:00:00.000000000, MSLP netcdf: 99110.69350240278, wind_mod netcdf: 18.519714864936518
#
# Time tempest dict: 2020-02-25 12:00:00, lat tempest -17.5, lon tempest 122.0,  MSLP tempest: 99331.81, wind_mod tempest: 12.77004
# Time netcdf: 2020-02-25T12:00:00.000000000, MSLP netcdf: 99269.26088792011, wind_mod netcdf: 15.88074386137511
#
# Time tempest dict: 2020-02-25 18:00:00, lat tempest -17.5, lon tempest 122.0,  MSLP tempest: 99053.6, wind_mod tempest: 15.09347
# Time netcdf: 2020-02-25T18:00:00.000000000, MSLP netcdf: 98987.64037596804, wind_mod netcdf: 17.739340281288438
#
# Time tempest dict: 2020-02-26 00:00:00, lat tempest -18.5, lon tempest 121.0,  MSLP tempest: 99127.7, wind_mod tempest: 15.98701
# Time netcdf: 2020-02-26T00:00:00.000000000, MSLP netcdf: 99021.66143362319, wind_mod netcdf: 20.27676013838969
#
# Time tempest dict: 2020-02-26 06:00:00, lat tempest -19.5, lon tempest 121.0,  MSLP tempest: 98918.87, wind_mod tempest: 14.12976
# Time netcdf: 2020-02-26T06:00:00.000000000, MSLP netcdf: 98849.19098943777, wind_mod netcdf: 19.649217106950093
#
# Time tempest dict: 2020-02-26 12:00:00, lat tempest -19.5, lon tempest 120.0,  MSLP tempest: 99018.83, wind_mod tempest: 16.21341
# Time netcdf: 2020-02-26T12:00:00.000000000, MSLP netcdf: 98910.7375031829, wind_mod netcdf: 18.55493119060872
#
# Time tempest dict: 2020-02-26 18:00:00, lat tempest -19.5, lon tempest 120.0,  MSLP tempest: 98556.79, wind_mod tempest: 18.53751
# Time netcdf: 2020-02-26T18:00:00.000000000, MSLP netcdf: 98344.83459928076, wind_mod netcdf: 23.617389292041235
#
# Time tempest dict: 2020-02-27 00:00:00, lat tempest -20.5, lon tempest 119.0,  MSLP tempest: 98724.35, wind_mod tempest: 16.41981
# Time netcdf: 2020-02-27T00:00:00.000000000, MSLP netcdf: 98306.72853944331, wind_mod netcdf: 20.702137529950996
#
# Time tempest dict: 2020-02-27 06:00:00, lat tempest -20.5, lon tempest 118.0,  MSLP tempest: 98471.12, wind_mod tempest: 16.32058
# Time netcdf: 2020-02-27T06:00:00.000000000, MSLP netcdf: 98124.12338927975, wind_mod netcdf: 20.66596830294529
#
# Time tempest dict: 2020-02-27 12:00:00, lat tempest -21.5, lon tempest 117.0,  MSLP tempest: 98762.09, wind_mod tempest: 16.03782
# Time netcdf: 2020-02-27T12:00:00.000000000, MSLP netcdf: 98300.49284453204, wind_mod netcdf: 20.837692192870882
#
# Time tempest dict: 2020-02-27 18:00:00, lat tempest -22.5, lon tempest 116.0,  MSLP tempest: 98575.64, wind_mod tempest: 12.99435
# Time netcdf: 2020-02-27T18:00:00.000000000, MSLP netcdf: 98294.06045667338, wind_mod netcdf: 17.36481358980116
#
# Time tempest dict: 2020-02-28 00:00:00, lat tempest -23.5, lon tempest 115.0,  MSLP tempest: 98838.06, wind_mod tempest: 15.43794
# Time netcdf: 2020-02-28T00:00:00.000000000, MSLP netcdf: 98619.83970954717, wind_mod netcdf: 16.845368331719083
#
# Time tempest dict: 2020-02-28 06:00:00, lat tempest -24.5, lon tempest 115.0,  MSLP tempest: 98753.44, wind_mod tempest: 15.49205
# Time netcdf: 2020-02-28T06:00:00.000000000, MSLP netcdf: 98628.54915341499, wind_mod netcdf: 19.985907197822925
#
# Time tempest dict: 2020-02-28 12:00:00, lat tempest -26.5, lon tempest 114.0,  MSLP tempest: 99137.99, wind_mod tempest: 15.49804
# Time netcdf: 2020-02-28T12:00:00.000000000, MSLP netcdf: 98806.66465295423, wind_mod netcdf: 17.579595781987436
#
# Time tempest dict: 2020-02-28 18:00:00, lat tempest -27.5, lon tempest 114.0,  MSLP tempest: 99051.93, wind_mod tempest: 17.88487
# Time netcdf: 2020-02-28T18:00:00.000000000, MSLP netcdf: 98888.53805882714, wind_mod netcdf: 19.646597477480462
#
# Time tempest dict: 2020-02-29 00:00:00, lat tempest -28.5, lon tempest 114.0,  MSLP tempest: 99441.77, wind_mod tempest: 16.65486
# Time netcdf: 2020-02-29T00:00:00.000000000, MSLP netcdf: 99230.8773165356, wind_mod netcdf: 18.764615682014608
#
# Time tempest dict: 2020-02-29 06:00:00, lat tempest -30.5, lon tempest 114.0,  MSLP tempest: 99521.45, wind_mod tempest: 15.58192
# Time netcdf: 2020-02-29T06:00:00.000000000, MSLP netcdf: 99358.23625590117, wind_mod netcdf: 17.419882010169008
#
# Track 3:
# Track Length: 29, Year: 2020, Month: 3, Date: 3, Hour: 12
# Time tempest dict: 2020-03-03 12:00:00, lat tempest -16.5, lon tempest 192.0,  MSLP tempest: 100183.0, wind_mod tempest: 11.17469
# Time netcdf: 2020-03-03T12:00:00.000000000, MSLP netcdf: 100141.62365583997, wind_mod netcdf: 12.720224130892085
#
# Time tempest dict: 2020-03-03 18:00:00, lat tempest -16.5, lon tempest 192.0,  MSLP tempest: 100107.0, wind_mod tempest: 12.25358
# Time netcdf: 2020-03-03T18:00:00.000000000, MSLP netcdf: 100081.41001365436, wind_mod netcdf: 13.804166790551937
#
# Time tempest dict: 2020-03-04 00:00:00, lat tempest -16.5, lon tempest 193.0,  MSLP tempest: 99988.13, wind_mod tempest: 13.54644
# Time netcdf: 2020-03-04T00:00:00.000000000, MSLP netcdf: 99969.79109214371, wind_mod netcdf: 15.827969444345959
#
# Time tempest dict: 2020-03-04 06:00:00, lat tempest -16.5, lon tempest 194.0,  MSLP tempest: 99919.03, wind_mod tempest: 15.73049
# Time netcdf: 2020-03-04T06:00:00.000000000, MSLP netcdf: 99890.21343768259, wind_mod netcdf: 19.03253674860104
#
# Time tempest dict: 2020-03-04 12:00:00, lat tempest -17.5, lon tempest 195.0,  MSLP tempest: 99791.72, wind_mod tempest: 15.6529
# Time netcdf: 2020-03-04T12:00:00.000000000, MSLP netcdf: 99760.70242690803, wind_mod netcdf: 19.997566218619337
#
# Time tempest dict: 2020-03-04 18:00:00, lat tempest -17.5, lon tempest 196.0,  MSLP tempest: 99743.64, wind_mod tempest: 16.5854
# Time netcdf: 2020-03-04T18:00:00.000000000, MSLP netcdf: 99689.68259437966, wind_mod netcdf: 19.95240513809764
#
# Time tempest dict: 2020-03-05 00:00:00, lat tempest -18.5, lon tempest 196.0,  MSLP tempest: 99617.5, wind_mod tempest: 15.47177
# Time netcdf: 2020-03-05T00:00:00.000000000, MSLP netcdf: 99580.91458463103, wind_mod netcdf: 19.165591524501927
#
# Time tempest dict: 2020-03-05 06:00:00, lat tempest -18.5, lon tempest 196.0,  MSLP tempest: 99608.91, wind_mod tempest: 14.22526
# Time netcdf: 2020-03-05T06:00:00.000000000, MSLP netcdf: 99576.37993537943, wind_mod netcdf: 19.962113963768793
#
# Time tempest dict: 2020-03-05 12:00:00, lat tempest -18.5, lon tempest 196.0,  MSLP tempest: 99550.45, wind_mod tempest: 13.58429
# Time netcdf: 2020-03-05T12:00:00.000000000, MSLP netcdf: 99481.34085013744, wind_mod netcdf: 17.3301860690413
#
# Time tempest dict: 2020-03-05 18:00:00, lat tempest -18.5, lon tempest 197.0,  MSLP tempest: 99522.53, wind_mod tempest: 16.48561
# Time netcdf: 2020-03-05T18:00:00.000000000, MSLP netcdf: 99464.25738826908, wind_mod netcdf: 19.00421961277536
#
# Time tempest dict: 2020-03-06 00:00:00, lat tempest -19.5, lon tempest 197.0,  MSLP tempest: 99392.34, wind_mod tempest: 16.15408
# Time netcdf: 2020-03-06T00:00:00.000000000, MSLP netcdf: 99298.33468031297, wind_mod netcdf: 18.42353814305108
#
# Time tempest dict: 2020-03-06 06:00:00, lat tempest -19.5, lon tempest 197.0,  MSLP tempest: 99318.91, wind_mod tempest: 16.13961
# Time netcdf: 2020-03-06T06:00:00.000000000, MSLP netcdf: 99212.96300806095, wind_mod netcdf: 19.06485518428735
#
# Time tempest dict: 2020-03-06 12:00:00, lat tempest -19.5, lon tempest 197.0,  MSLP tempest: 99204.54, wind_mod tempest: 16.92501
# Time netcdf: 2020-03-06T12:00:00.000000000, MSLP netcdf: 99056.30901030151, wind_mod netcdf: 20.328246049883656
#
# Time tempest dict: 2020-03-06 18:00:00, lat tempest -20.5, lon tempest 197.0,  MSLP tempest: 99175.82, wind_mod tempest: 17.07285
# Time netcdf: 2020-03-06T18:00:00.000000000, MSLP netcdf: 99092.89362280609, wind_mod netcdf: 19.67934974802509
#
# Time tempest dict: 2020-03-07 00:00:00, lat tempest -20.5, lon tempest 197.0,  MSLP tempest: 99053.92, wind_mod tempest: 16.85084
# Time netcdf: 2020-03-07T00:00:00.000000000, MSLP netcdf: 98987.08026553234, wind_mod netcdf: 19.30052794846836
#
# Time tempest dict: 2020-03-07 06:00:00, lat tempest -21.5, lon tempest 197.0,  MSLP tempest: 99051.52, wind_mod tempest: 17.2843
# Time netcdf: 2020-03-07T06:00:00.000000000, MSLP netcdf: 98954.46997622402, wind_mod netcdf: 20.68408496854025
#
# Time tempest dict: 2020-03-07 12:00:00, lat tempest -21.5, lon tempest 197.0,  MSLP tempest: 98895.69, wind_mod tempest: 16.99163
# Time netcdf: 2020-03-07T12:00:00.000000000, MSLP netcdf: 98858.35275753615, wind_mod netcdf: 21.783639317547284
#
# Time tempest dict: 2020-03-07 18:00:00, lat tempest -21.5, lon tempest 198.0,  MSLP tempest: 98799.7, wind_mod tempest: 18.16782
# Time netcdf: 2020-03-07T18:00:00.000000000, MSLP netcdf: 98727.83640143089, wind_mod netcdf: 22.340637457659867
#
# Time tempest dict: 2020-03-08 00:00:00, lat tempest -22.5, lon tempest 198.0,  MSLP tempest: 98511.55, wind_mod tempest: 19.26543
# Time netcdf: 2020-03-08T00:00:00.000000000, MSLP netcdf: 98436.06161475614, wind_mod netcdf: 24.985810285120568
#
# Time tempest dict: 2020-03-08 06:00:00, lat tempest -23.5, lon tempest 199.0,  MSLP tempest: 98363.86, wind_mod tempest: 20.67057
# Time netcdf: 2020-03-08T06:00:00.000000000, MSLP netcdf: 98168.1218777581, wind_mod netcdf: 25.583056159870804
#
# Time tempest dict: 2020-03-08 12:00:00, lat tempest -24.5, lon tempest 199.0,  MSLP tempest: 98161.21, wind_mod tempest: 21.8759
# Time netcdf: 2020-03-08T12:00:00.000000000, MSLP netcdf: 97868.22664451109, wind_mod netcdf: 26.780365773030468
#
# Time tempest dict: 2020-03-08 18:00:00, lat tempest -24.5, lon tempest 199.0,  MSLP tempest: 98282.38, wind_mod tempest: 21.4871
# Time netcdf: 2020-03-08T18:00:00.000000000, MSLP netcdf: 98000.37424765977, wind_mod netcdf: 28.520124239408656
#
# Time tempest dict: 2020-03-09 00:00:00, lat tempest -25.5, lon tempest 198.0,  MSLP tempest: 98373.84, wind_mod tempest: 19.6758
# Time netcdf: 2020-03-09T00:00:00.000000000, MSLP netcdf: 98050.45615389838, wind_mod netcdf: 23.595341833918333
#
# Time tempest dict: 2020-03-09 06:00:00, lat tempest -25.5, lon tempest 198.0,  MSLP tempest: 98490.88, wind_mod tempest: 17.20993
# Time netcdf: 2020-03-09T06:00:00.000000000, MSLP netcdf: 98289.09883136411, wind_mod netcdf: 20.08305973987076
#
# Time tempest dict: 2020-03-09 12:00:00, lat tempest -25.5, lon tempest 198.0,  MSLP tempest: 98654.37, wind_mod tempest: 15.64316
# Time netcdf: 2020-03-09T12:00:00.000000000, MSLP netcdf: 98399.83311234151, wind_mod netcdf: 19.412586425630384
#
# Time tempest dict: 2020-03-09 18:00:00, lat tempest -26.5, lon tempest 199.0,  MSLP tempest: 98746.12, wind_mod tempest: 15.59584
# ...
#
# Time tempest dict: 2024-11-16 18:00:00, lat tempest 16.5, lon tempest 128.0,  MSLP tempest: 99094.13, wind_mod tempest: 19.33378
# Time netcdf: 2024-11-16T18:00:00.000000000, MSLP netcdf: 98531.73805455133, wind_mod netcdf: 24.45114258659227
#
# Time tempest dict: 2024-11-17 00:00:00, lat tempest 17.5, lon tempest 127.0,  MSLP tempest: 99529.25, wind_mod tempest: 18.03966
# Time netcdf: 2024-11-17T00:00:00.000000000, MSLP netcdf: 98684.39982469934, wind_mod netcdf: 25.878839790521354
#
# Time tempest dict: 2024-11-17 06:00:00, lat tempest 17.5, lon tempest 126.0,  MSLP tempest: 98885.54, wind_mod tempest: 18.21405
# Time netcdf: 2024-11-17T06:00:00.000000000, MSLP netcdf: 98358.41844840854, wind_mod netcdf: 28.43880483898512
#
# Time tempest dict: 2024-11-17 12:00:00, lat tempest 17.5, lon tempest 125.0,  MSLP tempest: 98974.06, wind_mod tempest: 18.58681
# Time netcdf: 2024-11-17T12:00:00.000000000, MSLP netcdf: 98428.93135728393, wind_mod netcdf: 28.976608706209603
#
# Time tempest dict: 2024-11-17 18:00:00, lat tempest 17.5, lon tempest 124.0,  MSLP tempest: 98653.2, wind_mod tempest: 19.12484
# Time netcdf: 2024-11-17T18:00:00.000000000, MSLP netcdf: 98015.7442861412, wind_mod netcdf: 28.924789742142877
#
# Time tempest dict: 2024-11-18 00:00:00, lat tempest 17.5, lon tempest 123.0,  MSLP tempest: 98830.39, wind_mod tempest: 20.52499
# Time netcdf: 2024-11-18T00:00:00.000000000, MSLP netcdf: 97649.10346471002, wind_mod netcdf: 35.777320676839985
#
# Time tempest dict: 2024-11-18 06:00:00, lat tempest 17.5, lon tempest 122.0,  MSLP tempest: 99154.2, wind_mod tempest: 19.7037
# Time netcdf: 2024-11-18T06:00:00.000000000, MSLP netcdf: 97777.38308738955, wind_mod netcdf: 28.907365048080315
#
# Time tempest dict: 2024-11-18 12:00:00, lat tempest 16.5, lon tempest 121.0,  MSLP tempest: 99898.72, wind_mod tempest: 17.36398
# Time netcdf: 2024-11-18T12:00:00.000000000, MSLP netcdf: 99287.60442864479, wind_mod netcdf: 20.981259002688024
#
# Time tempest dict: 2024-11-18 18:00:00, lat tempest 16.5, lon tempest 119.0,  MSLP tempest: 99716.69, wind_mod tempest: 19.13449
# Time netcdf: 2024-11-18T18:00:00.000000000, MSLP netcdf: 98799.05283853835, wind_mod netcdf: 23.953428701943352
#
# Time tempest dict: 2024-11-19 00:00:00, lat tempest 16.5, lon tempest 118.0,  MSLP tempest: 99673.86, wind_mod tempest: 18.99341
# Time netcdf: 2024-11-19T00:00:00.000000000, MSLP netcdf: 98784.46623554907, wind_mod netcdf: 28.059518874969335
#
# Time tempest dict: 2024-11-19 06:00:00, lat tempest 16.5, lon tempest 117.0,  MSLP tempest: 99402.58, wind_mod tempest: 17.69445
# Time netcdf: 2024-11-19T06:00:00.000000000, MSLP netcdf: 98415.2406072944, wind_mod netcdf: 29.179568661104152
#
# Time tempest dict: 2024-11-19 12:00:00, lat tempest 15.5, lon tempest 115.0,  MSLP tempest: 99861.62, wind_mod tempest: 20.65228
# Time netcdf: 2024-11-19T12:00:00.000000000, MSLP netcdf: 98504.78349339319, wind_mod netcdf: 27.45271360088709
#
# Time tempest dict: 2024-11-19 18:00:00, lat tempest 15.5, lon tempest 114.0,  MSLP tempest: 99347.46, wind_mod tempest: 19.79182
# Time netcdf: 2024-11-19T18:00:00.000000000, MSLP netcdf: 98480.09124085918, wind_mod netcdf: 30.378360350573267
#
# Time tempest dict: 2024-11-20 00:00:00, lat tempest 15.5, lon tempest 112.0,  MSLP tempest: 99477.06, wind_mod tempest: 19.29642
# Time netcdf: 2024-11-20T00:00:00.000000000, MSLP netcdf: 98213.11954231095, wind_mod netcdf: 32.110514763834615
#
# Time tempest dict: 2024-11-20 06:00:00, lat tempest 15.5, lon tempest 111.0,  MSLP tempest: 99434.62, wind_mod tempest: 19.49539
# Time netcdf: 2024-11-20T06:00:00.000000000, MSLP netcdf: 97655.05362626552, wind_mod netcdf: 35.46406551925678
#
# Time tempest dict: 2024-11-20 12:00:00, lat tempest 14.5, lon tempest 110.0,  MSLP tempest: 99363.69, wind_mod tempest: 22.21612
# Time netcdf: 2024-11-20T12:00:00.000000000, MSLP netcdf: 97604.20892580856, wind_mod netcdf: 36.26109051528057
#
# Time tempest dict: 2024-11-20 18:00:00, lat tempest 14.5, lon tempest 109.0,  MSLP tempest: 100110.5, wind_mod tempest: 15.73029
# Time netcdf: 2024-11-20T18:00:00.000000000, MSLP netcdf: 99310.55241893728, wind_mod netcdf: 20.478886575708152
#
# Created /home/b/b382216/work/tc/fullres/IFS/tco1279-orca025-cycle3/tempest_fullres_txt/fullres_tempest_track_20241025-20241123.txt
# Opened tempest file: /home/b/b382216/work/tc/tmpdir/IFS/tco1279-orca025-cycle3/tempest_track_20241124-20241223.txt
# Opened NetCDF file: /home/b/b382216/work/tc/fullres/IFS/tco1279-orca025-cycle3/tempest_tracks_20241124-20241223.nc
# Track 1:
# Track Length: 24, Year: 2024, Month: 11, Date: 30, Hour: 18
# Time tempest dict: 2024-11-30 18:00:00, lat tempest 8.5, lon tempest 151.0,  MSLP tempest: 100498.7, wind_mod tempest: 11.34478
# Time netcdf: 2024-11-30T18:00:00.000000000, MSLP netcdf: 100414.63786721039, wind_mod netcdf: 13.133776692947977
#
# Time tempest dict: 2024-12-01 00:00:00, lat tempest 9.5, lon tempest 150.0,  MSLP tempest: 100717.1, wind_mod tempest: 12.93587
# Time netcdf: 2024-12-01T00:00:00.000000000, MSLP netcdf: 100614.3119335761, wind_mod netcdf: 15.279617999680298
#
# Time tempest dict: 2024-12-01 06:00:00, lat tempest 10.5, lon tempest 149.0,  MSLP tempest: 100432.0, wind_mod tempest: 13.5767
# Time netcdf: 2024-12-01T06:00:00.000000000, MSLP netcdf: 100361.78705790173, wind_mod netcdf: 16.097508892279674
#
# Time tempest dict: 2024-12-01 12:00:00, lat tempest 11.5, lon tempest 148.0,  MSLP tempest: 100668.4, wind_mod tempest: 14.23738
# Time netcdf: 2024-12-01T12:00:00.000000000, MSLP netcdf: 100559.37480803696, wind_mod netcdf: 16.723142876824195
#
# Time tempest dict: 2024-12-01 18:00:00, lat tempest 11.5, lon tempest 147.0,  MSLP tempest: 100343.1, wind_mod tempest: 14.92622
# Time netcdf: 2024-12-01T18:00:00.000000000, MSLP netcdf: 100200.64656185886, wind_mod netcdf: 16.74126610066751
#
# Time tempest dict: 2024-12-02 00:00:00, lat tempest 12.5, lon tempest 146.0,  MSLP tempest: 100526.4, wind_mod tempest: 15.97282
# Time netcdf: 2024-12-02T00:00:00.000000000, MSLP netcdf: 100329.15208855653, wind_mod netcdf: 20.530009536994914
#
# Time tempest dict: 2024-12-02 06:00:00, lat tempest 12.5, lon tempest 145.0,  MSLP tempest: 100134.4, wind_mod tempest: 16.08655
# Time netcdf: 2024-12-02T06:00:00.000000000, MSLP netcdf: 99871.2247979839, wind_mod netcdf: 21.533662802901922
#
# Time tempest dict: 2024-12-02 12:00:00, lat tempest 13.5, lon tempest 144.0,  MSLP tempest: 100307.3, wind_mod tempest: 16.19707
# Time netcdf: 2024-12-02T12:00:00.000000000, MSLP netcdf: 99956.87523726403, wind_mod netcdf: 20.60322414345494
#
# Time tempest dict: 2024-12-02 18:00:00, lat tempest 13.5, lon tempest 143.0,  MSLP tempest: 99886.2, wind_mod tempest: 16.23321
# Time netcdf: 2024-12-02T18:00:00.000000000, MSLP netcdf: 99650.91712832058, wind_mod netcdf: 22.18373589355643
#
# Time tempest dict: 2024-12-03 00:00:00, lat tempest 13.5, lon tempest 142.0,  MSLP tempest: 100271.5, wind_mod tempest: 19.00152
# Time netcdf: 2024-12-03T00:00:00.000000000, MSLP netcdf: 99724.43794734775, wind_mod netcdf: 25.394960309253705
#
# Time tempest dict: 2024-12-03 06:00:00, lat tempest 14.5, lon tempest 142.0,  MSLP tempest: 99654.88, wind_mod tempest: 16.7854
# Time netcdf: 2024-12-03T06:00:00.000000000, MSLP netcdf: 99288.62327841214, wind_mod netcdf: 25.449061862042516
#
# Time tempest dict: 2024-12-03 12:00:00, lat tempest 14.5, lon tempest 141.0,  MSLP tempest: 99870.97, wind_mod tempest: 17.42001
# Time netcdf: 2024-12-03T12:00:00.000000000, MSLP netcdf: 99410.55797954256, wind_mod netcdf: 22.76341185242542
#
# Time tempest dict: 2024-12-03 18:00:00, lat tempest 15.5, lon tempest 141.0,  MSLP tempest: 99419.03, wind_mod tempest: 17.67871
# Time netcdf: 2024-12-03T18:00:00.000000000, MSLP netcdf: 98752.2894840988, wind_mod netcdf: 28.213533113332637
#
# Time tempest dict: 2024-12-04 00:00:00, lat tempest 15.5, lon tempest 141.0,  MSLP tempest: 99315.9, wind_mod tempest: 17.82797
# Time netcdf: 2024-12-04T00:00:00.000000000, MSLP netcdf: 98416.35673528424, wind_mod netcdf: 29.292031860959305
#
# Time tempest dict: 2024-12-04 06:00:00, lat tempest 16.5, lon tempest 141.0,  MSLP tempest: 99336.17, wind_mod tempest: 17.39374
# Time netcdf: 2024-12-04T06:00:00.000000000, MSLP netcdf: 97830.48220319023, wind_mod netcdf: 29.48825498279998
#
# Time tempest dict: 2024-12-04 12:00:00, lat tempest 16.5, lon tempest 141.0,  MSLP tempest: 99253.32, wind_mod tempest: 19.02629
# Time netcdf: 2024-12-04T12:00:00.000000000, MSLP netcdf: 97241.75788888463, wind_mod netcdf: 33.66424468741026
#
# Time tempest dict: 2024-12-04 18:00:00, lat tempest 17.5, lon tempest 141.0,  MSLP tempest: 99638.12, wind_mod tempest: 19.67212
# Time netcdf: 2024-12-04T18:00:00.000000000, MSLP netcdf: 96553.28216257939, wind_mod netcdf: 38.94786333728642
#
# Time tempest dict: 2024-12-05 00:00:00, lat tempest 17.5, lon tempest 142.0,  MSLP tempest: 99088.44, wind_mod tempest: 17.06729
# Time netcdf: 2024-12-05T00:00:00.000000000, MSLP netcdf: 96839.54333477856, wind_mod netcdf: 38.73026976566924
#
# Time tempest dict: 2024-12-05 06:00:00, lat tempest 18.5, lon tempest 143.0,  MSLP tempest: 99399.21, wind_mod tempest: 17.51021
# Time netcdf: 2024-12-05T06:00:00.000000000, MSLP netcdf: 96592.24577637919, wind_mod netcdf: 38.81053893846801
#
# Time tempest dict: 2024-12-05 12:00:00, lat tempest 18.5, lon tempest 144.0,  MSLP tempest: 99760.91, wind_mod tempest: 18.62235
# Time netcdf: 2024-12-05T12:00:00.000000000, MSLP netcdf: 97257.92776992524, wind_mod netcdf: 38.26649502281875
#
# Time tempest dict: 2024-12-05 18:00:00, lat tempest 19.5, lon tempest 145.0,  MSLP tempest: 99253.44, wind_mod tempest: 18.52072
# Time netcdf: 2024-12-05T18:00:00.000000000, MSLP netcdf: 97543.58581153104, wind_mod netcdf: 33.13146564753186
#
# Time tempest dict: 2024-12-06 00:00:00, lat tempest 20.5, lon tempest 146.0,  MSLP tempest: 100133.5, wind_mod tempest: 18.47799
# Time netcdf: 2024-12-06T00:00:00.000000000, MSLP netcdf: 98257.70650671072, wind_mod netcdf: 31.977696796996124
#
# Time tempest dict: 2024-12-06 06:00:00, lat tempest 20.5, lon tempest 148.0,  MSLP tempest: 99725.59, wind_mod tempest: 18.67575
# Time netcdf: 2024-12-06T06:00:00.000000000, MSLP netcdf: 98320.47759162441, wind_mod netcdf: 36.81481592207551
#
# Time tempest dict: 2024-12-06 12:00:00, lat tempest 21.5, lon tempest 150.0,  MSLP tempest: 100238.9, wind_mod tempest: 16.63335
# Time netcdf: 2024-12-06T12:00:00.000000000, MSLP netcdf: 99525.16326987899, wind_mod netcdf: 25.962111597232532
#
# Created /home/b/b382216/work/tc/fullres/IFS/tco1279-orca025-cycle3/tempest_fullres_txt/fullres_tempest_track_20241124-20241223.txt
# Opened tempest file: /home/b/b382216/work/tc/tmpdir/IFS/tco1279-orca025-cycle3/tempest_track_20241224-20250122.txt
# Opened NetCDF file: /home/b/b382216/work/tc/fullres/IFS/tco1279-orca025-cycle3/tempest_tracks_20241224-20250122.nc
# Track 1:
# Track Length: 21, Year: 2024, Month: 12, Date: 27, Hour: 0
# Time tempest dict: 2024-12-27 00:00:00, lat tempest -15.5, lon tempest 44.0,  MSLP tempest: 100045.7, wind_mod tempest: 12.19796
# Time netcdf: 2024-12-27T00:00:00.000000000, MSLP netcdf: 99798.15590108294, wind_mod netcdf: 17.208916520843506
#
# Time tempest dict: 2024-12-27 06:00:00, lat tempest -15.5, lon tempest 43.0,  MSLP tempest: 100344.2, wind_mod tempest: 12.73242
# Time netcdf: 2024-12-27T06:00:00.000000000, MSLP netcdf: 100075.02059258285, wind_mod netcdf: 16.26687239319775
#
# Time tempest dict: 2024-12-27 12:00:00, lat tempest -16.5, lon tempest 42.0,  MSLP tempest: 99972.44, wind_mod tempest: 12.24449
# Time netcdf: 2024-12-27T12:00:00.000000000, MSLP netcdf: 99828.443817046, wind_mod netcdf: 17.110046657827475
#
# Time tempest dict: 2024-12-27 18:00:00, lat tempest -16.5, lon tempest 42.0,  MSLP tempest: 100049.5, wind_mod tempest: 14.46044
# Time netcdf: 2024-12-27T18:00:00.000000000, MSLP netcdf: 99789.74861490085, wind_mod netcdf: 18.11021042570081
#
# Time tempest dict: 2024-12-28 00:00:00, lat tempest -16.5, lon tempest 41.0,  MSLP tempest: 99763.4, wind_mod tempest: 14.62352
# Time netcdf: 2024-12-28T00:00:00.000000000, MSLP netcdf: 99503.99693038856, wind_mod netcdf: 18.28046817025903
#
# Time tempest dict: 2024-12-28 06:00:00, lat tempest -16.5, lon tempest 39.0,  MSLP tempest: 99980.65, wind_mod tempest: 14.1457
# Time netcdf: 2024-12-28T06:00:00.000000000, MSLP netcdf: 99398.80330749387, wind_mod netcdf: 19.55080523076506
#
# Time tempest dict: 2024-12-28 12:00:00, lat tempest -17.5, lon tempest 39.0,  MSLP tempest: 99509.29, wind_mod tempest: 14.76191
# Time netcdf: 2024-12-28T12:00:00.000000000, MSLP netcdf: 99214.68405456474, wind_mod netcdf: 18.62793893487836
#
# Time tempest dict: 2024-12-28 18:00:00, lat tempest -17.5, lon tempest 38.0,  MSLP tempest: 99844.41, wind_mod tempest: 14.20254
# Time netcdf: 2024-12-28T18:00:00.000000000, MSLP netcdf: 99485.62854134856, wind_mod netcdf: 18.721272248761437
#
# Time tempest dict: 2024-12-29 00:00:00, lat tempest -18.5, lon tempest 38.0,  MSLP tempest: 99432.78, wind_mod tempest: 15.96811
# Time netcdf: 2024-12-29T00:00:00.000000000, MSLP netcdf: 99173.07658951523, wind_mod netcdf: 19.439123112197883
#
# Time tempest dict: 2024-12-29 06:00:00, lat tempest -19.5, lon tempest 37.0,  MSLP tempest: 99632.36, wind_mod tempest: 15.55293
# Time netcdf: 2024-12-29T06:00:00.000000000, MSLP netcdf: 99207.53707179148, wind_mod netcdf: 19.659436961782824
#
# Time tempest dict: 2024-12-29 12:00:00, lat tempest -20.5, lon tempest 37.0,  MSLP tempest: 99339.45, wind_mod tempest: 15.48664
# Time netcdf: 2024-12-29T12:00:00.000000000, MSLP netcdf: 98883.08559070346, wind_mod netcdf: 21.576525214833364
#
# Time tempest dict: 2024-12-29 18:00:00, lat tempest -20.5, lon tempest 37.0,  MSLP tempest: 99573.07, wind_mod tempest: 15.92783
# Time netcdf: 2024-12-29T18:00:00.000000000, MSLP netcdf: 99138.92768014765, wind_mod netcdf: 18.975881649936156
#
# Time tempest dict: 2024-12-30 00:00:00, lat tempest -21.5, lon tempest 37.0,  MSLP tempest: 99476.52, wind_mod tempest: 15.66218
# Time netcdf: 2024-12-30T00:00:00.000000000, MSLP netcdf: 98884.9688153252, wind_mod netcdf: 19.830352078606595
#
# Time tempest dict: 2024-12-30 06:00:00, lat tempest -21.5, lon tempest 37.0,  MSLP tempest: 99754.84, wind_mod tempest: 15.83332
# Time netcdf: 2024-12-30T06:00:00.000000000, MSLP netcdf: 98924.0890280329, wind_mod netcdf: 21.272683261800015
#
# Time tempest dict: 2024-12-30 12:00:00, lat tempest -22.5, lon tempest 37.0,  MSLP tempest: 99346.89, wind_mod tempest: 16.23841
# Time netcdf: 2024-12-30T12:00:00.000000000, MSLP netcdf: 98660.70253951094, wind_mod netcdf: 20.471098995175105
#
# Time tempest dict: 2024-12-30 18:00:00, lat tempest -23.5, lon tempest 37.0,  MSLP tempest: 99579.73, wind_mod tempest: 15.12473
# Time netcdf: 2024-12-30T18:00:00.000000000, MSLP netcdf: 98713.15699262207, wind_mod netcdf: 20.151304961203177
#
# Time tempest dict: 2024-12-31 00:00:00, lat tempest -23.5, lon tempest 37.0,  MSLP tempest: 99340.41, wind_mod tempest: 15.55599
# Time netcdf: 2024-12-31T00:00:00.000000000, MSLP netcdf: 98554.92842798107, wind_mod netcdf: 20.322070028736544
#
# Time tempest dict: 2024-12-31 06:00:00, lat tempest -23.5, lon tempest 37.0,  MSLP tempest: 99281.95, wind_mod tempest: 15.38901
# Time netcdf: 2024-12-31T06:00:00.000000000, MSLP netcdf: 98755.35954664253, wind_mod netcdf: 19.591714297954947
#
# Time tempest dict: 2024-12-31 12:00:00, lat tempest -23.5, lon tempest 37.0,  MSLP tempest: 99185.98, wind_mod tempest: 17.03101
# Time netcdf: 2024-12-31T12:00:00.000000000, MSLP netcdf: 98613.65094054771, wind_mod netcdf: 23.03576639976217
#
# Time tempest dict: 2024-12-31 18:00:00, lat tempest -23.5, lon tempest 38.0,  MSLP tempest: 99206.96, wind_mod tempest: 16.71832
# Time netcdf: 2024-12-31T18:00:00.000000000, MSLP netcdf: 98790.48402720527, wind_mod netcdf: 22.000633689871698
#
# Time tempest dict: 2025-01-01 00:00:00, lat tempest -23.5, lon tempest 38.0,  MSLP tempest: 98962.92, wind_mod tempest: 17.54746
# Time netcdf: 2025-01-01T00:00:00.000000000, MSLP netcdf: 98605.08450264034, wind_mod netcdf: 22.78228359781992
#
# Created /home/b/b382216/work/tc/fullres/IFS/tco1279-orca025-cycle3/tempest_fullres_txt/fullres_tempest_track_20241224-20250122.txt
