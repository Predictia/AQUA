# %% [markdown]
# # Example notebok for dummy diagnostic
#
# Each diagnostic should have a notebook that demonstrates how to use it.
# This notebook should be placed in this folder.
# The notebook should be named after the diagnostic itself or a particular functionality, with the extension .ipynb.

# %%
import sys
# temporary hack if your env-dummy.yml
# does not install your diagnostic.
sys.path.insert(0, '../')
from dummy_class import DummyDiagnostic
# Out:
# FDB5 binary library not present on system, disabling FDB support.

# %%
# Empty class to be filled with your diagnostic
# It prints the catalogue as example of what you can do
# with the aqua module

model = 'ERA5'
exp = 'era5'
source = 'monthly'
var = 'msl'

dummy = DummyDiagnostic(model=model, exp=exp, source=source, var=var, loglevel='DEBUG')
# Out:
# 2023-06-23 10:17:22 :: Dummy :: WARNING  -> No regridding will be performed
# 2023-06-23 10:17:22 :: Dummy :: INFO     -> Regridding resolution: None
# 2023-06-23 10:17:22 :: Dummy :: INFO     -> Custom diagnostic variable: I'm a custom variable
# 2023-06-23 10:17:22 :: Dummy :: WARNING  -> No config directory specified
# 2023-06-23 10:17:22 :: Dummy :: WARNING  -> Config file not found
# 2023-06-23 10:17:22 :: Dummy :: WARNING  -> Please be sure all the settings are passed as arguments
# 2023-06-23 10:17:22 :: Dummy :: INFO     -> No figure folder specified, trying to use the config file setting
# 2023-06-23 10:17:22 :: Dummy :: WARNING  -> No figure folder specified, using the current directory
# 2023-06-23 10:17:22 :: Dummy :: DEBUG    -> Figure output folder: /home/b/b382289/AQUA/diagnostics/dummy/notebooks
# 2023-06-23 10:17:22 :: Dummy :: INFO     -> No data folder specified, trying to use the config file setting
# 2023-06-23 10:17:22 :: Dummy :: WARNING  -> No data folder specified, using the current directory
# 2023-06-23 10:17:22 :: Dummy :: DEBUG    -> Data output folder: /home/b/b382289/AQUA/diagnostics/dummy/notebooks
# 2023-06-23 10:17:22 :: Dummy :: INFO     -> No filename specified, using the config file setting
# 2023-06-23 10:17:22 :: Dummy :: WARNING  -> No filename specified, using the default one
# 2023-06-23 10:17:22 :: Dummy :: DEBUG    -> Output filename: dummy.nc
# 2023-06-23 10:17:28 :: Dummy :: DEBUG    -> Reader class initialized

# %%
dummy.retrieve()
# Out:
# 2023-06-23 10:17:28 :: Reader :: INFO     -> Retrieving variables: ['msl']
# 2023-06-23 10:17:28 :: Reader :: DEBUG    -> Variables in the fixes: {'msl': {'grib': True, 'source': 'MSL'}, 'sst': {'grib': True, 'source': 'SSTK'}}
# 2023-06-23 10:17:28 :: Reader :: INFO     -> msl: Pa --> Pa
# 2023-06-23 10:17:28 :: Dummy :: INFO     -> Data retrieved

# %%
dummy.data
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 996, lat: 721, lon: 1440)
# Coordinates:
#   * time     (time) datetime64[ns] 1940-01-01 1940-02-01 ... 2022-12-01
#   * lon      (lon) float64 0.0 0.25 0.5 0.75 1.0 ... 359.0 359.2 359.5 359.8
#   * lat      (lat) float64 90.0 89.75 89.5 89.25 ... -89.25 -89.5 -89.75 -90.0
# Data variables:
#     msl      (time, lat, lon) float32 dask.array<chunksize=(12, 721, 1440), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 2.2.1 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     institution:  European Centre for Medium-Range Weather Forecasts
#     history:      Thu May 25 12:09:12 2023: cdo -O -s -f nc4 -z zip -shifttim...
#     CDO:          Climate Data Operators version 2.2.0 (https://mpimet.mpg.de...

# %%
dummy.multiplication()

# %%
dummy.multiplication
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 996, lon: 1440, lat: 721)
# Coordinates:
#   * time     (time) datetime64[ns] 1940-01-01 1940-02-01 ... 2022-12-01
#   * lon      (lon) float64 0.0 0.25 0.5 0.75 1.0 ... 359.0 359.2 359.5 359.8
#   * lat      (lat) float64 90.0 89.75 89.5 89.25 ... -89.25 -89.5 -89.75 -90.0
# Data variables:
#     msl      (time, lat, lon) float32 dask.array<chunksize=(12, 721, 1440), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 2.2.1 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     institution:  European Centre for Medium-Range Weather Forecasts
#     history:      Thu May 25 12:09:12 2023: cdo -O -s -f nc4 -z zip -shifttim...
#     CDO:          Climate Data Operators version 2.2.0 (https://mpimet.mpg.de...

# %%
dummy._secret_method()
# Out:
# 2023-06-23 10:17:28 :: Dummy :: DEBUG    -> This is a secret method

# %%
dummy.fldmean()
# Out:
# 2023-06-23 10:17:50 :: Dummy :: INFO     -> Field mean computed
# 2023-06-23 10:17:50 :: Dummy :: INFO     -> Field mean: <xarray.Dataset>
# Dimensions:  (time: 996)
# Coordinates:
#   * time     (time) datetime64[ns] 1940-01-01 1940-02-01 ... 2022-12-01
# Data variables:
#     msl      (time) float64 dask.array<chunksize=(12,), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 2.2.1 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     institution:  European Centre for Medium-Range Weather Forecasts
#     history:      Thu May 25 12:09:12 2023: cdo -O -s -f nc4 -z zip -shifttim...
#     CDO:          Climate Data Operators version 2.2.0 (https://mpimet.mpg.de...

# %%
dummy.fldmean[var].plot()
