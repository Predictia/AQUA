# %% [markdown]
# # Global mean seasonal cycles
#
# This notebook shows how to use the global time series diagnostic to evaluate seasonal cycles.

# %% [markdown]
# The `SeasonalCycle` class is a derivation of the `Timeseries` class  and provides an easy interface to plot seasonal cycles for a given list of experiments and a variable or formula.

# %%
from global_time_series import SeasonalCycle

# %% [markdown]
# Let's plot the global mean temperature for the historical experiment, with a comparison done with the same ERA5 time span and 1990-1999 climatology.

# %%
sc = SeasonalCycle(var='2t', models='IFS-NEMO', exps='historical-1990', sources='lra-r100-monthly',
                   startdate='1990-01-01', enddate='1999-12-31',
                   std_startdate='1990-01-01', std_enddate='1999-12-31',
                   save=False, loglevel='INFO')
# Out:
# 2024-02-26 15:51:06 :: Timeseries :: INFO     -> Figure will not be saved
# 2024-02-26 15:51:06 :: SeasonalCycle :: INFO     -> SeasonalCycle class initialized
# 2024-02-26 15:51:06 :: SeasonalCycle :: INFO     -> SeasonalCycle class initialized

# %% [markdown]
# By default the `SeasonalCycle` class will use `ERA5` as the reference dataset, but you can change it by setting the `plot_ref_kw` parameter to the desired dataset.
#
# The seasonalcycle is generated, plot and saved by running the `run` method of the `SeasonalCycle` class.

# %%
sc.run()
# Out:
# 2024-02-26 15:51:08 :: SeasonalCycle :: INFO     -> Retrieving data for IFS-NEMO historical-1990 lra-r100-monthly
# 2024-02-26 15:51:09 :: Reader :: INFO     -> No specific fix found, will call the default fix IFS-NEMO-default
# 2024-02-26 15:51:09 :: Reader :: WARNING  -> The requested default fixer name IFS-NEMO-default does not exist in fixes files
# 2024-02-26 15:51:09 :: Reader :: WARNING  -> No fixes available for model IFS-NEMO, experiment historical-1990, source lra-r100-monthly
# 2024-02-26 15:51:09 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-02-26 15:51:09 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2024-02-26 15:51:16 :: SeasonalCycle :: INFO     -> Monthly data retrieved
# 2024-02-26 15:51:16 :: Reader :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2024-02-26 15:51:16 :: Reader :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2024-02-26 15:51:16 :: Reader :: INFO     -> Grid metadata is era5-r025
# 2024-02-26 15:51:16 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2024-02-26 15:51:17 :: Reader :: INFO     -> Variables to be fixed: {'2t': {'grib': True, 'source': 'T2M'}}
# 2024-02-26 15:51:17 :: Reader :: INFO     -> 2t: converting units K --> K
# 2024-02-26 15:51:17 :: Reader :: INFO     -> coordinates adjusted to cf by AQUA fixer
# 2024-02-26 15:51:17 :: SeasonalCycle :: INFO     -> Extracting the seasonal cycle
# 2024-02-26 15:51:17 :: SeasonalCycle :: INFO     -> Processing IFS-NEMO historical-1990
