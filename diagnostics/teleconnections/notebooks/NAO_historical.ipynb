# %%
from teleconnections import Teleconnection

# %%
tc_ERA = Teleconnection(model='ERA5', exp='era5', source='monthly', loglevel='INFO', telecname='NAO', startdate="1990-01-01", enddate="1998-11-01", savefig=True)
# Out:
# 2024-01-25 11:26:37 :: Teleconnection :: WARNING  -> No regrid will be performed, be sure that the data is already at low resolution
# 2024-01-25 11:26:37 :: Teleconnection :: WARNING  -> No time aggregation will be performed, be sure that the data is already at the desired frequency
# 2024-01-25 11:26:37 :: Teleconnection :: INFO     -> Namelist loaded
# 2024-01-25 11:26:37 :: Teleconnection :: WARNING  -> No figure folder specified, using the current directory
# 2024-01-25 11:26:37 :: Teleconnection :: INFO     -> No filename specified, using the default name
# 2024-01-25 11:26:37 :: Teleconnection :: INFO     -> Saving figures to None/None
# 2024-01-25 11:26:37 :: Reader :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2024-01-25 11:26:37 :: Reader :: INFO     -> Fix names ERA5-destine-v1 found for model ERA5, experiment era5, source monthly
# 2024-01-25 11:26:38 :: Reader :: INFO     -> Grid metadata is era5-r025
# 2024-01-25 11:26:38 :: Teleconnection :: INFO     -> Reader initialized

# %%
tc_ERA.evaluate_index()
# Out:
# 2024-01-25 11:26:40 :: Teleconnection :: WARNING  -> No retrieve has been performed, trying to retrieve
# 2024-01-25 11:26:40 :: Reader :: INFO     -> Retrieving variables: ['msl']
# 2024-01-25 11:26:40 :: Reader :: INFO     -> Retrieving variables: ['msl']
# /LUMI_TYKKY_Qwg3aWT/miniconda/envs/env1/lib/python3.11/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# 2024-01-25 11:26:40 :: Reader :: INFO     -> Variables to be fixed: {'msl': {'grib': True, 'source': 'MSL'}}
# 2024-01-25 11:26:40 :: Reader :: INFO     -> msl: converting units Pa --> Pa
# 2024-01-25 11:26:40 :: Reader :: INFO     -> coordinates adjusted to cf by AQUA fixer
# 2024-01-25 11:26:40 :: Teleconnection :: INFO     -> Data retrieved
# 2024-01-25 11:26:49 :: Teleconnection :: INFO     -> Index evaluated

# %%
tc_ERA.plot_index(title='NAO index (ERA5, 1990-1998)')
# Out:
# 2024-01-25 11:26:50 :: Teleconnection :: INFO     -> Index plot saved to /pfs/lustrep3/projappl/project_465000454/nurissom/AQUA/diagnostics/teleconnections/notebooks/teleconnections_ERA5_era5_monthly_NAO_index.pdf

# %%
reg_ERA_DFJ = tc_ERA.evaluate_regression(season='DJF')
reg_ERA_JJA = tc_ERA.evaluate_regression(season='JJA')
cor_ERA_DJF = tc_ERA.evaluate_correlation(season='DJF')
cor_ERA_JJA = tc_ERA.evaluate_correlation(season='JJA')

# %%
tc_IFS = Teleconnection(model='IFS-NEMO', exp='historical-1990', source='lra-r100-monthly', loglevel='INFO', telecname='NAO', savefig=True)
# Out:
# 2024-01-25 11:27:10 :: Teleconnection :: WARNING  -> No regrid will be performed, be sure that the data is already at low resolution
# 2024-01-25 11:27:10 :: Teleconnection :: WARNING  -> No time aggregation will be performed, be sure that the data is already at the desired frequency
# 2024-01-25 11:27:10 :: Teleconnection :: INFO     -> Namelist loaded
# 2024-01-25 11:27:10 :: Teleconnection :: WARNING  -> No figure folder specified, using the current directory
# 2024-01-25 11:27:10 :: Teleconnection :: INFO     -> No filename specified, using the default name
# 2024-01-25 11:27:10 :: Teleconnection :: INFO     -> Saving figures to None/None
# 2024-01-25 11:27:10 :: Reader :: WARNING  -> No fixes available for model IFS-NEMO
# 2024-01-25 11:27:10 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2024-01-25 11:27:10 :: Teleconnection :: INFO     -> Reader initialized

# %%
tc_IFS.evaluate_index()
# Out:
# 2024-01-25 11:27:12 :: Teleconnection :: WARNING  -> No retrieve has been performed, trying to retrieve
# 2024-01-25 11:27:12 :: Reader :: INFO     -> Retrieving variables: ['msl']
# 2024-01-25 11:27:12 :: Reader :: INFO     -> Retrieving variables: ['msl']
# /LUMI_TYKKY_Qwg3aWT/miniconda/envs/env1/lib/python3.11/site-packages/xarray/core/indexing.py:1446: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /LUMI_TYKKY_Qwg3aWT/miniconda/envs/env1/lib/python3.11/site-packages/xarray/core/indexing.py:1446: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /LUMI_TYKKY_Qwg3aWT/miniconda/envs/env1/lib/python3.11/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# 2024-01-25 11:27:17 :: Teleconnection :: INFO     -> Data retrieved
# 2024-01-25 11:27:17 :: Teleconnection :: INFO     -> Index evaluated

# %%
tc_IFS.plot_index(title='NAO index (IFS-NEMO, 1990-1998)')
# Out:
# 2024-01-25 11:27:18 :: Teleconnection :: INFO     -> Index plot saved to /pfs/lustrep3/projappl/project_465000454/nurissom/AQUA/diagnostics/teleconnections/notebooks/teleconnections_IFS-NEMO_historical-1990_lra-r100-monthly_NAO_index.pdf

# %%
reg_IFS_DFJ = tc_IFS.evaluate_regression(season='DJF')
reg_IFS_JJA = tc_IFS.evaluate_regression(season='JJA')
cor_IFS_DJF = tc_IFS.evaluate_correlation(season='DJF')
cor_IFS_JJA = tc_IFS.evaluate_correlation(season='JJA')

# %%
from teleconnections import maps_plot

# %%
maps_reg = [reg_ERA_DFJ, reg_IFS_DFJ, reg_ERA_JJA, reg_IFS_JJA]
titles = ['ERA5 DJF regression', 'IFS-NEMO DJF regression', 'ERA5 JJA regression', 'IFS-NEMO JJA regression']

# %%
maps_plot(maps_reg, title='NAO regression maps (1990-1998)', titles=titles, save=True, filename='NAO_regression_maps.pdf')

# %%
cor_maps = [cor_ERA_DJF, cor_IFS_DJF, cor_ERA_JJA, cor_IFS_JJA]
titles = ['ERA5 DJF correlation', 'IFS-NEMO DJF correlation', 'ERA5 JJA correlation', 'IFS-NEMO JJA correlation']

maps_plot(cor_maps, title='NAO correlation maps (1990-1998)', titles=titles, save=True, filename='NAO_correlation_maps.pdf')
