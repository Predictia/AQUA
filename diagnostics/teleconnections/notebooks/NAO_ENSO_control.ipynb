# %%
from teleconnections import Teleconnection

# %%
tc_IFS = Teleconnection(model='ERA5', exp='era5', source='monthly', loglevel='INFO', telecname='NAO', startdate="1990-01-01", enddate="1997-12-31")
# Out:
# 2024-01-24 18:42:55 :: Teleconnection :: WARNING  -> No regrid will be performed, be sure that the data is already at low resolution
# 2024-01-24 18:42:55 :: Teleconnection :: WARNING  -> No time aggregation will be performed, be sure that the data is already at the desired frequency
# 2024-01-24 18:42:55 :: Teleconnection :: INFO     -> Namelist loaded
# 2024-01-24 18:42:55 :: Reader :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2024-01-24 18:42:56 :: Reader :: INFO     -> Fix names ERA5-destine-v1 found for model ERA5, experiment era5, source monthly
# 2024-01-24 18:42:56 :: Reader :: INFO     -> Grid metadata is era5-r025
# 2024-01-24 18:43:00 :: Teleconnection :: INFO     -> Reader initialized

# %%
tc_IFS.evaluate_index()
# Out:
# 2024-01-24 18:43:28 :: Teleconnection :: WARNING  -> No retrieve has been performed, trying to retrieve
# 2024-01-24 18:43:28 :: Reader :: INFO     -> Retrieving variables: ['msl']
# 2024-01-24 18:43:28 :: Reader :: INFO     -> Retrieving variables: ['msl']
# /LUMI_TYKKY_Qwg3aWT/miniconda/envs/env1/lib/python3.11/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# 2024-01-24 18:43:29 :: Reader :: INFO     -> Variables to be fixed: {'msl': {'grib': True, 'source': 'MSL'}}
# 2024-01-24 18:43:29 :: Reader :: INFO     -> msl: converting units Pa --> Pa
# 2024-01-24 18:43:29 :: Reader :: INFO     -> coordinates adjusted to cf by AQUA fixer
# 2024-01-24 18:43:29 :: Teleconnection :: INFO     -> Data retrieved
# ...

# %%
tc_IFS.plot_index()
