# %%
from aqua.diagnostics import sshVariabilityCompute
from aqua.diagnostics import sshVariabilityPlot
# Out:
# /work/ab0995/a270260/aqua/lib/python3.12/site-packages/intake_esm/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %%
model_dict = {"var":"zos","model":"IFS-FESOM", "exp":"ssp370","source":"lra-r100-monthly","startdate":"2021-01-01","enddate":"2021-02-01"}

# %%
ssh_model = sshVariabilityCompute(**model_dict)

# %%
ssh_model.run()
# Out:
# 2025-09-29 22:31:59 :: ConfigPath :: WARNING  -> Multiple triplets found in ['nextgems4', 'climatedt-phase1'], setting nextgems4 as the default
# 2025-09-29 22:31:59 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2025-09-29 22:31:59 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2025-09-29 22:32:19 :: Reader :: WARNING  -> No match found for [262124, 263124, 'avg_zos', 'ssh', 'zos']
# 2025-09-29 22:32:19 :: Reader :: ERROR    -> Retrieved empty dataset for var=['zos']. First, check its existence in the data catalog.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ssh_model.run()
#
# File /work/ab0995/a270260/AQUA_13/AQUA/src/aqua_diagnostics/sshVariability/ssh_variability.py:71, in sshVariabilityCompute.run(self)
#      69 def run(self):
# ...

# %%
from aqua import Reader

# %%
reader = Reader(model="IFS-FESOM",exp="ssp370",source="lra-r100-monthly")
# Out:
# 2025-09-29 23:10:49 :: ConfigPath :: WARNING  -> Multiple triplets found in ['nextgems4', 'climatedt-phase1'], setting nextgems4 as the default
# 2025-09-29 23:10:50 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2025-09-29 23:10:50 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data

# %%
data = reader.retrieve()
# Out:
# ECCODES ERROR   :  concept: no match for shortName=cprea
# ECCODES ERROR   :  concept: input handle edition=2, centre=0
# ECCODES ERROR   :  Please check the Parameter Database 'https://codes.ecmwf.int/grib/param-db/'
# ECCODES ERROR   :  concept: no match for shortName=sisnthick
# ECCODES ERROR   :  concept: input handle edition=2, centre=0
# ECCODES ERROR   :  Please check the Parameter Database 'https://codes.ecmwf.int/grib/param-db/'

# %%
data
# Out:
# <xarray.Dataset> Size: 45GB
# Dimensions:    (time: 359, lat: 180, lon: 360, level: 69, plev: 19)
# Coordinates:
#   * time       (time) datetime64[ns] 3kB 2020-02-01 2020-03-01 ... 2049-12-01
#   * lat        (lat) float64 1kB -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * lon        (lon) float64 3kB 0.0 1.0 2.0 3.0 4.0 ... 356.0 357.0 358.0 359.0
#   * level      (level) float64 552B 2.5 7.5 12.5 ... 5.825e+03 6.175e+03
#     idx_level  (level) int64 552B dask.array<chunksize=(69,), meta=np.ndarray>
#   * plev       (plev) float64 152B 1e+05 9.25e+04 8.5e+04 ... 1e+03 500.0 100.0
# Data variables: (12/35)
#     2t         (time, lat, lon) float64 186MB dask.array<chunksize=(1, 180, 360), meta=np.ndarray>
#     siconc     (time, lat, lon) float64 186MB dask.array<chunksize=(9, 180, 360), meta=np.ndarray>
#     sithick    (time, lat, lon) float64 186MB dask.array<chunksize=(9, 180, 360), meta=np.ndarray>
# ...
