# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from aqua.diagnostics.ocean_drift.hovmoller import Hovmoller
from aqua.diagnostics.ocean_drift.plot_hovmoller import PlotHovmoller

# %%
hov = Hovmoller(
    catalog='mn5-phase2',
    model='IFS-NEMO',
    exp='control-1990-freeze',
    source='lra-r100-monthly',
    startdate='01-01-1991',
    enddate='31-05-1991',
    loglevel='INFO'
)

# %%
hov.run(region='sss', dim_mean='lat', anomaly_ref='t0')
# Out:
# 2025-06-20 16:46:01 :: Hovmoller :: INFO     -> Running Hovmoller diagram generation
# 2025-06-20 16:46:01 :: ConfigPath :: INFO     -> IFS-NEMO_control-1990-freeze_lra-r100-monthly triplet found in in mn5-phase2!
# 2025-06-20 16:46:02 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-06-20 16:46:02 :: Fixer :: INFO     -> No fixer_name found, only convention will be applied
# 2025-06-20 16:46:02 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2025-06-20 16:46:02 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2025-06-20 16:46:02 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2025-06-20 16:47:31 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2025-06-20 16:47:31 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2025-06-20 16:47:31 :: Regridder :: INFO     -> Grid name: lon-lat
# 2025-06-20 16:47:31 :: Regridder :: INFO     -> Loading existing source area from /gpfs/scratch/ehpc01/data/AQUA/areas/cell_area_IFS-NEMO_control-1990-freeze_lra-r100-monthly.nc.
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Loading data model from /home/bsc/bsc032946/.aqua/data_model/aqua.yaml
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Analysing coordinate: time
# 2025-06-20 16:47:31 :: Reader :: INFO     -> Retrieving variables: ['thetao', 'so']
# 2025-06-20 16:47:31 :: Fixer :: INFO     -> Variables to be fixed: {'so': {'source': [262500, 263500, 'salt', 'avg_so', 'so'], 'grid': 262500}, 'thetao': {'source': [150129, 262501, 263501, 'avg_thetao', 'temp', 'ocpt', 'to', 'thetao'], 'grid': 262501}}
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Loading data model from /home/bsc/bsc032946/.aqua/data_model/aqua.yaml
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-06-20 16:47:31 :: CoordTransator :: INFO     -> Analysing coordinate: time
# 2025-06-20 16:47:31 :: Hovmoller :: INFO     -> Data retrieved successfully
# 2025-06-20 16:47:31 :: Hovmoller :: INFO     -> Region Sargasso Sea found, using lon: [-70, -50], lat: [20, 35]
# 2025-06-20 16:47:31 :: Hovmoller :: INFO     -> Applying area selection for region: Sargasso Sea
# 2025-06-20 16:47:31 :: Hovmoller :: INFO     -> Modified longname of the region: Sargasso Sea
# 2025-06-20 16:47:31 :: Hovmoller :: INFO     -> Processing data with standardise=False, anomaly_ref=t0
# 2025-06-20 16:47:31 :: Hovmoller :: INFO     -> Processing data with standardise=False, anomaly_ref=None
# 2025-06-20 16:47:31 :: Hovmoller :: INFO     -> Processing data with standardise=True, anomaly_ref=t0
# 2025-06-20 16:47:31 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-06-20 16:47:32 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/ocean_drift.hovmoller_anom_t0.mn5-phase2.IFS-NEMO.control-1990-freeze.sss.nc
# 2025-06-20 16:47:32 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-06-20 16:47:33 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/ocean_drift.hovmoller_full.mn5-phase2.IFS-NEMO.control-1990-freeze.sss.nc
# 2025-06-20 16:47:33 :: create_folder :: INFO     -> Folder ./netcdf already exists
# /home/bsc/bsc032946/.conda/envs/aquas/lib/python3.12/site-packages/dask/array/numpy_compat.py:57: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# 2025-06-20 16:47:34 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/ocean_drift.hovmoller_std_anom_t0.mn5-phase2.IFS-NEMO.control-1990-freeze.sss.nc
# 2025-06-20 16:47:34 :: Hovmoller :: INFO     -> Hovmoller diagram saved to netCDF file

# %%
hov_plot = PlotHovmoller(data = hov.processed_data_list)
hov_plot.plot_hovmoller()
# Out:
# /home/bsc/bsc032946/.conda/envs/aquas/lib/python3.12/site-packages/dask/array/numpy_compat.py:57: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# /home/bsc/bsc032946/.conda/envs/aquas/lib/python3.12/site-packages/dask/array/numpy_compat.py:57: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
