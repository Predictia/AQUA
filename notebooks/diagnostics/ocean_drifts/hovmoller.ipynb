# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from aqua.diagnostics.ocean_drift.hovmoller import Hovmoller
from aqua.diagnostics.ocean_drift.plot_hovmoller import PlotHovmoller
# Out:
# /home/bsc/bsc032946/.conda/envs/aqua/lib/python3.12/site-packages/intake_esm/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %%
hov = Hovmoller(
    catalog='mn5-phase2',
    model='IFS-NEMO',
    exp='control-1990-freeze',
    source='lra-r100-monthly',
    startdate='01-01-1991',
    enddate='31-05-1994',
    loglevel='INFO'
)

# %%
hov.run(
    region='io',
    dim_mean=['lat', 'lon'],
    anomaly_ref='t0'
)
# Out:
# 2025-09-04 13:28:09 :: Hovmoller :: INFO     -> Running Hovmoller diagram generation
# 2025-09-04 13:28:09 :: ConfigPath :: INFO     -> IFS-NEMO_control-1990-freeze_lra-r100-monthly triplet found in in mn5-phase2!
# 2025-09-04 13:28:09 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-09-04 13:28:09 :: Fixer :: INFO     -> No fixer_name found, only convention will be applied
# 2025-09-04 13:28:09 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2025-09-04 13:28:09 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2025-09-04 13:28:09 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2025-09-04 13:28:47 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-09-04 13:28:47 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2025-09-04 13:28:47 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-09-04 13:28:47 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2025-09-04 13:28:47 :: Regridder :: INFO     -> Grid name: lon-lat
# 2025-09-04 13:28:47 :: Regridder :: INFO     -> Loading existing source area from /gpfs/scratch/ehpc01/data/AQUA/areas/cell_area_IFS-NEMO_control-1990-freeze_lra-r100-monthly.nc.
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Loading data model from /home/bsc/bsc032946/.aqua/data_model/aqua.yaml
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Analysing coordinate: time
# 2025-09-04 13:28:47 :: Reader :: INFO     -> Retrieving variables: ['thetao', 'so']
# 2025-09-04 13:28:47 :: Fixer :: INFO     -> Variables to be fixed: {'so': {'source': [262500, 263500, 'salt', 'avg_so', 'so'], 'grid': 262500}, 'thetao': {'source': [150129, 262501, 263501, 'avg_thetao', 'temp', 'ocpt', 'to', 'thetao'], 'grid': 262501}}
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Loading data model from /home/bsc/bsc032946/.aqua/data_model/aqua.yaml
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-09-04 13:28:47 :: CoordTransator :: INFO     -> Analysing coordinate: time
# 2025-09-04 13:28:47 :: Hovmoller :: INFO     -> Data retrieved successfully
# 2025-09-04 13:28:47 :: Hovmoller :: INFO     -> Selecting region: io for diagnostic 'ocean3d'.
# 2025-09-04 13:28:47 :: Hovmoller :: INFO     -> Region Indian Ocean found, using lon: [30, 110], lat: [-30, 30]
# 2025-09-04 13:28:47 :: Hovmoller :: INFO     -> Applying area selection for region: Indian Ocean
# 2025-09-04 13:28:47 :: FldStat :: INFO     -> Computing area-weighted mean on ['lat', 'lon'] dimensions
# 2025-09-04 13:28:47 :: Hovmoller :: INFO     -> Processing data with standardise=False, anomaly_ref=t0
# 2025-09-04 13:28:47 :: Hovmoller :: INFO     -> Processing data with standardise=False, anomaly_ref=None
# 2025-09-04 13:28:47 :: Hovmoller :: INFO     -> Processing data with standardise=True, anomaly_ref=t0
# 2025-09-04 13:28:47 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-04 13:29:03 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/ocean_drift.hovmoller_full.mn5-phase2.IFS-NEMO.control-1990-freeze.r1.io.nc
# 2025-09-04 13:29:03 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-04 13:29:19 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/ocean_drift.hovmoller_anom_t0.mn5-phase2.IFS-NEMO.control-1990-freeze.r1.io.nc
# 2025-09-04 13:29:19 :: create_folder :: INFO     -> Folder ./netcdf already exists
# /home/bsc/bsc032946/.conda/envs/aqua/lib/python3.12/site-packages/dask/array/numpy_compat.py:57: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# 2025-09-04 13:29:34 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/ocean_drift.hovmoller_std_anom_t0.mn5-phase2.IFS-NEMO.control-1990-freeze.r1.io.nc
# 2025-09-04 13:29:34 :: Hovmoller :: INFO     -> Hovmoller diagram saved to netCDF file

# %%
hov_plot = PlotHovmoller(data = hov.processed_data_list)
hov_plot.plot_hovmoller()
# Out:
# /gpfs/projects/ehpc01/sghosh/AQUA/src/aqua/graphics/hovmoller.py:200: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /gpfs/projects/ehpc01/sghosh/AQUA/src/aqua/graphics/hovmoller.py:200: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /gpfs/projects/ehpc01/sghosh/AQUA/src/aqua/graphics/hovmoller.py:200: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /gpfs/projects/ehpc01/sghosh/AQUA/src/aqua/graphics/hovmoller.py:200: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /home/bsc/bsc032946/.conda/envs/aqua/lib/python3.12/site-packages/dask/array/numpy_compat.py:57: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# /gpfs/projects/ehpc01/sghosh/AQUA/src/aqua/graphics/hovmoller.py:200: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /home/bsc/bsc032946/.conda/envs/aqua/lib/python3.12/site-packages/dask/array/numpy_compat.py:57: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# /gpfs/projects/ehpc01/sghosh/AQUA/src/aqua/graphics/hovmoller.py:200: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /gpfs/projects/ehpc01/sghosh/AQUA/src/aqua_diagnostics/ocean_drift/multiple_hovmoller.py:127: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0, 1, 0.95])  # Leave space for title
