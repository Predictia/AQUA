# %% [markdown]
# ## Ocean Trends

# %% [markdown]
# ### loading the modules

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from aqua.diagnostics.ocean_trends import Trends
# Out:
# /home/bsc/bsc032946/.conda/envs/aqua/lib/python3.12/site-packages/intake_esm/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %% [markdown]
# ### Initalizing the function

# %%
trend = Trends(catalog='mn5-phase2', model='IFS-NEMO', exp='control-1990-freeze', source='lra-r100-monthly',
                startdate="01-01-1990", enddate="31-12-1990",
          loglevel='DEBUG')

# %%
trend.run(
    outputdir= ".",
    var=['thetao', 'so'],
    region="io")
# Out:
# 2025-07-21 15:24:27 :: ConfigPath :: DEBUG    -> Updating the log_level to DEBUG
# 2025-07-21 15:24:27 :: ConfigPath :: DEBUG    -> AQUA installation found in /home/bsc/bsc032946/.aqua
# 2025-07-21 15:24:27 :: ConfigPath :: DEBUG    -> Configuration file found in /home/bsc/bsc032946/.aqua/config-aqua.yaml
# 2025-07-21 15:24:27 :: ConfigPath :: DEBUG    -> Available catalogs are ['mn5-phase2']
# 2025-07-21 15:24:27 :: ConfigPath :: DEBUG    -> Default catalog will be mn5-phase2
# 2025-07-21 15:24:27 :: ConfigPath :: DEBUG    -> Catalog file is /home/bsc/bsc032946/.aqua/catalogs/mn5-phase2/catalog.yaml
# 2025-07-21 15:24:27 :: ConfigPath :: DEBUG    -> Machine file is /home/bsc/bsc032946/.aqua/catalogs/mn5-phase2/machine.yaml
# 2025-07-21 15:24:27 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to MN5
# 2025-07-21 15:24:27 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to MN5
# ...

# %% [markdown]
# ### Plotting the data

# %%
trend.trend_coef.thetao[1].plot()
