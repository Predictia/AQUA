# %% [markdown]
# # Histogram diagnostic - Single histogram/PDF plot
#
# The aim of this diagnostic is to visualise the probability density function (PDF) or histogram of a certain variable over a specified region.
#
# In this notebook we demonstrate how to:
# 1. Compute a histogram using the `Histogram` class
# 2. Plot it using the `PlotHistogram` class
# 3. Optionally include reference data for comparison

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import the classes

# %%
from aqua.diagnostics.histogram import Histogram
from aqua.diagnostics.histogram import PlotHistogram
# Out:
# /LUMI_TYKKY_p0JFJ8i/miniforge/envs/env1/lib/python3.12/site-packages/intake_esm/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %% [markdown]
# ## Setup data dictionaries
#
# We define:
# - `dataset_dict`: Configuration for the model data
# - `obs_dict`: Configuration for reference/observational data (optional)
# - `common_dict`: Common parameters for both datasets

# %%
dataset_dict = {
    'catalog': 'climatedt-phase1',
    'model': 'ICON',
    'exp': 'historical-1990',
    'source': 'lra-r100-monthly'
}

obs_dict = {
    'catalog': 'obs',
    'model': 'ERA5',
    'exp': 'era5',
    'source': 'monthly'
}

common_dict = {
    'startdate': '1990-01-01',
    'enddate': '1999-12-31',
    'bins': 100,              # Number of bins for histogram
    'weighted': True,         # Use latitudinal weights
    'loglevel': 'INFO'
}

# %% [markdown]
# ## Compute histograms
#
# We create `Histogram` objects for both model and reference data.
# The `run()` method:
# 1. Retrieves the data from the catalog
# 2. Computes the histogram with `density=True` to get a PDF
# 3. Saves the result to a netCDF file
#
# We'll analyze `tprate` (Total Precipitation Rate) in mm/day.

# %%
# Create Histogram objects
hist_dataset = Histogram(**dataset_dict, **common_dict)
hist_obs = Histogram(**obs_dict, **common_dict)

# Configuration for the variable
run_dict = {
    'var': 'tprate',
    'units': 'mm/day',
    'density': True  # Get PDF instead of counts
}

# Compute histograms
hist_dataset.run(**run_dict)
hist_obs.run(**run_dict)
# Out:
# 2025-10-24 07:28:13 :: Histogram :: INFO     -> No region provided, using lon_limits: None, lat_limits: None
# 2025-10-24 07:28:13 :: Histogram :: INFO     -> No region provided, using lon_limits: None, lat_limits: None
# 2025-10-24 07:28:13 :: Histogram :: INFO     -> Running Histogram diagnostic for tprate
# 2025-10-24 07:28:13 :: Histogram :: INFO     -> Retrieving data for variable tprate
# 2025-10-24 07:28:13 :: ConfigPath :: INFO     -> ICON_historical-1990_lra-r100-monthly triplet found in in climatedt-phase1!
# 2025-10-24 07:28:13 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-10-24 07:28:13 :: Fixer :: INFO     -> Fix names in metadata is icon-destine-v1-lra
# 2025-10-24 07:28:13 :: Fixer :: INFO     -> Fix names icon-destine-v1-lra found in fixes files
# 2025-10-24 07:28:13 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2025-10-24 07:28:13 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2025-10-24 07:28:13 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2025-10-24 07:28:28 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-10-24 07:28:28 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2025-10-24 07:28:28 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-10-24 07:28:28 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2025-10-24 07:28:28 :: Regridder :: INFO     -> Grid name: lon-lat
# 2025-10-24 07:28:28 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_ICON_historical-1990_lra-r100-monthly.nc.
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2025-10-24 07:28:28 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2025-10-24 07:28:28 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2025-10-24 07:28:28 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-10-24 07:28:28 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2025-10-24 07:28:28 :: Histogram :: INFO     -> Computing histogram
# 2025-10-24 07:28:28 :: Histogram :: INFO     -> Computing histogram
# 2025-10-24 07:28:29 :: Histogram :: INFO     -> Computing histogram with the following parameters: bins=100, range=(-1.02334877711951, 103.3582264890705)
# 2025-10-24 07:28:29 :: Histogram :: INFO     -> Saving histogram to netcdf
# 2025-10-24 07:28:29 :: Histogram :: INFO     -> Saving histogram for variable tprate
# 2025-10-24 07:28:29 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-10-24 07:28:29 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/histogram.histogram.climatedt-phase1.ICON.historical-1990.r1.tprate.nc
# 2025-10-24 07:28:29 :: Histogram :: INFO     -> Histogram diagnostic computation completed
# 2025-10-24 07:28:29 :: Histogram :: INFO     -> Running Histogram diagnostic for tprate
# 2025-10-24 07:28:29 :: Histogram :: INFO     -> Retrieving data for variable tprate
# 2025-10-24 07:28:29 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2025-10-24 07:28:30 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-10-24 07:28:30 :: Fixer :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2025-10-24 07:28:30 :: Fixer :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2025-10-24 07:28:30 :: Reader :: INFO     -> Grid metadata is era5-r025s
# 2025-10-24 07:28:30 :: Regridder :: INFO     -> Grid name: era5-r025s
# 2025-10-24 07:28:30 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/aqua-dvc/areas/cell_area_era5-r025s.nc.
# 2025-10-24 07:28:30 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-10-24 07:28:30 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-10-24 07:28:30 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-10-24 07:28:30 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-10-24 07:28:30 :: CoordTransformer :: INFO     -> Reversing coordinate lat from decreasing to increasing
# 2025-10-24 07:28:30 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-10-24 07:28:30 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-10-24 07:28:30 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-10-24 07:28:30 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2025-10-24 07:28:30 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2025-10-24 07:28:30 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': 'TP', 'grib': 260048, 'src_units': 'm/day'}}
# 2025-10-24 07:28:30 :: Fixer :: INFO     -> tprate: converting units m/day --> kg m**-2 s**-1
# 2025-10-24 07:28:31 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-10-24 07:28:31 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-10-24 07:28:31 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-10-24 07:28:31 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-10-24 07:28:31 :: CoordTransformer :: INFO     -> Reversing coordinate lat from decreasing to increasing
# 2025-10-24 07:28:31 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-10-24 07:28:31 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-10-24 07:28:31 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-10-24 07:28:31 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2025-10-24 07:28:31 :: Histogram :: INFO     -> Computing histogram
# 2025-10-24 07:28:31 :: Histogram :: INFO     -> Computing histogram
# 2025-10-24 07:28:37 :: Histogram :: INFO     -> Computing histogram with the following parameters: bins=100, range=(-1.423110809326172, 143.73419174194336)
# 2025-10-24 07:28:37 :: Histogram :: INFO     -> Saving histogram to netcdf
# 2025-10-24 07:28:37 :: Histogram :: INFO     -> Saving histogram for variable tprate
# 2025-10-24 07:28:37 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-10-24 07:28:43 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/histogram.histogram.obs.ERA5.era5.r1.tprate.nc
# 2025-10-24 07:28:43 :: Histogram :: INFO     -> Histogram diagnostic computation completed

# %% [markdown]
# ## Plot the histogram/PDF
#
# Now we use `PlotHistogram` to visualize the computed histograms.
# We can plot:
# - Single model data with reference data
# - Multiple models together
# - With or without reference data

# %%
# Setup plot with model data and reference
plot = PlotHistogram(
    data=[hist_dataset.histogram_data],  # Note: needs to be a list
    ref_data=hist_obs.histogram_data,    # Reference data
    loglevel='INFO'
)

# Generate and save the plot
plot.run(
    ylogscale=True,    # Logarithmic scale for y-axis (frequency)
    xlogscale=False,   # Linear scale for x-axis (precipitation)
    smooth=False       # No smoothing applied
)
# Out:
# 2025-10-24 07:28:43 :: PlotHistogram :: INFO     -> Running PlotHistogram
# 2025-10-24 07:28:49 :: create_folder :: INFO     -> Folder ./png already exists
# 2025-10-24 07:28:50 :: add_png_metadata :: INFO     -> Metadata added to PNG: ./png/histogram.histogram_pdf.climatedt-phase1.ICON.historical-1990.r1.tprate.png
# 2025-10-24 07:28:50 :: OutputSaver :: INFO     -> Saved PNG: ./png/histogram.histogram_pdf.climatedt-phase1.ICON.historical-1990.r1.tprate.png
# 2025-10-24 07:28:50 :: PlotHistogram :: INFO     -> PlotHistogram completed successfully
